# %% [markdown]
# ## Generation of table summaries with LLM
# Ask Mistral 7B Instruct v0.3 to read a table and generate a summary of it <br>
# This notebook is used as support for performing table summaries in bulk.
# Once processed the summaries are stored to file.

# %%
# !pip install torch==2.1.0+cu121 torchvision==0.15.0+cu121 torchaudio==2.1.0+cu121
# !pip install --upgrade sympy
# !pip uninstall -y transformers
# !pip install transformers
# !pip install bitsandbytes

# %% [markdown]
# Suggested to run on Colab with a T4, 15GB gpu memory are required

# %%
from google.colab import drive
import numpy as np
from huggingface_hub import notebook_login
import torch
import time
from transformers import pipeline, AutoTokenizer, AutoModelForCausalLM
from transformers import BitsAndBytesConfig
import os
import re
import warnings
warnings.filterwarnings('ignore')

# %%
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
drive.mount('/content/gdrive')
# %cd gdrive/MyDrive/PW_NLP
# Out:
# Mounted at /content/gdrive
# /content/gdrive/MyDrive/PW_NLP

# %%
import torch
print(torch.version.cuda)
print(torch.cuda.is_available())

# !nvidia-smi
# Out:
# 12.4
# True
# Sat Feb  1 09:05:18 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   43C    P8             12W /   70W |       2MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
model_card = "mistralai/Mistral-7B-Instruct-v0.3"

tokenizer = AutoTokenizer.from_pretrained(model_card)
tokenizer.pad_token = tokenizer.eos_token

terminators = [
    tokenizer.eos_token_id,
    tokenizer.convert_tokens_to_ids("<|eot_id|>")
]

bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_use_double_quant=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.bfloat16,
)

# %%
model = AutoModelForCausalLM.from_pretrained(
    model_card,
    return_dict=True,
    quantization_config=bnb_config,
    device_map='auto'
)

generation_config = model.generation_config
generation_config.max_new_tokens = 1000
generation_config.eos_token_id = tokenizer.eos_token_id
generation_config.pad_token_id = tokenizer.eos_token_id
generation_config.temperature = 0.0
generation_config.num_return_sequences = 1

# %%
def call_model(model, input_ids_prompt, generation_config):
    start_time = time.time()
    with torch.no_grad():
      output = model.generate(
          **input_ids_prompt,
          max_new_tokens=generation_config.max_new_tokens,
          eos_token_id=generation_config.eos_token_id,
          pad_token_id=generation_config.pad_token_id,
          temperature=generation_config.temperature,
          num_return_sequences=generation_config.num_return_sequences
      )
      end_time = time.time()

    generated_text = tokenizer.decode(output[0], skip_special_tokens=True)
    return generated_text, round(end_time-start_time, 2)

# %%
def parse_response(text):
    # Define regex patterns for extracting the title, description, and keywords
    title_pattern = r"'title':\s*'(.*?)'"
    description_pattern = r"'description':\s*'(.*?)'"
    keywords_pattern = r"'keywords':\s*\[(.*?)\]"

    # Extract title, description, and keywords using regex
    title_match = re.search(title_pattern, text)
    description_match = re.search(description_pattern, text)
    keywords_match = re.search(keywords_pattern, text)

    # Check if all parts were found
    if title_match and description_match and keywords_match:
        title = title_match.group(1)
        description = description_match.group(1)
        # Clean up the keywords list and join them into a string
        keywords = ', '.join([kw.strip("'") for kw in keywords_match.group(1).split(',')])

        # Return the formatted string
        return f"{title}. {description} {keywords}"
    else:
        return "Error: Could not extract information"

# %%
template_short = """
You are a finance expert specialized in analyzing tables.

### Task ###
Summarize the table in a dictionary with the following keys:
- 'title': A concise title for the table.
- 'description': A brief description of the table's contents and key trends.
- 'keywords': A list of relevant keywords.

**Note**: Do not return the table, prompt, or any extra text. Return only the dictionary.

### Table ###
"""

template_long = """
You are a finance expert specialized in analyzing financial tables.

### Task ###
Analyze the table and transcribe its contents into a well-structured summary. Generate a detailed paragraph that captures all relevant information, including numerical data, trends, and observations.
If the table contains acronyms, provide their concise definitions where possible.
Return the output in the form of a dictionary with the following keys:
- 'title': A concise title for the table.
- 'description': A brief description of the table's contents and key trends.
- 'keywords': A list of the most relevant keywords of the table.

**Note**: Do not return the table, prompt, or any extra text. Return only the dictionary.

### Table ###
"""

# %%
def create_summaries(dataset, template, template_name, max_new_tokens=1000):
    generation_config.max_new_tokens = max_new_tokens
    print(f"CREATING SUMMARIES FOR {dataset}, with template: {template}\n\n")

    # Check if the results file are already there, and continue in case
    if os.path.exists(f'table_summaries_{dataset}_{template_name}.npy'):
        summaries_npy = np.load(f'table_summaries_{dataset}_{template_name}.npy', allow_pickle='TRUE').item()
        print(f"table_summaries_{dataset}_{template_name}.npy already created!\t It contains: ", len(summaries_npy), " summary tables ", list(summaries_npy.keys()))
    else:
        summaries_npy = {}
    if os.path.exists(f'Timing_{dataset}_{template_name}.npy'):
        timing_npy = np.load(f'Timing_{dataset}_{template_name}.npy', allow_pickle='TRUE').item()
        print(f"Timing_{dataset}_{template_name}.npy already created!\t It contains: ", len(timing_npy), " summary tables ")
    else:
        timing_npy = {}

    # Load the extracted tables to compute the summaries
    table_dict = np.load(f'extracted_tables_{dataset}.npy', allow_pickle='TRUE').item()
    print(f"\nLoaded extracted_tables_{dataset}, it has {len(table_dict)} tables to process")

    count = 0
    print("\n\n")
    for key, value in table_dict.items():
        count += 1
        print(f"\t{count} - Key: {key}")
        # Check if the table has already been processed
        if key in summaries_npy:
            print(f"\t\tSkipping {key}, already processed ...\n")
            continue
        if value == []:
            print(f"\t\tSkipping {key}, no table found ...\n")
            continue

        table = value[0]
        prompt = template + table
        # Tokenize the prompt
        input_ids_prompt = tokenizer(prompt, return_tensors="pt").to(model.device)
        # Call the model
        model_response, total_time = call_model(model, input_ids_prompt, generation_config)
        # Parse the response
        response_text = model_response[len(prompt):]
        parsed_resp = parse_response(response_text)
        print(parsed_resp)
        print(f"Time: {total_time} seconds")
        print("\n\n")

        summaries_npy[key] = parsed_resp
        np.save(f'table_summaries_{dataset}_{template_name}.npy', summaries_npy)
        timing_npy[key] = total_time
        np.save(f'Timing_{dataset}_{template_name}.npy', timing_npy)

# %% [markdown]
# -------------------------------------------------

# %%
# create_summaries("FinQA", template_short, "short")
# Out:
# CREATING SUMMARIES FOR FinQA, with template:
# You are a finance expert who specializes in analyzing tables.
#
# ### Task ###
# Summarize the table in a dictionary with the following keys:
# - 'title': A concise title for the table.
# - 'description': A brief description of the table's contents and key trends.
# - 'keywords': A list of relevant keywords.
#
# **Note**: Do not return the table, prompt, or any extra text. Return only the dictionary.
#
# ### Table ###
#
#
#
# table_summaries_FinQA_short.npy already created!	 It contains:  160  summary tables  ['d6167ace8', 'd61650380', 'd6166eb32', 'd616785a6', 'd61655808', 'd616540de', 'd616760d0', 'd61660f64', 'd61650524', 'd6165a4d4', 'd6168290c', 'd6165f736', 'd6165cdec', 'd61651758', 'd61658206', 'd61665460', 'd616556b4', 'd6166041a', 'd616749e2', 'd6166c440', 'd61666450', 'd61652ff4', 'd616950b6', 'd61655132', 'd61656fc8', 'd616619d2', 'd6165e656', 'd6165385a', 'd61652536', 'd6167bf94', 'd6165e3e0', 'd61679b40', 'd61657de2', 'd61665db6', 'd6166b2c0', 'd6167c4bc', 'd6165f344', 'd61659c0a', 'd6165c82e', 'd6166f3e8', 'd61657130', 'd61676c2e', 'd61654d5e', 'd61670572', 'd61663a84', 'd61667648', 'd61653e4a', 'd616687c8', 'd61679a14', 'd616515c8', 'd6167950a', 'd6166751c', 'd6165a8e4', 'd61654fe8', 'd6165f5ec', 'd6166a47e', 'd61669894', 'd6166d64c', 'd61651f82', 'd61673cb8', 'd6165a042', 'd6167743a', 'd61650830', 'd6166bc7a', 'd61666b6c', 'd6166299a', 'd6167a824', 'd6165b8c0', 'd6165e052', 'd6168ddf2', 'd61668660', 'd6165525e', 'd6165c0e0', 'd6165e9e4', 'd616670e4', 'd6165c3a6', 'd616a0a24', 'd61669682', 'd61677610', 'd616a402a', 'd6168643a', 'd6169a002', 'd6165f9d4', 'd6167e6f4', 'd61660dfc', 'd616580b2', 'd6168242a', 'd6166bf90', 'd61661aea', 'd61674f82', 'd616862d2', 'd6165899a', 'd6165c9a0', 'd6167676a', 'd6166ace4', 'd61699ada', 'd61661752', 'd6165439a', 'd6165defe', 'd61653b7a', 'd6165ab96', 'd6167a54a', 'd61652c8e', 'd61675c84', 'd61650ce0', 'd6164fd9a', 'd6165556a', 'd6167048c', 'd6165270c', 'd616831c2', 'd61674046', 'd61684cb6', 'd6165737e', 'd616680b6', 'd6166cea4', 'd61662f44', 'd61665c62', 'd61669efc', 'd61656168', 'd6168db72', 'd61668d2c', 'd6165853a', 'd61671260', 'd6165ef8e', 'd61650236', 'd6165241e', 'd6167deca', 'd616547b4', 'd616534ea', 'd616606d6', 'd6165d7a6', 'd616624e0', 'd6167331c', 'd6166479a', 'd61679140', 'd6165725c', 'd616521f8', 'd6166fae6', 'd61673916', 'd61658b70', 'd616821f0', 'd61657f36', 'd61663bec', 'd616a5204', 'd6167c390', 'd6166e29a', 'd6165aa4c', 'd6168ecb6', 'd61670b1c', 'd61656ce4', 'd61657626', 'd6166c08a', 'd61654976', 'd61693414', 'd616553ee', 'd61654c3c', 'd6166a258', 'd6167f63a', 'd616535da', 'd61662e22']
# Timing_FinQA_short.npy already created!	 It contains:  160  summary tables
# Loaded extracted_tables_FinQA, it has 247 tables to process
#
#
#
# 	1 - Key: d6167ace8
# 		Skipping d6167ace8, already processed ...
#
# 	2 - Key: d61650380
# 		Skipping d61650380, already processed ...
#
# 	3 - Key: d6166eb32
# 		Skipping d6166eb32, already processed ...
#
# 	4 - Key: d616785a6
# 		Skipping d616785a6, already processed ...
#
# 	5 - Key: d61655808
# 		Skipping d61655808, already processed ...
#
# 	6 - Key: d616540de
# 		Skipping d616540de, already processed ...
#
# 	7 - Key: d616760d0
# 		Skipping d616760d0, already processed ...
#
# 	8 - Key: d61660f64
# 		Skipping d61660f64, already processed ...
#
# 	9 - Key: d61650524
# 		Skipping d61650524, already processed ...
#
# 	10 - Key: d6165a4d4
# 		Skipping d6165a4d4, already processed ...
#
# 	11 - Key: d6168290c
# 		Skipping d6168290c, already processed ...
#
# 	12 - Key: d6165f736
# 		Skipping d6165f736, already processed ...
#
# 	13 - Key: d6165cdec
# 		Skipping d6165cdec, already processed ...
#
# 	14 - Key: d61651758
# 		Skipping d61651758, already processed ...
#
# 	15 - Key: d61658206
# 		Skipping d61658206, already processed ...
#
# 	16 - Key: d61665460
# 		Skipping d61665460, already processed ...
#
# 	17 - Key: d616556b4
# 		Skipping d616556b4, already processed ...
#
# 	18 - Key: d6166041a
# 		Skipping d6166041a, already processed ...
#
# 	19 - Key: d616749e2
# 		Skipping d616749e2, already processed ...
#
# 	20 - Key: d6166c440
# 		Skipping d6166c440, already processed ...
#
# 	21 - Key: d61666450
# 		Skipping d61666450, already processed ...
#
# 	22 - Key: d61652ff4
# 		Skipping d61652ff4, already processed ...
#
# 	23 - Key: d616950b6
# 		Skipping d616950b6, already processed ...
#
# 	24 - Key: d61655132
# 		Skipping d61655132, already processed ...
#
# 	25 - Key: d61656fc8
# 		Skipping d61656fc8, already processed ...
#
# 	26 - Key: d616619d2
# 		Skipping d616619d2, already processed ...
#
# 	27 - Key: d6165e656
# 		Skipping d6165e656, already processed ...
#
# 	28 - Key: d6165385a
# 		Skipping d6165385a, already processed ...
#
# 	29 - Key: d61652536
# 		Skipping d61652536, already processed ...
#
# 	30 - Key: d6167bf94
# 		Skipping d6167bf94, already processed ...
#
# 	31 - Key: d6165e3e0
# 		Skipping d6165e3e0, already processed ...
#
# 	32 - Key: d61679b40
# 		Skipping d61679b40, already processed ...
#
# 	33 - Key: d61657de2
# 		Skipping d61657de2, already processed ...
#
# 	34 - Key: d61665db6
# 		Skipping d61665db6, already processed ...
#
# 	35 - Key: d6166b2c0
# 		Skipping d6166b2c0, already processed ...
#
# 	36 - Key: d6167c4bc
# 		Skipping d6167c4bc, already processed ...
#
# 	37 - Key: d6165f344
# 		Skipping d6165f344, already processed ...
#
# 	38 - Key: d61659c0a
# 		Skipping d61659c0a, already processed ...
#
# 	39 - Key: d6165c82e
# 		Skipping d6165c82e, already processed ...
#
# 	40 - Key: d6166f3e8
# 		Skipping d6166f3e8, already processed ...
#
# 	41 - Key: d61657130
# 		Skipping d61657130, already processed ...
#
# 	42 - Key: d61676c2e
# 		Skipping d61676c2e, already processed ...
#
# 	43 - Key: d61654d5e
# 		Skipping d61654d5e, already processed ...
#
# 	44 - Key: d61670572
# 		Skipping d61670572, already processed ...
#
# 	45 - Key: d61663a84
# 		Skipping d61663a84, already processed ...
#
# 	46 - Key: d61667648
# 		Skipping d61667648, already processed ...
#
# 	47 - Key: d61653e4a
# 		Skipping d61653e4a, already processed ...
#
# 	48 - Key: d616687c8
# 		Skipping d616687c8, already processed ...
#
# 	49 - Key: d61679a14
# 		Skipping d61679a14, already processed ...
#
# 	50 - Key: d616515c8
# 		Skipping d616515c8, already processed ...
#
# 	51 - Key: d6167950a
# 		Skipping d6167950a, already processed ...
#
# 	52 - Key: d6166751c
# 		Skipping d6166751c, already processed ...
#
# 	53 - Key: d6165a8e4
# 		Skipping d6165a8e4, already processed ...
#
# 	54 - Key: d61654fe8
# 		Skipping d61654fe8, already processed ...
#
# 	55 - Key: d6165f5ec
# 		Skipping d6165f5ec, already processed ...
#
# 	56 - Key: d6166a47e
# 		Skipping d6166a47e, already processed ...
#
# 	57 - Key: d61669894
# 		Skipping d61669894, already processed ...
#
# 	58 - Key: d6166d64c
# 		Skipping d6166d64c, already processed ...
#
# 	59 - Key: d61651f82
# 		Skipping d61651f82, already processed ...
#
# 	60 - Key: d61673cb8
# 		Skipping d61673cb8, already processed ...
#
# 	61 - Key: d6165a042
# 		Skipping d6165a042, already processed ...
#
# 	62 - Key: d6167743a
# 		Skipping d6167743a, already processed ...
#
# 	63 - Key: d61650830
# 		Skipping d61650830, already processed ...
#
# 	64 - Key: d6166bc7a
# 		Skipping d6166bc7a, already processed ...
#
# 	65 - Key: d61666b6c
# 		Skipping d61666b6c, already processed ...
#
# 	66 - Key: d6166299a
# 		Skipping d6166299a, already processed ...
#
# 	67 - Key: d6167a824
# 		Skipping d6167a824, already processed ...
#
# 	68 - Key: d6165b8c0
# 		Skipping d6165b8c0, already processed ...
#
# 	69 - Key: d6165e052
# 		Skipping d6165e052, already processed ...
#
# 	70 - Key: d6168ddf2
# 		Skipping d6168ddf2, already processed ...
#
# 	71 - Key: d61668660
# 		Skipping d61668660, already processed ...
#
# 	72 - Key: d6165525e
# 		Skipping d6165525e, already processed ...
#
# 	73 - Key: d6165c0e0
# 		Skipping d6165c0e0, already processed ...
#
# 	74 - Key: d6165e9e4
# 		Skipping d6165e9e4, already processed ...
#
# 	75 - Key: d616670e4
# 		Skipping d616670e4, already processed ...
#
# 	76 - Key: d6165c3a6
# 		Skipping d6165c3a6, already processed ...
#
# 	77 - Key: d616a0a24
# 		Skipping d616a0a24, already processed ...
#
# 	78 - Key: d61669682
# 		Skipping d61669682, already processed ...
#
# 	79 - Key: d61677610
# 		Skipping d61677610, already processed ...
#
# 	80 - Key: d616a402a
# 		Skipping d616a402a, already processed ...
#
# 	81 - Key: d6168643a
# 		Skipping d6168643a, already processed ...
#
# 	82 - Key: d6169a002
# 		Skipping d6169a002, already processed ...
#
# 	83 - Key: d6165f9d4
# 		Skipping d6165f9d4, already processed ...
#
# 	84 - Key: d6167e6f4
# 		Skipping d6167e6f4, already processed ...
#
# 	85 - Key: d61660dfc
# 		Skipping d61660dfc, already processed ...
#
# 	86 - Key: d616580b2
# 		Skipping d616580b2, already processed ...
#
# 	87 - Key: d6168242a
# 		Skipping d6168242a, already processed ...
#
# 	88 - Key: d6166bf90
# 		Skipping d6166bf90, already processed ...
#
# 	89 - Key: d61661aea
# 		Skipping d61661aea, already processed ...
#
# 	90 - Key: d61674f82
# 		Skipping d61674f82, already processed ...
#
# 	91 - Key: d616862d2
# 		Skipping d616862d2, already processed ...
#
# 	92 - Key: d6165899a
# 		Skipping d6165899a, already processed ...
#
# 	93 - Key: d6165c9a0
# 		Skipping d6165c9a0, already processed ...
#
# 	94 - Key: d6167676a
# 		Skipping d6167676a, already processed ...
#
# 	95 - Key: d6166ace4
# 		Skipping d6166ace4, already processed ...
#
# 	96 - Key: d61699ada
# 		Skipping d61699ada, already processed ...
#
# 	97 - Key: d61661752
# 		Skipping d61661752, already processed ...
#
# 	98 - Key: d6165439a
# 		Skipping d6165439a, already processed ...
#
# 	99 - Key: d6165defe
# 		Skipping d6165defe, already processed ...
#
# 	100 - Key: d61653b7a
# 		Skipping d61653b7a, already processed ...
#
# 	101 - Key: d6165ab96
# 		Skipping d6165ab96, already processed ...
#
# 	102 - Key: d6167a54a
# 		Skipping d6167a54a, already processed ...
#
# 	103 - Key: d61652c8e
# 		Skipping d61652c8e, already processed ...
#
# 	104 - Key: d61675c84
# 		Skipping d61675c84, already processed ...
#
# 	105 - Key: d61650ce0
# 		Skipping d61650ce0, already processed ...
#
# 	106 - Key: d6164fd9a
# 		Skipping d6164fd9a, already processed ...
#
# 	107 - Key: d6165556a
# 		Skipping d6165556a, already processed ...
#
# 	108 - Key: d6167048c
# 		Skipping d6167048c, already processed ...
#
# 	109 - Key: d6165270c
# 		Skipping d6165270c, already processed ...
#
# 	110 - Key: d616831c2
# 		Skipping d616831c2, already processed ...
#
# 	111 - Key: d61674046
# 		Skipping d61674046, already processed ...
#
# 	112 - Key: d61684cb6
# 		Skipping d61684cb6, already processed ...
#
# 	113 - Key: d6165737e
# 		Skipping d6165737e, already processed ...
#
# 	114 - Key: d616680b6
# 		Skipping d616680b6, already processed ...
#
# 	115 - Key: d6166cea4
# 		Skipping d6166cea4, already processed ...
#
# 	116 - Key: d61662f44
# 		Skipping d61662f44, already processed ...
#
# 	117 - Key: d61665c62
# 		Skipping d61665c62, already processed ...
#
# 	118 - Key: d61669efc
# 		Skipping d61669efc, already processed ...
#
# 	119 - Key: d61656168
# 		Skipping d61656168, already processed ...
#
# 	120 - Key: d6168db72
# 		Skipping d6168db72, already processed ...
#
# 	121 - Key: d61668d2c
# 		Skipping d61668d2c, already processed ...
#
# 	122 - Key: d6165853a
# 		Skipping d6165853a, already processed ...
#
# 	123 - Key: d61671260
# 		Skipping d61671260, already processed ...
#
# 	124 - Key: d6165ef8e
# 		Skipping d6165ef8e, already processed ...
#
# 	125 - Key: d61650236
# 		Skipping d61650236, already processed ...
#
# 	126 - Key: d6165241e
# 		Skipping d6165241e, already processed ...
#
# 	127 - Key: d6167deca
# 		Skipping d6167deca, already processed ...
#
# 	128 - Key: d616547b4
# 		Skipping d616547b4, already processed ...
#
# 	129 - Key: d616534ea
# 		Skipping d616534ea, already processed ...
#
# 	130 - Key: d616606d6
# 		Skipping d616606d6, already processed ...
#
# 	131 - Key: d6165d7a6
# 		Skipping d6165d7a6, already processed ...
#
# 	132 - Key: d616624e0
# 		Skipping d616624e0, already processed ...
#
# 	133 - Key: d6167331c
# 		Skipping d6167331c, already processed ...
#
# 	134 - Key: d6166479a
# 		Skipping d6166479a, already processed ...
#
# 	135 - Key: d61679140
# 		Skipping d61679140, already processed ...
#
# 	136 - Key: d6165725c
# 		Skipping d6165725c, already processed ...
#
# 	137 - Key: d616521f8
# 		Skipping d616521f8, already processed ...
#
# 	138 - Key: d6166fae6
# 		Skipping d6166fae6, already processed ...
#
# 	139 - Key: d61673916
# 		Skipping d61673916, already processed ...
#
# 	140 - Key: d61658b70
# 		Skipping d61658b70, already processed ...
#
# 	141 - Key: d616821f0
# 		Skipping d616821f0, already processed ...
#
# 	142 - Key: d61657f36
# 		Skipping d61657f36, already processed ...
#
# 	143 - Key: d61663bec
# 		Skipping d61663bec, already processed ...
#
# 	144 - Key: d616a5204
# 		Skipping d616a5204, already processed ...
#
# 	145 - Key: d6167c390
# 		Skipping d6167c390, already processed ...
#
# 	146 - Key: d6166e29a
# 		Skipping d6166e29a, already processed ...
#
# 	147 - Key: d6165aa4c
# 		Skipping d6165aa4c, already processed ...
#
# 	148 - Key: d6168ecb6
# 		Skipping d6168ecb6, already processed ...
#
# 	149 - Key: d61670b1c
# 		Skipping d61670b1c, already processed ...
#
# 	150 - Key: d61656ce4
# 		Skipping d61656ce4, already processed ...
#
# 	151 - Key: d61657626
# 		Skipping d61657626, already processed ...
#
# 	152 - Key: d6166c08a
# 		Skipping d6166c08a, already processed ...
#
# 	153 - Key: d61654976
# 		Skipping d61654976, already processed ...
#
# 	154 - Key: d61693414
# 		Skipping d61693414, already processed ...
#
# 	155 - Key: d616553ee
# 		Skipping d616553ee, already processed ...
#
# 	156 - Key: d61654c3c
# 		Skipping d61654c3c, already processed ...
#
# 	157 - Key: d6166a258
# 		Skipping d6166a258, already processed ...
#
# 	158 - Key: d6167f63a
# 		Skipping d6167f63a, already processed ...
#
# 	159 - Key: d616535da
# 		Skipping d616535da, already processed ...
#
# 	160 - Key: d61662e22
# 		Skipping d61662e22, already processed ...
#
# 	161 - Key: d61663dfe
# Net Income and Shares Outstanding. This table shows the net income and shares outstanding for three years ending December 31, 2013 to 2015. The net income remained constant at $1,000 million for all years. The number of basic weighted-average shares outstanding decreased from 156.6 million in 2013 to 170.3 million in 2015. The number of diluted weighted-average shares outstanding increased from 158.7 million in 2013 to 171.8 million in 2015. The net income per diluted share decreased from 6.4 in 2013 to 5.8 in 2014 and further to 5.9 in 2015. net income,  'shares outstanding,  'basic weighted-average shares outstanding,  'diluted weighted-average shares outstanding,  'net income per diluted share,  '2013,  '2014,  '2015
# Time: 27.65 seconds
#
#
#
# 	162 - Key: d6167082e
# Stock Options Vesting Schedule. This table shows the number of shares and their fair value for various stock option grants, vested shares, forfeited shares, and non-vested shares as of May 31 of each year from 2011 to 2020. stock options,  'vesting schedule,  'shares,  'grant,  'weighted average grant-date fair value,  'vested,  'forfeited,  'non-vested
# Time: 63.22 seconds
#
#
#
# 	163 - Key: d6166d174
# Restructuring Charges for 2015. This table shows the costs associated with various restructuring programs in 2015. The main costs include termination benefits, facility closure costs, contract termination costs, and other exit costs. The total restructuring charges for 2015 were $7,819 thousand. restructuring,  'charges,  '2015,  'termination benefits,  'facility closure costs,  'contract termination costs,  'other exit costs,  'thousands
# Time: 13.32 seconds
#
#
#
# 	164 - Key: d6165ae20
# Table of Financial Obligations. This table shows the breakdown of financial obligations for a company, with the total amount being $5424. The two main categories are single-dip equity obligations and labor-related deemed claims. financial obligations,  'single-dip equity obligations,  'labor-related deemed claim,  'total
# Time: 8.08 seconds
#
#
#
# 	165 - Key: d61668304
# Assets Under Management (AUM) by Asset Class. This table shows the total assets under management (AUM) for each asset class as of December 31, 2011 and December 31, 2012. Key trends include an increase in net new business and net acquired for all asset classes, with the largest increase in the alternatives category. assets under management,  'AUM,  'equity,  'fixed income,  'multi-asset class,  'alternatives,  'net new business,  'net acquired
# Time: 13.07 seconds
#
#
#
# 	166 - Key: d61667ce2
# Stock Shares Over Time. This table shows the number of shares issued, treasury shares, and shares outstanding for a company over a period of time. Key trends include the exercise of stock options and issuance of other stock awards, which resulted in a decrease in treasury shares and an increase in shares outstanding. shares issued,  'treasury shares,  'shares outstanding,  'stock options,  'stock awards,  'exercise,  'decrease,  'increase
# Time: 12.59 seconds
#
#
#
# 	167 - Key: d6166a5d2
# Error: Could not extract information
# Time: 166.38 seconds
#
#
#
# 	168 - Key: d6167309c
# US Credit Card Industry Overview. This table shows the evolution of the US credit card industry from 2006 to 2008 in billions of dollars. Key trends include a decrease in on-balance-sheet assets and an increase in securitized receivables, with a notable drop in credit card receivables held-for-sale in 2008. credit card,  'industry,  'on-balance-sheet,  'securitized receivables,  'held-for-sale,  'US,  'evolution,  '2006,  '2007,  '2008
# Time: 16.14 seconds
#
#
#
# 	169 - Key: d6165c25c
# Lease and Purchase Obligations. This table shows the total lease and purchase obligations in millions for the years 2007 to 2011, with a trend of decreasing lease obligations and a significant increase in purchase obligations after 2011. lease obligations,  'purchase obligations,  'millions,  'trend,  '2007,  '2008,  '2009,  '2010,  '2011
# Time: 11.69 seconds
#
#
#
# 	170 - Key: d61672ef8
# Interest and Principal Payments by Year. This table shows the total interest and principal payments for two different products from 2016 to 2020. The principal and interest product has consistently higher payments compared to the interest only product. The total payments for both products have increased significantly from 2016 to 2020. payments,  'interest,  'principal,  'year,  'product,  'increase,  'total
# Time: 11.88 seconds
#
#
#
# 	171 - Key: d61668516
# Interest Rates and Borrowings. This table shows the average and maximum borrowings, as well as the weighted average interest rates for the years 2016 and 2017. Key trends include a decrease in average and maximum borrowings, and an increase in weighted average interest rates. borrowings,  'interest rates,  'average,  'maximum,  'weighted,  '2016,  '2017
# Time: 11.04 seconds
#
#
#
# 	172 - Key: d61681034
# Securities Balance Sheet. This table shows the balance of securities in millions as of December 2015 and December 2014. Key trends include a decrease in securities purchased under agreements to resell, an increase in securities borrowed, a decrease in securities sold under agreements to repurchase, and a significant decrease in securities loaned. securities,  'balance,  'purchased,  'resell,  'borrowed,  'sold,  'repurchase,  'loaned,  'millions,  'December,  '2015,  '2014
# Time: 14.37 seconds
#
#
#
# 	173 - Key: d6166f622
# Interest Rate Changes and Their Impact on Assets. This table shows the impact of changes in interest rates on assets over a period of years. The table shows the change in assets for an increase of 200 basis points, 100 basis points, and a decrease of 100 basis points. interest rates,  'assets,  'changes,  'basis points,  'impact
# Time: 20.37 seconds
#
#
#
# 	174 - Key: d616583e6
# Stock Ownership of Apple Executive Officers and Directors. This table shows the stock ownership of Apple executive officers and directors as of a certain date. Notable absences include Tim Cook, Millard Drexler, and Phil Schiller. The group as a whole owns 9,378,423 shares, accounting for 1.09% of the company. Apple,  'stock,  'ownership,  'executive officers,  'directors
# Time: 12.79 seconds
#
#
#
# 	175 - Key: d6165eaf2
# Market Share of Infraserv Gmbh & Co Branches as of December 31, 2016. The table shows the market share of four Infraserv Gmbh & Co branches as of December 31, 2016, with the largest share held by the Gendorf branch at 39%. Infraserv Gmbh & Co,  'market share,  'branches,  'December 31,  2016,  'Gendorf,  'Hoechst,  'Knapsack,  'Kulz
# Time: 14.52 seconds
#
#
#
# 	176 - Key: d61652ad6
# Financial Performance of a Bank. This table shows the financial performance of a bank from 2007 to 2009. Key trends include a decrease in total assets and liabilities, a significant drop in net income, and an increase in net interest revenue. Non-interest revenue has fluctuated significantly. net interest revenue,  'non-interest revenue,  'revenues net of interest expense,  'total operating expenses,  'net credit losses,  'provision for unfunded lending commitments,  'credit reserve builds,  'provisions for credit losses,  'income taxes,  'net income,  'eop assets,  'eop liabilities
# Time: 23.09 seconds
#
#
#
# 	177 - Key: d61693e8c
# Quarterly Sales Growth by Year. This table shows the quarterly sales growth for four consecutive years from 2012 to 2015. The growth rates are consistent across all quarters for each year, with a slight increase in sales growth from 2012 to 2015. sales growth,  'quarterly,  'year,  '2012,  '2013,  '2014,  '2015
# Time: 16.22 seconds
#
#
#
# 	178 - Key: d61662094
# Liability and Cash Payments Over Three Years. This table shows the liability and cash payments for employee separations, lease terminations, and other facility closing costs from 2004 to 2006. liability,  'expense,  'cash payments,  'employee separations,  'lease terminations,  'facility closing costs,  '2004,  '2005,  '2006
# Time: 12.95 seconds
#
#
#
# 	179 - Key: d6166c8e6
# Assets Under Management by Vehicle Type (2002-2003). The table shows the assets under management by various types of vehicles for the years 2002 and 2003. Key trends include a decrease in structured commercial loan vehicles and credit-linked note vehicles, while municipal bond vehicles and other client intermediation vehicles remained relatively stable. assets,  'under management,  'vehicle type,  '2002,  '2003,  'structured commercial loan vehicles,  'credit-linked note vehicles,  'municipal bond vehicles,  'other client intermediation vehicles
# Time: 13.45 seconds
#
#
#
# 	180 - Key: d6167a2a2
# Balance Sheet - Tax Positions. This table shows the balance sheet for tax positions from 2017 to 2018. Key trends include a decrease in reductions for tax positions of prior years, an increase in additions for tax positions of prior years, and a decrease in the balance at December 31. balance sheet,  'tax positions,  '2017,  '2018,  'additions,  'reductions,  'settlements,  'business combinations,  'lapse of statute of limitations,  'foreign currency translation
# Time: 14.04 seconds
#
#
#
# 	181 - Key: d6169c32a
# Equity Compensation Plans. This table provides information on equity compensation plans approved and not approved by security holders, including the number of securities to be issued, weighted-average exercise prices, and remaining securities available for future issuance. equity compensation plans,  'security holders,  'number of securities,  'exercise price,  'available securities
# Time: 10.18 seconds
#
#
#
# 	182 - Key: d6165e23c
# Land Improvements. The table shows the number of instances for various types of land improvements. Key trends include a higher range for buildings (39-40) and a lower range for most other categories (1-10). land improvements,  'buildings,  'furniture fixtures and equipment,  'landscaping,  'office equipment,  'parking lots and roadways,  'structures
# Time: 12.93 seconds
#
#
#
# 	183 - Key: d6168ea86
# Yearly Amounts. This table shows the yearly amounts from 2019 to 2023, with a significant increase in 2021, followed by a decrease in 2022 and a slight increase in 2023. The total amount from 2019 to 2023 is $6,609,866. year,  'amount,  'increase,  'decrease,  'total
# Time: 11.37 seconds
#
#
#
# 	184 - Key: d616644ac
# Revenue by Product Category (2004-2006). The table shows the revenue in millions for various product categories of a company from 2004 to 2006. Key trends include a decrease in revenue for printing papers and corporate and other expenses, while revenue for industrial packaging and forest products remained relatively stable. revenue,  'product categories,  '2004-2006,  'printing papers,  'industrial packaging,  'consumer packaging,  'distribution,  'forest products,  'corporate expenses
# Time: 12.99 seconds
#
#
#
# 	185 - Key: d616631ec
# U.S. Tax Rates and Credits. This table shows the statutory U.S. tax rate, state income taxes net of federal benefit, international income taxes net, U.S. research and development credit, reserves for tax contingencies, domestic manufacturer 2019s deduction, all other net, and effective worldwide tax rate for the years 2011, 2012, and 2013. tax rate,  'state income taxes,  'international income taxes,  'U.S. research and development credit,  'reserves for tax contingencies,  'domestic manufacturer deduction,  'all other,  'effective worldwide tax rate,  '2011,  '2012,  '2013
# Time: 17.47 seconds
#
#
#
# 	186 - Key: d6164f9bc
# Real Estate Facilities by Ownership and Location. This table shows the square footage of owned and leased facilities in millions for the United States and other countries. The total facilities column represents the sum of owned and leased facilities for each location. real estate,  'facilities,  'owned facilities,  'leased facilities,  'square footage,  'millions,  'United States,  'other countries,  'total
# Time: 10.84 seconds
#
#
#
# 	187 - Key: d6166e8e4
# Fiscal Year vs. Volume and Support Incentives. This table shows the total fiscal (in millions) and volume and support incentives from 2009 to 2013, with a significant drop in 2012. After 2013, the incentives are only 3. fiscal,  'millions,  'volume,  'support incentives,  'trend,  '2009,  '2010,  '2011,  '2012,  '2013
# Time: 12.36 seconds
#
#
#
# 	188 - Key: d61651dca
# Total Contractual Obligations by Maturity. This table shows the total contractual obligations for various types of liabilities, broken down by maturity. The majority of obligations are due within 5 years, with a significant portion due within the next year. Keywords: total, contractual obligations, liabilities, maturity, debt, capital lease obligations, operating leases, purchase obligations, other noncurrent liabilities. total,  'contractual obligations,  'liabilities,  'maturity,  'debt,  'capital lease obligations,  'operating leases,  'purchase obligations,  'other noncurrent liabilities
# Time: 14.92 seconds
#
#
#
# 	189 - Key: d6165a6dc
# Financial Liabilities Over Time. This table shows the evolution of various financial liabilities from 2008 to 2012, and their total values. Key trends include a decrease in capital leases and operating leases, a significant increase in debt principal and debt interest, and a steady increase in other liabilities. capital leases,  'operating leases,  'debt principal,  'debt interest,  'purchase commitments,  'pension fundings,  'other liabilities,  'financial liabilities,  'trends,  '2008,  '2009,  '2010,  '2011,  '2012
# Time: 17.2 seconds
#
#
#
# 	190 - Key: d6165d2a6
# US Lending Trends. This table shows the total consumer and commercial lending in the US from December 31, 2011 to December 31, 2012. Key trends include an increase in total consumer lending (A), total TDRs, and nonperforming loans. Credit card lending (C) decreased slightly. lending,  'consumer,  'commercial,  'trends,  'US,  'total,  'TDRs,  'nonperforming,  'credit card
# Time: 13.0 seconds
#
#
#
# 	191 - Key: d6165a36c
# Net Undeveloped Acres by Year and Region. This table shows the net undeveloped acres expiring in the years 2014, 2015, and 2016 for various regions including the US, Europe, Africa, and International. Key trends include a significant increase in acres expiring in Africa for 2015, and a decrease in acres expiring worldwide in 2016 compared to 2014. net undeveloped acres,  'expiring,  '2014,  '2015,  '2016,  'US,  'Europe,  'Africa,  'International,  'increase,  'decrease
# Time: 16.08 seconds
#
#
#
# 	192 - Key: d6168cff6
# Contractual Obligations by Type. This table shows the contractual obligations of a company in millions of dollars, broken down by type (debt, operating leases, capital lease obligations, purchase obligations, other post retirement benefits, income tax contingencies) and the payments due by specific years. contractual obligations,  'millions of dollars,  'debt,  'operating leases,  'capital lease obligations,  'purchase obligations,  'other post retirement benefits,  'income tax contingencies,  'payments due,  'years
# Time: 14.52 seconds
#
#
#
# 	193 - Key: d61673dee
# Cash Obligations and Accreted Value. This table shows the total cash obligations and the accreted value of 3.00% and 7.125% notes from 2008 to 2011, as well as the balance as of December 31, 2006. cash obligations,  'accreted value,  '3.00% notes,  '7.125% notes,  '2008,  '2009,  '2010,  '2011,  'December 31 2006
# Time: 14.96 seconds
#
#
#
# 	194 - Key: d61659156
# Total Future Minimum Lease Payments. This table shows the total future minimum lease payments for a given asset. The payments decrease from 2015 to 2018, then increase significantly thereafter. The total future minimum lease payments amount to $57,096. lease payments,  'total future,  'minimum,  'asset,  '2014-2018,  'increase,  'decrease
# Time: 11.55 seconds
#
#
#
# 	195 - Key: d6165c626
# Financial Statement. This table shows the financial performance of a company from 2005 to 2007. Key trends include a decrease in net derivative gains, an increase in net unrealized investment gains, a significant increase in net foreign exchange translation, and a consistent decrease in postretirement plans and accumulated other comprehensive loss. net derivative gains,  'net unrealized investment gains,  'net foreign exchange translation,  'postretirement plans,  'accumulated other comprehensive loss
# Time: 12.11 seconds
#
#
#
# 	196 - Key: d6166288c
# Yearly Expenses. This table shows the yearly expenses from 2014 to 2018 and beyond, with a significant increase in expenses starting from 2018. expenses,  'yearly,  '2014,  '2018,  'increase
# Time: 9.57 seconds
#
#
#
# 	197 - Key: d616673dc
# Balance Sheet: Tax Positions. This table shows the balance sheet for tax positions from 2007 to 2008. Key trends include a decrease in the balance at January 1, additions based on tax positions related to the current year, and reductions for tax positions of prior years. balance sheet,  'tax positions,  '2007,  '2008,  'additions,  'reductions,  'pre-acquisition unrecognized tax benefits,  'currency
# Time: 13.15 seconds
#
#
#
# 	198 - Key: d6168e4f0
# Fiscal Year Obligations by Type. This table shows the total contractual obligations, payments due by fiscal year, and breakdown by fiscal years 2007-2010 for operating leases and other obligations. contractual obligations,  'payments due,  'fiscal year,  'operating lease obligations,  'other obligations,  'total obligations
# Time: 9.34 seconds
#
#
#
# 	199 - Key: d616530f8
# Balance and Reductions for Tax Positions from 2007 to 2021. This table shows the balance at the end of each fiscal year from 2007 to 2021, as well as the reductions for tax positions for closing of the applicable statute of limitations for the same period. balance,  'tax positions,  'statute of limitations,  'fiscal year,  'reductions
# Time: 51.3 seconds
#
#
#
# 	200 - Key: d6165b23a
# Stock Price Performance from 2013 to 2017. This table shows the stock price performance of CME Group Inc., S&P 500, Peer Group, and Nasdaq Composite from 2013 to 2017. stock price,  'CME Group Inc.,  'S&P 500,  'Peer Group,  'Nasdaq Composite,  'performance,  '2013,  '2014,  '2015,  '2016,  '2017
# Time: 17.91 seconds
#
#
#
# 	201 - Key: d6168ab98
# Interest Rates and Volatility of Shares. This table shows the range and weighted average of risk-free interest rates and the expected volatility of underlying stock prices for different years. The expected life of the shares is constant at 6 months for all years. interest rates,  'risk-free,  'volatility,  'stock prices,  'years
# Time: 10.61 seconds
#
#
#
# 	202 - Key: d6168b11a
# Company Property and Equipment Costs. This table shows the cost of various types of property and equipment for the company, comparing 2006 and 2005. company,  'property,  'equipment,  'cost,  '2006,  '2005
# Time: 9.63 seconds
#
#
#
# 	203 - Key: d61658864
# Revenue Growth Over Time. This table shows the revenue of five companies over the years 2008 to 2011. The revenue growth is significant for all companies, with the exception of Company 2, which saw a decline in 2011 compared to 2010. revenue,  'growth,  'companies,  'time,  '2008,  '2009,  '2010,  '2011
# Time: 21.11 seconds
#
#
#
# 	204 - Key: d616536fc
# Nuclear Power Revenue and Volume Changes (2011-2015). This table shows the net revenue and changes in nuclear realized price and volume for the years 2011 to 2015. The table indicates a consistent downward trend in nuclear realized price changes and volume, while other revenue remains relatively stable. net revenue,  'nuclear realized price changes,  'nuclear volume,  'other,  '2011,  '2012,  '2013,  '2014,  '2015
# Time: 27.84 seconds
#
#
#
# 	205 - Key: d6166c67a
# Stock Price Indexes from 2012 to 2017. This table shows the stock price indexes for Arconic Inc., S&P 500 AE Index, and S&P 500 AE Materials Index from 2012 to 2017. Arconic Inc.,  'S&P 500 AE Index,  'S&P 500 AE Materials Index,  'stock price,  'index,  '2012,  '2013,  '2014,  '2015,  '2016,  '2017
# Time: 15.96 seconds
#
#
#
# 	206 - Key: d6167900a
# Financial Performance of Snap-On Incorporated from 2002 to 2020. This table shows the stock prices of Snap-On Incorporated, its peer group, and the S&P 500 from 2002 to 2020. The stock prices have generally increased over the years, with a significant growth from 2014 to 2020. Snap-On Incorporated,  'stock price,  'S&P 500,  'peer group,  'financial performance,  'trends
# Time: 50.83 seconds
#
#
#
# 	207 - Key: d61658738
# Outstanding Debt and Payments by Maturity. This table shows the total outstanding debt and payments due by maturity for notes payable, long-term debt, capital lease obligations, operating leases, and interest. Key trends include a high total debt of $9379 million, with the majority due in more than 5 years ($4968 million). debt,  'outstanding,  'payments,  'maturity,  'notes payable,  'long-term debt,  'capital lease obligations,  'operating leases,  'interest
# Time: 13.5 seconds
#
#
#
# 	208 - Key: d61651bfe
# Stock Price Trends (2015-2016). This table shows the high and low stock prices for each quarter from 2015 to 2016. The stock prices have generally increased from 2015 to 2016, with the highest high price in 2016 being $118.09 and the lowest low price being $83.07. stock price,  'trends,  '2015,  '2016,  'high,  'low,  'quarter
# Time: 14.33 seconds
#
#
#
# 	209 - Key: d61657cac
# Share Purchase Data. This table provides data on the total number of shares purchased and the average price paid per share for a specific period. No data is available for the maximum number of shares that may yet be purchased under the plans or programs. share,  'purchase,  'total,  'number,  'average,  'price,  'period
# Time: 9.72 seconds
#
#
#
# 	210 - Key: d61651906
# Mortgage Balances. This table shows the total commercial and residential mortgage balances at fair value and lower of cost or market for the years 2011 and 2012. mortgages,  'commercial,  'residential,  'fair value,  'lower of cost or market,  'balance,  '2011,  '2012
# Time: 11.08 seconds
#
#
#
# 	211 - Key: d6167197c
# Accrued Liabilities by Category (Millions). This table shows the accrued liabilities for various categories in millions for the years 2012 and 2013. Key trends include a decrease in income taxes, accrued warranty, and accrued selling and promotion expense, while other categories have seen an increase. accrued liabilities,  'income taxes,  'warranty,  'selling and promotion expense,  'other
# Time: 11.4 seconds
#
#
#
# 	212 - Key: d6168710a
# Balance Sheet for Tax Positions. This table shows the balance sheet for tax positions from 2014 to 2016. Key trends include a decrease in the balance at January 1, additions based on tax positions related to the current year, and a reduction as a result of the lapse of statute of limitations and effective settlements. balance sheet,  'tax positions,  '2014,  '2015,  '2016,  'additions,  'foreign currency,  'reduction,  'statute of limitations,  'settlements
# Time: 14.67 seconds
#
#
#
# 	213 - Key: d61679c4e
# Restricted Stock Units Vesting Schedule. This table shows the vesting schedule for restricted stock units, with a fixed grant of 8000 units vesting annually from January 25, 2011 to January 25, 2022. vesting,  'schedule,  'restricted stock units,  'grant,  'annually,  'January,  '2011,  '2022
# Time: 22.99 seconds
#
#
#
# 	214 - Key: d6165996c
# Balance Sheet for December 2014 and 2013. This table shows the balance sheet of a company for the years 2013 and 2014. Key trends include a decrease in global core liquid assets, a decrease in secured client financing, and an increase in total assets. balance sheet,  '2013,  '2014,  'global core liquid assets,  'cash,  'secured client financing,  'inventory,  'secured financing agreements,  'receivables,  'institutional client services,  'public equity,  'private equity,  'debt,  'loans receivable,  'investing & lending,  'total inventory and related assets,  'other assets,  'total assets
# Time: 17.62 seconds
#
#
#
# 	215 - Key: d61670f9a
# Derivative Liabilities and Collateral. This table shows the changes in net derivative liabilities under bilateral agreements, collateral posted, and additional collateral or termination payments for one- and two-notch downgrades from December 2012 to December 2013. derivative liabilities,  'bilateral agreements,  'collateral,  'termination payments,  'downgrade,  '2012,  '2013
# Time: 10.31 seconds
#
#
#
# 	216 - Key: d6166500a
# Global Economic Growth by Region (2012-2019). This table shows the annual economic growth rates for North America, Europe, and Asia/Pacific from 2012 to 2019. The growth rates for North America and Europe are relatively stable, while Asia/Pacific shows a slight increase over the years. economic growth,  'North America,  'Europe,  'Asia/Pacific,  'annual,  '2012-2019
# Time: 25.22 seconds
#
#
#
# 	217 - Key: d616509c0
# Financial Statement. This table shows the financial position of the company from 2012 to 2016. Key trends include an increase in total assets, total stockholders equity, and cash and cash equivalents, while total debt has also risen. financial,  'statement,  'assets,  'debt,  'equity,  'cash,  'inventories
# Time: 11.54 seconds
#
#
#
# 	218 - Key: d61651488
# Electric Company Revenue and Costs. This table shows the net revenue, volume/weather, retail electric price, and other costs for the years 2016, 2017, and 2018. The net revenue decreased slightly from 2016 to 2018, while the volume/weather and retail electric price remained constant. The other costs increased slightly from 2016 to 2018. net revenue,  'volume/weather,  'retail electric price,  'other costs,  '2016,  '2017,  '2018
# Time: 21.7 seconds
#
#
#
# 	219 - Key: d6167c0d4
# Stock Prices and Indices from 2000 to 2003. This table shows the stock prices of Illumina Inc., the NASDAQ Composite Index, and the S&P 500 Index from July 27, 2000, to December 26, 2003. stock prices,  'Illumina Inc.,  'NASDAQ Composite Index,  'S&P 500 Index,  '2000,  '2001,  '2002,  '2003
# Time: 17.54 seconds
#
#
#
# 	220 - Key: d616668f6
# Pension and Retiree Medical and Other Expenses. The table shows the pension and retiree medical and other expenses from 2011 to 2016. The pension expenses have been steadily increasing from 574 in 2011 to 785 in 2015. The retiree medical and other expenses have remained relatively stable, ranging from 169 to 173 from 2011 to 2015. There is also a row that shows the total expenses from 2014 to 2020. pension,  'retiree medical,  'expenses,  'trends,  'total expenses
# Time: 14.75 seconds
#
#
#
# 	221 - Key: d6166587a
# Balance Sheet Over Time. This table shows the balance of an account from December 28, 2007 to December 31, 2020. The balance increases over time, with the exception of December 28, which represents the balance at the end of the previous year. balance,  'time,  'increase,  'account
# Time: 49.05 seconds
#
#
#
# 	222 - Key: d6165b74e
# Risk Exposure by Type (Millions of Dollars). The table shows the risk exposure by type for the years 2016, 2017, and 2018. The most significant change occurred in foreign exchange risks, which increased from $1.7 billion in 2016 to $2.4 billion in 2017. The total risk exposure decreased from $7.9 billion in 2016 to $9.1 billion in 2017. risk exposure,  'interest rate risks,  'foreign exchange risks,  'equity risks,  'commodity and other risks,  'credit products and risks,  'millions of dollars,  '2016,  '2017,  '2018
# Time: 16.81 seconds
#
#
#
# 	223 - Key: d616803d2
# Revenue Recognition for Fiscal Year 2019. The table shows the balance sheet for the fiscal year ended June 30, 2019, with a focus on revenue recognition. The deferral of revenue is $3008 million, and the recognition of deferred revenue results in a decrease of $3084 million. The balance as of July 1, 2018, is $510 million, and the balance as of June 30, 2019, is $428 million. revenue,  'deferral,  'recognition,  'balance,  'fiscal year,  '2019
# Time: 14.67 seconds
#
#
#
# 	224 - Key: d6166fc08
# Average Total Assets for the Years Ended December 2013 and 2012. The table shows the average total assets for U.S. dollar-denominated and non-U.S. dollar-denominated assets for the years ended December 2013 and 2012. The total assets increased from $172,095 million in 2012 to $182,650 million in 2013. assets,  'U.S. dollar-denominated,  'non-U.S. dollar-denominated,  'average,  'total,  '2012,  '2013
# Time: 14.96 seconds
#
#
#
# 	225 - Key: d61653d14
# Cash Flow Statement. This table shows the net cash provided by operating activities, additions to properties, and cash flow for the years 2004 to 2006. The table indicates an increase in net cash provided by operating activities and cash flow from 2004 to 2006, while additions to properties have decreased. cash flow,  'net cash provided by operating activities,  'additions to properties,  'year-over-year change
# Time: 11.9 seconds
#
#
#
# 	226 - Key: d6165ec6e
# Bank Capital and Risk-Weighted Assets. This table shows the changes in tier 1 and tier 2 capital, total capital, risk-weighted assets, tier 1 capital ratio, total capital ratio, and tier 1 leverage ratio for a bank from December 2011 to December 2012. capital,  'risk-weighted assets,  'tier 1,  'tier 2,  'total,  'ratio,  'leverage,  'bank
# Time: 13.23 seconds
#
#
#
# 	227 - Key: d6165cc84
# Yearly Revenue. This table shows the yearly revenue of a company from 2015 to 2019, with a significant drop in revenue after 2019. revenue,  'yearly,  'company,  'trend,  'drop
# Time: 8.4 seconds
#
#
#
# 	228 - Key: d6165fb0a
# Stock Performance from 2007 to 2012. This table shows the stock performance of Abiomed Inc, the NASDAQ Composite Index, and the NASDAQ Medical Equipment SIC Code 3840-3849 from 2007 to 2012. stock,  'performance,  'Abiomed Inc,  'NASDAQ Composite Index,  'NASDAQ Medical Equipment,  'SIC Code 3840-3849
# Time: 13.38 seconds
#
#
#
# 	229 - Key: d6168ba0c
# Yearly Revenue Growth. This table shows the yearly revenue growth from 2015 to 2020 and thereafter. The revenue has been increasing since 2016, with a significant jump in 2020 and thereafter. revenue,  'growth,  'yearly,  '2015,  '2016,  '2017,  '2018,  '2019,  '2020,  'increase,  'significant jump
# Time: 12.86 seconds
#
#
#
# 	230 - Key: d6165c4fa
# Net Derivative Losses by Strategy. This table shows the net derivative losses for various strategies from 2002 to 2003. The most significant losses were incurred by mitigating price risk and protecting crack spread values. On the other hand, trading activities and protecting margin on fixed price sales showed a positive trend. Protecting carrying values of excess inventories and protecting the carrying values of excess inventories also showed a negative trend. net derivative losses,  'mitigate price risk,  'protect carrying values,  'protect margin on fixed price sales,  'trading activities,  'crack spread values,  '2002,  '2003
# Time: 14.63 seconds
#
#
#
# 	231 - Key: d6165b10e
# Assets Pledged by Year. This table shows the total assets pledged by the company for the years 2009 and 2010. Key trends include a decrease in total assets pledged from $525.4 billion in 2009 to $450.1 billion in 2010. assets,  'pledged,  'year,  '2009,  '2010,  'decrease,  'totalassetspledged
# Time: 12.38 seconds
#
#
#
# 	232 - Key: d616868fe
# Net Tangible Assets Acquired as of July 13, 2006. This table shows the net tangible assets acquired as of July 13, 2006, categorized by various assets such as in-process research and development, developed technology and know-how, customer relationship, trade name, order backlog, deferred income taxes, and goodwill. The total net tangible assets acquired is $220,600. net tangible assets,  'July 13,  2006,  'in-process research and development,  'developed technology and know-how,  'customer relationship,  'trade name,  'order backlog,  'deferred income taxes,  'goodwill,  'final purchase price
# Time: 17.15 seconds
#
#
#
# 	233 - Key: d6166bb62
# Real Estate Usage by Business Type. This table shows the approximate number and size in square feet of various business types. The largest business type is offices, followed by switching centers, data centers, warehouses, and call centers. business type,  'real estate,  'usage,  'approximately,  'number,  'size,  'square feet,  'switching centers,  'data centers,  'call center,  'warehouses,  'offices
# Time: 11.32 seconds
#
#
#
# 	234 - Key: d6165d8fa
# Quarterly Financial Summary. The table shows the financial summary for the company, with key trends being a decrease in total assets from $47 million in January 2012 to $43 million in December 2012, and a decrease in losses related to 2013 loan repurchases and settlements from $8 million in 2011 to $8 million in 2012. financial summary,  'total assets,  'losses,  '2012,  '2011,  'loan repurchases,  'settlements
# Time: 13.08 seconds
#
#
#
# 	235 - Key: d6165fd12
# Tax Positions Balance. This table shows the balance of tax positions from January 1, 2007 to December 31, 2007. Key trends include additions based on tax positions related to the current year (4), additions for tax positions of prior years (24), reductions for tax positions of prior years (-6), and settlements (-5). tax positions,  'balance,  'additions,  'reductions,  'settlements,  'current year,  'prior years
# Time: 13.01 seconds
#
#
#
# 	236 - Key: d616662b6
# Senior Secured Transition Bonds Series A. Table displays the amounts (in thousands) for various tranches of senior secured transition bonds series A, with their respective coupon rates and maturity dates. senior secured transition bonds,  'series A,  'tranches,  'amounts,  'coupon rates,  'maturity dates
# Time: 14.83 seconds
#
#
#
# 	237 - Key: d6166ba4a
# Stock Issuance and Repurchase. This table shows the issuance and repurchase of stocks over a period from January 1, 2010 to December 31, 2012. Key trends include the issuance of stocks for acquisitions, employee stock purchase plans, and conversions of debentures. Repurchases were made through a stock repurchase program. stock,  'issuance,  'repurchase,  'acquisition,  'debentures,  'employee stock purchase plan,  'optionees,  'treasury,  'shares outstanding
# Time: 22.11 seconds
#
#
#
# 	238 - Key: d6168493c
# Energy Prices Over Time. This table shows the prices of WTI crude oil, Brent crude oil, and Henry Hub natural gas (both versions A and B) from 2011 to 2013. Key trends include a general increase in oil prices and fluctuating natural gas prices. energy,  'prices,  'oil,  'gas,  'WTI,  'Brent,  'Henry Hub,  '2011,  '2012,  '2013
# Time: 14.94 seconds
#
#
#
# 	239 - Key: d616a1e56
# Stock Performance from 2009 to 2014. This table shows the stock performance of State Street Corporation, S&P 500 Index, and S&P Financial Index from 2009 to 2014. stock,  'performance,  'State Street Corporation,  'S&P 500 Index,  'S&P Financial Index,  '2009,  '2010,  '2011,  '2012,  '2013,  '2014
# Time: 13.76 seconds
#
#
#
# 	240 - Key: d61667a3a
# Trading Assets and Liabilities Over Three Years. This table shows the trading assets and liabilities for the years 2007, 2008, and 2009. Key trends include a decrease in trading assets 2013 debt and equity instruments and trading assets 2013 derivative receivables, while trading liabilities 2013 debt and equity instruments (a) and trading liabilities 2013 derivative payables have increased. trading assets,  '2007,  '2008,  '2009,  'debt and equity instruments,  'derivative receivables,  'trading liabilities,  'debt and equityinstruments (a),  'derivative payables
# Time: 16.19 seconds
#
#
#
# 	241 - Key: d6167fbbc
# Cash Flow Statement. The table shows the cash flow statement for a company, with a decrease in operating activities from 2015 to 2016, a significant decrease in investing activities from 2015 to 2017, and an increase in financing activities from 2015 to 2016. cash flow,  'operating activities,  'investing activities,  'financing activities,  'millions,  'decrease,  'increase
# Time: 11.7 seconds
#
#
#
# 	242 - Key: d6166ade8
# Weighted Average Useful Life of Intangible Assets. This table shows the weighted average useful life of various intangible assets in years. The assets include purchased technology, localization, trademarks, customer contracts and relationships, and other intangibles. The shortest useful life is for localization (1 year), while the longest is for purchased technology (4 years). intangible assets,  'useful life,  'purchased technology,  'localization,  'trademarks,  'customer contracts,  'relationships,  'other intangibles
# Time: 12.74 seconds
#
#
#
# 	243 - Key: d61659f02
# Accrued Balances for Restructurings. This table shows the accrued balances for previous and current restructurings, total charges, cash payments, adjustments, and the final accrued balance at two different dates. accrued balance,  'restructurings,  'total charges,  'cash payments,  'adjustments
# Time: 12.99 seconds
#
#
#
# 	244 - Key: d6166579e
# Annual Net Revenue and Associated Costs. This table shows the annual net revenue and associated costs for a company from 2014 to 2016. Key trends include steady net revenue growth and consistent costs for certain items such as retail electric price, volume/weather, Louisiana business combination customer credits, MISO deferral, Waterford 3 replacement steam generator provision, and other costs. net revenue,  'annual,  '2014,  '2015,  '2016,  'revenue growth,  'retail electric price,  'volume/weather,  'Louisiana business combination customer credits,  'MISO deferral,  'Waterford 3 replacement steam generator provision,  'other costs
# Time: 30.2 seconds
#
#
#
# 	245 - Key: d61679f8c
# Debt Obligations of the Company. The table shows the debt obligations of the company for the years 2009 and 2010. The table includes various types of debt such as commercial mortgage pass-through certificates, revolving credit facilities, term loans, and notes. The total debt obligations decreased from $5,587,388 in 2010 to $4,211,581 in 2009. The long-term obligations also decreased from $5,512,492 in 2010 to $4,141,060 in 2009. debt,  'obligations,  'commercial mortgage,  'revolving credit,  'term loan,  'xcel credit,  'colombian short-term credit,  'senior notes,  'convertible notes,  'senior subordinated notes,  'notes payable,  'capital leases,  'total,  'current portion,  'long-term obligations,  '2009,  '2010
# Time: 24.46 seconds
#
#
#
# 	246 - Key: d61653f9e
# Currency Exchange Rates and Total Increase/Decrease. This table shows the exchange rates of four currencies (pound sterling, euro, real, and Indian rupee) from 2015 to 2017. The total increase or decrease in the exchange rate is also provided. The pound sterling had the highest increase in value, while the Indian rupee had the lowest increase. currency,  'exchange rate,  'pound sterling,  'euro,  'real,  'Indian rupee,  '2015,  '2016,  '2017,  'total increase or decrease
# Time: 15.06 seconds
#
#
#
# 	247 - Key: d6165f254
# Financial Assets Balance Sheet. The table shows the balance sheet of financial assets for a company as of December 2016 and December 2017. The total financial assets decreased from $23,280 million in 2016 to $19,201 million in 2017. The decrease is mainly due to a drop in cash instruments and derivatives. financial assets,  'cash instruments,  'derivatives,  'balance sheet,  'decrease,  '2016,  '2017
# Time: 12.92 seconds

# %%
dataset = "FinQA"
table_dict = np.load(f'table_summaries_{dataset}_short.npy', allow_pickle='TRUE').item()
print(len(table_dict))
# Out:
# 247

# %% [markdown]
# ------------------------------------------------------------------------------------------------------------------

# %%
# create_summaries("MultiHeritt", template_short, "short", max_new_tokens=2000)
# Out:
# CREATING SUMMARIES FOR MultiHeritt, with template:
# You are a finance expert who specializes in analyzing tables.
#
# ### Task ###
# Summarize the table in a dictionary with the following keys:
# - 'title': A concise title for the table.
# - 'description': A brief description of the table's contents and key trends.
# - 'keywords': A list of relevant keywords.
#
# **Note**: Do not return the table, prompt, or any extra text. Return only the dictionary.
#
# ### Table ###
#
#
#
# Timing_MultiHeritt_short.npy already created!	 It contains:  1  summary tables
#
# Loaded extracted_tables_MultiHeritt, it has 876 tables to process
#
#
#
# 	1 - Key: d8327a646
# Total Contractual Obligations by Time Horizon. This table shows the total contractual obligations for various financial items, categorized by time horizon. The table highlights the significant long-term debt and purchase obligations not recorded on the Consolidated Statements of Financial Position. debt,  'obligations,  'purchase,  'contractual,  'time horizon,  'financial position
# Time: 14.25 seconds
#
#
#
# 	2 - Key: d80ee2864
# 		Skipping d80ee2864, no table found ...
#
# 	3 - Key: d842dcf7a
# Lease Payments Over Time. This table shows the total minimum lease payments, operating leases, and capital leases for a company from 2007 to later years. Key trends include a decrease in total minimum lease payments and an increase in the present value of lease payments excluding interest. lease payments,  'minimum lease payments,  'operating leases,  'capital leases,  '2007,  '2008,  '2009,  '2010,  '2011,  'later years,  'present value,  'interest
# Time: 16.42 seconds
#
#
#
# 	4 - Key: d82441b60
# 		Skipping d82441b60, no table found ...
#
# 	5 - Key: d82d2c6a8
# Revenue and Income Analysis. This table shows the total revenues, operating income, and net income for a company over two years. The revenues increased by 8%, while operating income and net income saw significant increases of 461% and 363% respectively. revenues,  'income,  'operating,  'net,  'increase,  'percentage,  'analysis
# Time: 14.39 seconds
#
#
#
# 	6 - Key: d81a04f30
# Net Sales by Product Category. The table shows the net sales for four product categories (Tools, Diagnostics and repair information, Equipment) from 2010 to 2012. The total net sales increased from $2,619.2 million in 2010 to $2,937.9 million in 2012. Net Sales,  'Product Category,  'Tools,  'Diagnostics and repair information,  'Equipment,  'Increase,  '2010,  '2011,  '2012
# Time: 16.72 seconds
#
#
#
# 	7 - Key: d819229aa
# 		Skipping d819229aa, no table found ...
#
# 	8 - Key: d812de4cc
# 		Skipping d812de4cc, no table found ...
#
# 	9 - Key: d815b510a
# Financial Performance of Real Estate Company. This table shows the financial performance of a real estate company from 2003 to 2007. Key trends include an increase in rental income, net income, and funds from operations, as well as a decrease in loss before minority interests and discontinued operations. real estate,  'financial performance,  'rental income,  'net income,  'funds from operations,  'loss,  'minority interests,  'discontinued operations
# Time: 47.0 seconds
#
#
#
# 	10 - Key: d81128272
# 		Skipping d81128272, no table found ...
#
# 	11 - Key: d8199c930
# 		Skipping d8199c930, no table found ...
#
# 	12 - Key: d80ee27b0
# Financial Performance of a Company (2008-2009). The table shows the financial performance of a company for the years ended December 31, 2008 and 2009. Total revenues increased by 2%, while net loss decreased by 71%. revenues,  'expenses,  'net loss,  'change,  '2008,  '2009
# Time: 26.45 seconds
#
#
#
# 	13 - Key: d81818a3c
# Financial Statements for the Year Ended December 31, 2009. This table presents the financial statements for the year ended December 31, 2009. Key trends include a decrease in total operating revenues (-9.5%), a decrease in total operating expenses (-11.4%), and an increase in consolidated investment products-2 (7.9%). The overall net income attributable to common shareholders is $322.5 million. revenues,  'expenses,  'income,  'net income,  'common shareholders,  'consolidated entities,  'investment products
# Time: 23.74 seconds
#
#
#
# 	14 - Key: d812ed486
# 		Skipping d812ed486, no table found ...
#
# 	15 - Key: d811283ee
# 		Skipping d811283ee, no table found ...
#
# 	16 - Key: d8203ffd0
# Conversion of Preferred Shares. This table shows the conversion of preferred shares for the years 2010 to 2012. The number of shares outstanding remains constant at 221,474. The conversion rate per share, conversion price, and conversion shares vary slightly each year. shares,  'conversion,  'preferred,  'outstanding,  '2010,  '2011,  '2012
# Time: 17.38 seconds
#
#
#
# 	17 - Key: d82267b64
# Revenue and Expense Analysis for 2011 and 2012. This table shows the revenues and expenses for a company for the years 2011 and 2012. Key trends include an increase in net income, a decrease in net income as a percentage of revenues, and an increase in expenses as a percentage of revenues. revenues,  'expenses,  'net income,  '2011,  '2012,  'increase,  'decrease,  'percentage
# Time: 22.58 seconds
#
#
#
# 	18 - Key: d842dce6c
# Quarterly Credit Commitments. This table shows the total amount of various types of credit commitments for the years 2009 and 2010. Key trends include a decrease in Standby Letters of Credit-1, an increase in Open End Consumer Lines of Credit, and a significant increase in Commercial Lines of Credit. credit commitments,  '2009,  '2010,  'Standby Letters of Credit-1,  'Open End Consumer Lines of Credit,  'Commercial Lines of Credit,  'Undeferred Loan Commitments - Variable Rate-1,  'Undeferred Loan Commitments – Fixed Rate
# Time: 17.84 seconds
#
#
#
# 	19 - Key: d8327a81c
# 		Skipping d8327a81c, no table found ...
#
# 	20 - Key: d81cc5a1c
# 		Skipping d81cc5a1c, no table found ...
#
# 	21 - Key: d81decb70
# Outstanding Stock Options. This table shows the number of shares and weighted average exercise price for stock options outstanding, exercised, forfeited, and expired from 2011 to 2020. Key trends include a decrease in the number of shares outstanding and a decrease in the weighted average exercise price over the years. stock options,  'shares,  'weighted average exercise price,  'outstanding,  'exercised,  'forfeited,  'expired,  'trends
# Time: 69.75 seconds
#
#
#
# 	22 - Key: d8292c544
# 		Skipping d8292c544, no table found ...
#
# 	23 - Key: d8196f3f4
# Net Reserves by Year. This table shows the net reserves for the company and ceding companies in millions of dollars for the years 2004 to 2006. net reserves,  '2004,  '2005,  '2006,  'ceding companies,  'direct insurance,  'assumed reinsurance,  'incurred but not reported reserves,  'gross reserves,  'reinsurance receivable
# Time: 12.66 seconds
#
#
#
# 	24 - Key: d8373b14e
# Energy Contracts. A table showing energy contracts with their inception, commencement, termination dates, notional amounts, and contract prices. energy,  'contracts,  'notional amount,  'contract price,  'inception date,  'commencement date,  'termination date
# Time: 15.41 seconds
#
#
#
# 	25 - Key: d827068f0
# Net Charge-offs and Allowance for Loan and Lease Losses. This table shows net charge-offs and allowance for loan and lease losses for both commercial and consumer lending for the years 2011 and 2012. net charge-offs,  'allowance for loan and lease losses,  'commercial lending,  'consumer lending,  '2011,  '2012
# Time: 14.25 seconds
#
#
#
# 	26 - Key: d829ed99c
# Cash Flow Statement for 2004 and 2005. This table presents the cash flow statement for the years 2004 and 2005, broken down into operating, investing, financing activities, and the effect of exchange rate changes on cash and cash equivalents. cash flow statement,  '2004,  '2005,  'net income,  'operating activities,  'investing activities,  'financing activities,  'exchange rate changes
# Time: 21.75 seconds
#
#
#
# 	27 - Key: d81e4fb4e
# Notional Amounts and Derivative Receivables MTM by Asset Class as of December 31. This table shows the notional amounts and derivative receivables marked-to-market (MTM) for various asset classes as of December 31 for the years 2004 and 2005. Key trends include an increase in total notional amounts from $40.514 billion in 2004 to $43.593 billion in 2005, and a decrease in exposure net of collateral from $57 billion in 2004 to $44 billion in 2005. Notional amounts,  'Derivative receivables MTM,  'Interest rate,  'Foreign exchange,  'Equity,  'Credit derivatives,  'Commodity,  'Total,  'Collateral,  'Exposure
# Time: 20.12 seconds
#
#
#
# 	28 - Key: d8247dfb6
# 		Skipping d8247dfb6, no table found ...
#
# 	29 - Key: d8373b22a
# U.S. Tax Collections by Level of Government (2010-2012). This table shows the total tax collections for the federal, state, and combined levels of government from 2010 to 2012. Key trends include a decrease in federal tax collections from 2010 to 2011, followed by an increase in 2012. State tax collections decreased from 2010 to 2011, but increased in 2012. Combined federal and state tax collections decreased from 2010 to 2011, but increased in 2012. tax collections,  'federal,  'state,  '2010,  '2011,  '2012,  'increase,  'decrease
# Time: 20.98 seconds
#
#
#
# 	30 - Key: d82e4efe0
# 		Skipping d82e4efe0, no table found ...
#
# 	31 - Key: d80f34cfe
# U.S. Government Revenue by Level and Location (2006-2008). This table shows the revenue of the U.S. government from federal, state and local, and foreign sources for the years 2006 to 2008. Key trends include a decrease in state and local revenue and an increase in federal revenue from 2006 to 2008. revenue,  'U.S. government,  'federal,  'state and local,  'foreign,  '2006,  '2007,  '2008
# Time: 17.02 seconds
#
#
#
# 	32 - Key: d82787ad6
# Balance Sheet of Investments. This table shows the balance sheet of investments for a financial institution as of December 31, 2018 and 2017. The table includes short-term investments and cash equivalents, fixed maturities, and equity securities. Key trends include an increase in total assets supporting experience-rated contractholder liabilities from 2017 to 2018. investments,  'balance sheet,  'short-term investments,  'cash equivalents,  'fixed maturities,  'corporate securities,  'commercial mortgage-backed securities,  'residential mortgage-backed securities,  'asset-backed securities,  'foreign government bonds,  'U.S. government authorities and agencies,  'obligations of U.S. states,  'equity securities,  'total assets,  'experience-rated contractholder liabilities
# Time: 21.59 seconds
#
#
#
# 	33 - Key: d8327a68c
# Pension and Other Postretirement Benefits. This table shows the recognized net actuarial loss/gain, amortization of prior service credits, and total for pension and other postretirement benefits. pension,  'actuarial loss/gain,  'amortization,  'postretirement benefits,  'credits,  'total
# Time: 9.24 seconds
#
#
#
# 	34 - Key: d8202fb30
# Company Financial Performance. This table shows the financial performance of the company from 2010 to 2012. Net sales have increased significantly from 2010 to 2012, while gross margin percentage has also increased but at a slower rate. Operating expenses have also increased, but operating income and net income have also increased. net sales,  'cost of sales,  'gross margin,  'gross margin percentage,  'operating expenses,  'operating income,  'net income
# Time: 19.97 seconds
#
#
#
# 	35 - Key: d810cc5e4
# 		Skipping d810cc5e4, no table found ...
#
# 	36 - Key: d830e4f70
# 		Skipping d830e4f70, no table found ...
#
# 	37 - Key: d83ac8726
# Plan Assets by Fair Value Hierarchy Level. This table shows the total plan assets for various investment types, categorized by their level in the fair value hierarchy. Key trends include a decrease in Level 3 assets and an increase in Other investments measured at net asset value. plan assets,  'fair value hierarchy,  'Level 1,  'Level 2,  'Level 3,  'Registered investment companies,  'Limited partnerships,  'Fixed income securities,  'Insurance contracts,  'Other,  'net asset value
# Time: 15.3 seconds
#
#
#
# 	38 - Key: d84dc5f18
# Oil and Gas Company Revenue by Region and Division. This table shows the revenue of an oil and gas company for the years 2002 to 2004, broken down by region (Domestic and International) and division (Exploration and Production (E&P), Refining, Marketing and Transportation (RM&T), and Integrated Gas (IG)). The total revenue for each year is also provided. oil,  'gas,  'revenue,  'exploration,  'production,  'domestic,  'international,  'refining,  'marketing,  'transportation,  'integrated gas
# Time: 14.84 seconds
#
#
#
# 	39 - Key: d8156667c
# Balance Sheet. This table shows the balance sheet of a company, with key assets and liabilities. Notable assets include cash, accounts receivable, amortizable intangibles, goodwill, deferred tax assets, other assets, and investment in TradeHelm. Liabilities include accounts payable, accrued expenses, deferred revenue, and total liabilities. The total assets, total liabilities, and total equity are also provided. Balance Sheet,  'Cash,  'Accounts Receivable,  'Amortizable Intangibles,  'Goodwill,  'Deferred Tax Assets,  'Accounts Payable,  'Accrued Expenses,  'Deferred Revenue,  'Total Purchase Price,  'Total Liabilities,  'Total Assets,  'Total Equity
# Time: 20.29 seconds
#
#
#
# 	40 - Key: d811dc146
# Unsecured Borrowings and Liabilities. This table shows the unsecured short-term and long-term borrowings, as well as other liabilities and accrued expenses for the years 2014, 2015, and 2016. unsecured borrowings,  'liabilities,  'accrued expenses,  '2014,  '2015,  '2016
# Time: 11.72 seconds
#
#
#
# 	41 - Key: d824b7ec8
# Energy Generation by Location, Fuel Type, and Contract Status. This table provides information on energy generation by location, fuel type, ownership interest, gross capacity, and the percentage of gross capacity under long-term contracts. Key trends include the dominance of natural gas in Michigan, the absence of long-term contracts for wood-fired power plants in Michigan, and the lack of long-term contracts for any power plants in North Carolina. energy,  'generation,  'location,  'fuel type,  'ownership,  'interest,  'gross capacity,  'long-term contract,  'California,  'Connecticut,  'Michigan,  'North Carolina
# Time: 15.93 seconds
#
#
#
# 	42 - Key: d81143a0e
# 		Skipping d81143a0e, no table found ...
#
# 	43 - Key: d83b5a1d0
# Financial Statement Summary. This table provides a summary of the financial statements for the years ended September 30, 2009, 2008, and 2007. Key trends include an increase in total share-based compensation expense, total assets, total liabilities, and total revenue, while net income saw a fluctuation. financial statement,  'share-based compensation expense,  'total assets,  'total liabilities,  'total revenue,  'net income
# Time: 25.61 seconds
#
#
#
# 	44 - Key: d83dd4b18
# 		Skipping d83dd4b18, no table found ...
#
# 	45 - Key: d81f401c0
# 		Skipping d81f401c0, no table found ...
#
# 	46 - Key: d838f1e52
# Derivative Assets by Type and Year. This table shows the derivative assets for various types (interest rate contracts, futures and forwards, written options, purchased options, foreign exchange contracts, equity contracts, commodity contracts, and credit derivatives) for the years 2004 and 2005. Key trends include an increase in total derivative assets from $23,712 million in 2004 to $30,235 million in 2005. derivative assets,  'interest rate contracts,  'futures and forwards,  'written options,  'purchased options,  'foreign exchange contracts,  'equity contracts,  'commodity contracts,  'credit derivatives,  '2004,  '2005,  'millions
# Time: 22.61 seconds
#
#
#
# 	47 - Key: d82074226
# 		Skipping d82074226, no table found ...
#
# 	48 - Key: d824419da
# 		Skipping d824419da, no table found ...
#
# 	49 - Key: d8202fac2
# 		Skipping d8202fac2, no table found ...
#
# 	50 - Key: d857773cc
# 		Skipping d857773cc, no table found ...
#
# 	51 - Key: d815b556a
# Capital Expenditures and Operating Expenses. This table shows the total capital expenditures, recurring capital expenditures, repair and maintenance expense, and net operating income for the years 2006 and 2007. Key trends include a decrease in total capital expenditures, net operating income, and revenue enhancing improvements, while asset preservation expenditures and major renovations saw significant increases. capital expenditures,  'recurring capital expenditures,  'repair and maintenance expense,  'net operating income,  '2006,  '2007,  'decrease,  'increase
# Time: 35.41 seconds
#
#
#
# 	52 - Key: d817f63ce
# 		Skipping d817f63ce, no table found ...
#
# 	53 - Key: d8240078c
# Ameriprise Financial Income Statement. This table shows the income statement for Ameriprise Financial for the years ended December 31, 2011 and 2010. Key trends include a 10% increase in total revenues, a 12% increase in operating income, and a 4% increase in net income attributable to Ameriprise Financial. Ameriprise Financial,  'income statement,  'revenues,  'operating income,  'net income,  '2011,  '2010
# Time: 20.62 seconds
#
#
#
# 	54 - Key: d8259f4bc
# 		Skipping d8259f4bc, no table found ...
#
# 	55 - Key: d8366a422
# Financial Performance Over Three Months in 2008. This table shows the financial performance of a company over three months in 2008, with key trends including a significant increase in income before income taxes and a large discontinued operation in the second quarter. revenues,  'income,  'discontinued operations,  'net income,  'dividends,  'earnings per share
# Time: 12.76 seconds
#
#
#
# 	56 - Key: d825901a6
# Refinery Utilization by Year and Refinery. This table shows the refinery utilization for various refineries in different years. Key trends include a general increase in utilization from 2006 to 2008 for most refineries, with exceptions at Port Reading and Bayway. refinery,  'utilization,  'year,  '2006,  '2007,  '2008,  'HOVENSA,  'Crude,  'Fluid catalytic cracker,  'Coker,  'Port Reading,  'Bayway,  'Delaware City,  'Philadelphia,  'Torrance
# Time: 26.19 seconds
#
#
#
# 	57 - Key: d824fcf78
# Loans and Lending Commitments by Year Ended December. This table shows the changes in loans receivable and lending commitments from December 2017 to December 2018. The table also includes changes in the allowance for credit losses for both years. loans,  'lending commitments,  'credit losses,  'allowance,  'year,  '2017,  '2018
# Time: 23.7 seconds
#
#
#
# 	58 - Key: d85173836
# 		Skipping d85173836, no table found ...
#
# 	59 - Key: d813b8ffa
# Balance Sheet - Liabilities. This table shows the carrying amounts and estimated fair values of various liabilities as of December 31, 2009 and 2008. Key trends include a decrease in total liabilities from 2008 to 2009. liabilities,  'carrying amounts,  'estimated fair value,  '2008,  '2009,  'Marketable Securities,  'Notes Payable,  'Mortgages Payable,  'Construction Payable,  'Mandatorily Redeemable Noncontrolling Interests,  'Long-term Debt,  'Total Current Liabilities,  'Total Noncurrent Liabilities,  'Total Liabilities
# Time: 34.17 seconds
#
#
#
# 	60 - Key: d812184de
# 		Skipping d812184de, no table found ...
#
# 	61 - Key: d8187d63a
# Financial Performance of Company (2012-2013). This table shows the financial performance of the company for the years ended December 31, 2012 and 2013. Key trends include a 5% increase in total revenues, a 10% decrease in operating earnings, and a 12% decrease in net earnings per share. revenues,  'expenses,  'operating earnings,  'net earnings,  'net earnings per share,  '2012,  '2013
# Time: 23.06 seconds
#
#
#
# 	62 - Key: d8151169a
# Property, Plant, and Equipment (PP&E) Balance Sheet. This table shows the balance sheet for Property, Plant, and Equipment (PP&E) for the years 2004 and 2005. The total PP&E value decreased from $2,389 million in 2004 to $2,341 million in 2005. The largest category is Buildings and leasehold improvements, followed by Land, Furniture and equipment, Timeshare properties, and Construction in progress. Property,  Plant,  and Equipment (PP&E),  'balance sheet,  '2004,  '2005,  'Land,  'Buildings and leasehold improvements,  'Furniture and equipment,  'Timeshare properties,  'Construction in progress,  'accumulated depreciation
# Time: 18.78 seconds
#
#
#
# 	63 - Key: d843a7b1c
# 		Skipping d843a7b1c, no table found ...
#
# 	64 - Key: d8186c024
# Stores Opened, Closed, and Total Stores at End of Fiscal Year by Region. This table shows the number of stores opened, closed, and the total number of stores at the end of each fiscal year for Best Buy and its subsidiaries in various regions. Key trends include a decrease in total stores in Fiscal 2010 for Best Buy Europe and an increase in total stores in Fiscal 2011 for the International segment. Best Buy,  'Stores,  'Opened,  'Closed,  'Fiscal Year,  'Total Stores,  'Best Buy Europe,  'Canada,  'Future Shop,  'Best Buy,  'Best Buy Mobile,  'China,  'Five Star,  'Best Buy-3,  'Mexico,  'Best Buy,  'Turkey,  'International segment,  'United States
# Time: 28.69 seconds
#
#
#
# 	65 - Key: d80f34d62
# US Corporate Bond Cost of Funds by Credit Rating. This table shows the cost of funds for US corporate bonds by credit rating from 2003 to 2008. Key trends include a significant increase in cost of funds for all ratings from 2003 to 2005, followed by a decrease in 2006 and 2007. The cost of funds for bonds below investment grade saw the largest increase from 2003 to 2005. US Corporate Bonds,  'Cost of Funds,  'Credit Rating,  'Trends,  'Increase,  'Decrease
# Time: 18.1 seconds
#
#
#
# 	66 - Key: d811fbece
# Stock Price Trends. This table shows the high and low stock prices for a given company for each quarter from 2014 to 2015. stock price,  'trends,  'high,  'low,  'quarter,  '2014,  '2015
# Time: 10.44 seconds
#
#
#
# 	67 - Key: d8193ecc2
# Loews Common Stock Performance vs. S&P 500 Index. This table shows the performance of Loews Common Stock, S&P 500 Index, and a peer group of Loews from 2011 to 2016. The stock prices are indexed to 100 for the year 2011. Loews Common Stock had a lower average growth rate compared to the S&P 500 Index, but outperformed its peer group. Loews Common Stock,  'S&P 500 Index,  'Performance,  'Stock Prices,  'Index,  'Growth Rate,  'Peer Group
# Time: 21.74 seconds
#
#
#
# 	68 - Key: d8259025a
# 		Skipping d8259025a, no table found ...
#
# 	69 - Key: d8157da48
# 		Skipping d8157da48, no table found ...
#
# 	70 - Key: d81bf4174
# Assurant Revenue by Business Unit. Revenue for Assurant Solutions and Assurant Specialty Property for the years 2014 and 2015. Assurant Health and Assurant Employee Benefits do not have data for 2015. Assurant,  'Revenue,  'Business Unit,  '2014,  '2015,  'Assurant Solutions,  'Assurant Specialty Property
# Time: 11.78 seconds
#
#
#
# 	71 - Key: d83ac85aa
# 		Skipping d83ac85aa, no table found ...
#
# 	72 - Key: d82384cae
# Purchase Price Allocation. This table shows the allocation of the purchase price for a set of assets. The largest allocations are to intangible assets and property and equipment. There are also significant negative allocations to goodwill and non-current assets. purchase price,  'allocation,  'assets,  'intangible assets,  'property and equipment,  'non-current assets,  'goodwill,  'liabilities
# Time: 11.85 seconds
#
#
#
# 	73 - Key: d8259020a
# Loans by Banking Type and Product. This table shows the total loans for Commercial Banking, Retail Banking, and Consumer Banking as of December 31 for the years 2009 to 2013. Key trends include a significant increase in Commercial and Industrial loans, a decrease in Commercial real estate loans, and a steady growth in residential mortgage loans. loans,  'commercial banking,  'retail banking,  'consumer banking,  'commercial real estate,  'commercial and industrial,  'equipment financing,  'residential mortgage,  'adjustable-rate,  'fixed-rate,  'home equity,  'other consumer
# Time: 19.44 seconds
#
#
#
# 	74 - Key: d827f3dee
# 		Skipping d827f3dee, no table found ...
#
# 	75 - Key: d827f3c0e
# 		Skipping d827f3c0e, no table found ...
#
# 	76 - Key: d8366a4b8
# 		Skipping d8366a4b8, no table found ...
#
# 	77 - Key: d82aee6fc
# Revenue Breakdown for Investment Banking and Related Services in 2006. This table shows the revenue breakdown for various investment banking and related services for the year ended Dec. 31, 2006. The table includes 26 different services, with columns for the average, high, and low revenue for each service. The table shows that Commodity trading had the lowest average revenue, while Investment banking(c) had the highest average revenue. revenue,  'investment banking,  '2006,  'average,  'high,  'low,  'commodity trading,  'services
# Time: 80.45 seconds
#
#
#
# 	78 - Key: d824b7f9a
# Guarantees and Indemnifications. This table provides details about various guarantees and indemnifications, including indemnifications from asset sales, surety bonds, and put options. The table includes the guarantee description, issue date, expiration date, maximum obligation, FIN 45 carrying amount, and the number of rows for each category. guarantee,  'indemnification,  'asset sales,  'surety bonds,  'put options,  'maximum obligation,  'FIN 45,  'carrying amount
# Time: 18.57 seconds
#
#
#
# 	79 - Key: d8177aaf8
# 		Skipping d8177aaf8, no table found ...
#
# 	80 - Key: d83dd4c44
# Financial Analysis of Employee Benefits. This table shows the financial impact of employee benefits over four years. Key trends include a significant increase in pension expenses from 2015 to 2017, while other employee benefits have remained relatively stable. employee benefits,  'pension,  'deferred compensation,  'share-based plans,  'core operating earnings,  '2015,  '2016,  '2017
# Time: 14.33 seconds
#
#
#
# 	81 - Key: d81decc88
# 		Skipping d81decc88, no table found ...
#
# 	82 - Key: d82400930
# Assets and Liabilities Acquired. This table shows the assets and liabilities acquired by the company. The largest asset is Goodwill at $634,203, while the largest liability is Long-term liabilities at $494,995. The net assets acquired are $1,042,661. assets,  'liabilities,  'acquired,  'property,  'plant,  'equipment,  'trademarks,  'goodwill,  'current,  'long-term
# Time: 13.42 seconds
#
#
#
# 	83 - Key: d81d75aca
# 		Skipping d81d75aca, no table found ...
#
# 	84 - Key: d80f34dda
# Outstanding Cost or Amortized Cost of Debt by Credit Rating. This table shows the outstanding cost or amortized cost of debt for various credit ratings from 2003 to 2007. Notable trends include a decrease in debt costs for all ratings from 2003 to 2007, with the exception of the "Below Investment Grade" category which saw an increase in costs from 2004 to 2007. debt,  'cost,  'amortized cost,  'credit rating,  '2003,  '2004,  '2005,  '2006,  '2007,  'trends
# Time: 18.03 seconds
#
#
#
# 	85 - Key: d83f65b1c
# Financial Performance Over Time. This table shows the financial performance of a company over the years 2012, 2013, and 2014. Key trends include a significant increase in net income from 2013 to 2014, and a large gain on sale of business and impairment/write-down in 2014. Financial Performance,  'Sales,  'Income,  'Tax,  'Gain,  'Loss,  'Discontinued Operations
# Time: 15.46 seconds
#
#
#
# 	86 - Key: d815ddb0a
# 		Skipping d815ddb0a, no table found ...
#
# 	87 - Key: d82729ada
# Gain (Loss) Over Three Years. This table shows the gain (loss) for assets and liabilities over three years. Key trends include a significant increase in gain from 2016 to 2017, followed by a decrease in 2018. Notable assets include bond and equity securities, alternative investments, and other short-term investments. gain,  'loss,  'assets,  'liabilities,  'bond,  'equity,  'securities,  'alternative investments,  'short-term investments,  'long-term debt
# Time: 13.91 seconds
#
#
#
# 	88 - Key: d82375240
# Net Charge-offs and Allowance for Loan and Lease Losses. This table shows the net charge-offs and allowance for loan and lease losses for both commercial and consumer lending for the years 2016 and 2017. Key trends include a decrease in total net charge-offs from $543 million in 2016 to $457 million in 2017, and a decrease in net charge-offs to average loans for the year ended from 0.26% in 2016 to 0.21% in 2017. net charge-offs,  'allowance for loan and lease losses,  'commercial lending,  'consumer lending,  'millions,  '2016,  '2017
# Time: 21.04 seconds
#
#
#
# 	89 - Key: d82d2c9c8
# 		Skipping d82d2c9c8, no table found ...
#
# 	90 - Key: d815cd1ec
# 		Skipping d815cd1ec, no table found ...
#
# 	91 - Key: d83f65c16
# Bond Portfolio Analysis. Analysis of a bond portfolio over three years, showing changes in risk-free interest rate, expected life, expected volatility, expected dividend yield, and expected return. bond,  'portfolio,  'analysis,  'interest rate,  'expected life,  'volatility,  'dividend yield,  'return
# Time: 11.81 seconds
#
#
#
# 	92 - Key: d828cab46
# 		Skipping d828cab46, no table found ...
#
# 	93 - Key: d816cab26
# ONEOK Partners Net Income and Distributions. This table shows the net income and distributions for ONEOK Partners from 2005 to 2007. The total distributions from the partnership increased significantly from 2005 to 2006, and then decreased in 2007. The net income remained constant at $1,024 for all years. ONEOK Partners,  'net income,  'distributions,  'general partner,  'incentive distributions,  'years ended December 31
# Time: 39.55 seconds
#
#
#
# 	94 - Key: d81baf8ee
# Revenue and Expense Analysis for Fiscal Years 2018 and 2019. This table shows the financial performance of the company for the fiscal years ended June 30, 2018 and 2019. Key trends include significant increases in revenues, particularly in advertising and other categories, and a decrease in selling, general and administrative expenses. revenues,  'expenses,  'advertising,  'circulation,  'subscription,  'segment EBITDA,  'net income
# Time: 15.37 seconds
#
#
#
# 	95 - Key: d815210b8
# Financial and Employment Metrics. This table shows the net sales, operating profit, operating margin, backlog at year-end, and number of employees for the given years. net sales,  'operating profit,  'operating margin,  'backlog,  'employees
# Time: 10.59 seconds
#
#
#
# 	96 - Key: d8259f318
# Trading Securities and Equity Investments. This table shows the balance sheet of trading securities and equity investments for a company from December 31, 2008 to January 1, 2010. Key trends include an increase in total assets over time, with a significant jump following the National City acquisition. Trading securities,  'Equity investments,  'Balance sheet,  'National City acquisition,  'Increase,  'Total assets
# Time: 19.54 seconds
#
#
#
# 	97 - Key: d81486db0
# 		Skipping d81486db0, no table found ...
#
# 	98 - Key: d830e4e9e
# Square Footage of Major Cities. This table shows the approximate square footage of major cities in the United States and Canada. Notably, New York City has the smallest square footage, while Alpharetta, Georgia has the largest. Square Footage,  'Location,  'Alpharetta,  'New York,  'Chicago,  'Toronto,  'California,  'Georgia,  'Virginia,  'Jersey City,  'Illinois,  'Canada
# Time: 13.92 seconds
#
#
#
# 	99 - Key: d811393e2
# 		Skipping d811393e2, no table found ...
#
# 	100 - Key: d81e4fd60
# Balance Sheet for Credit-Impaired Securities. This table shows the balance sheet for credit-impaired securities from 2009 to 2010. Key trends include an increase in the balance due to new credit-impaired securities and a decrease due to sales of credit-impaired securities. credit-impaired securities,  'balance sheet,  '2009,  '2010,  'beginning of period,  'end of period,  'additions,  'reductions
# Time: 13.68 seconds
#
#
#
# 	101 - Key: d817bbf1c
# Quarterly Sales by Rank. This table shows the quarterly sales for four different ranks in a company, with the first quarter of 2009 as the base period. The sales have been increasing over time, with the fourth rank showing the highest growth. sales,  'quarter,  'rank,  'growth
# Time: 16.28 seconds
#
#
#
# 	102 - Key: d817bbfa8
# Investment Breakdown by Trust. This table shows the principal amount of subordinated notes/debentures issued to various trusts, as well as the investment in unconsolidated subsidiaries for each trust. The table also includes the rate for each trust. principal amount,  'subordinated note,  'debenture,  'trust,  'rate,  'investment,  'unconsolidated subsidiary
# Time: 13.32 seconds
#
#
#
# 	103 - Key: d81f02028
# Stores and E-commerce Sites Comparison. This table shows the number of stores (freestanding stores, concession shops, and total stores) and e-commerce sites (North American sites, European sites, Asian sites, and total e-commerce sites) for a given year. The table shows an increase in the total number of stores from 2013 to 2014, while the number of e-commerce sites remained the same. stores,  'e-commerce sites,  'freestanding stores,  'concession shops,  'North American sites,  'European sites,  'Asian sites,  '2013,  '2014
# Time: 16.2 seconds
#
#
#
# 	104 - Key: d818188b6
# Real Estate Ownership and Leasing by Country (in thousands of square feet). The table shows the total square footage of real estate owned and leased in the United States and other countries. The United States has the majority of owned and leased real estate, but other countries have a significant portion of leased real estate. The total square footage of real estate in both countries is over 9,000 thousand square feet. real estate,  'ownership,  'leased,  'square footage,  'United States,  'other countries,  'thousands
# Time: 13.17 seconds
#
#
#
# 	105 - Key: d8259f3ea
# Unrecognized tax benefits. The table shows unrecognized tax benefits related to acquired companies within the measurement period. The table contains two categories: permanent differences and temporary differences. The total unrecognized tax benefits amount to $227 million. unrecognized tax benefits,  'acquired companies,  'measurement period,  'permanent differences,  'temporary differences,  'millions
# Time: 10.64 seconds
#
#
#
# 	106 - Key: d82d2c8b0
# Risk Management Strategy Performance. This table shows the performance of different strategies under the Risk Management Strategy. The table includes the value of total assets, duration of assets, net duration gap, and net fair value change. Risk Management Strategy,  'Performance,  'Total Assets,  'Duration,  'Net Duration Gap,  'Net Fair Value Change
# Time: 10.64 seconds
#
#
#
# 	107 - Key: d8126d164
# Cash Flow Statement. This table shows the cash flow statement for the years 2006 to 2008. The main trends are an increase in cash provided by operating activities, a decrease in cash used in investing activities, and a decrease in cash used in financing activities. cash flow statement,  'operating activities,  'investing activities,  'financing activities,  '2006,  '2007,  '2008
# Time: 17.24 seconds
#
#
#
# 	108 - Key: d815cd25a
# Financial Performance Over Three Years. This table shows the financial performance of a company over three years, comparing the year ended December 31, 2016 to the previous two years. Key trends include a decrease in net sales and cost of sales, an increase in operating income, and a decrease in net income as a percentage of net sales. net sales,  'cost of sales,  'gross profit,  'operating expenses,  'operating income,  'net income,  'percent change
# Time: 31.38 seconds
#
#
#
# 	109 - Key: d815dd812
# Assets under Management. This table shows the assets under management, client brokerage assets, assets in custody, client deposits, and total net client assets for the years 2008 and 2009. assets,  'under management,  'client brokerage assets,  'assets in custody,  'client deposits,  'total net client assets
# Time: 13.19 seconds
#
#
#
# 	110 - Key: d8366a062
# 		Skipping d8366a062, no table found ...
#
# 	111 - Key: d8366a152
# 		Skipping d8366a152, no table found ...
#
# 	112 - Key: d81566618
# Revenue and Expense Analysis for 2007 and 2008. This table shows the revenues and expenses for a company from 2007 to 2008. Key trends include a significant increase in net income, a rise in marketing and advertising expenses, and a decrease in occupancy expenses. revenue,  'expenses,  '2007,  '2008,  'net income,  'marketing,  'advertising,  'occupancy
# Time: 18.57 seconds
#
#
#
# 	113 - Key: d81cc59b8
# Equity Performance Comparison. Comparison of key financial metrics for ESPP, SPY, and IWM over the years 2011-2013. Key trends include higher volatility and total return for IWM, while ESPP and SPY have similar dividend yields and betas. ESPP,  'SPY,  'IWM,  'dividend yield,  'expected volatility,  'risk-free interest rate,  'beta,  'total return
# Time: 40.96 seconds
#
#
#
# 	114 - Key: d8364bba8
# Net Revenues by Region (2011-2013). This table shows the net revenues for various regions from 2011 to 2013. Europe and North America have relatively stable revenues, while Latin America and Asia Pacific have experienced growth. Africa and Middle East have shown significant increases in 2013. net revenues,  'Europe,  'Latin America,  'Asia Pacific,  'North America,  'Africa,  'Middle East,  'growth,  'stability
# Time: 23.06 seconds
#
#
#
# 	115 - Key: d82bda0d4
# MetLife Income Statement for 2007 and 2008. This table presents the income statement for MetLife for the years ended December 31, 2007 and 2008. Key trends include an 8.1% increase in total revenues, a 12.4% decrease in income before provision for income tax, and a 26.6% decrease in net income. MetLife,  'income statement,  'revenues,  'expenses,  'net income,  '2007,  '2008
# Time: 22.64 seconds
#
#
#
# 	116 - Key: d817f6306
# Income Statement. This table shows the income statement for a company from 2011 to 2013. Key trends include a decrease in net income from 2011 to 2012, followed by a slight increase in 2013. Basic and diluted earnings per share also decreased from 2011 to 2012, but increased slightly in 2013. income,  'statement,  'net income,  'basic earnings per share,  'diluted earnings per share,  '2011,  '2012,  '2013
# Time: 15.57 seconds
#
#
#
# 	117 - Key: d8237510a
# Tobacco and Health Litigation Expenses. This table shows the accrued liability and pre-tax charges for tobacco and health litigation items for the years 2015 to 2017. tobacco,  'health,  'litigation,  'expenses,  'accrued liability,  'pre-tax charges,  '2015,  '2016,  '2017
# Time: 16.1 seconds
#
#
#
# 	118 - Key: d842c8dd6
# American Tower Corporation Balance Sheet and Cash Flow Data. This table provides a summary of American Tower Corporation\ American Tower Corporation,  'balance sheet,  'cash flow,  'assets,  'liabilities,  'equity,  'net income,  'net cash
# Time: 56.31 seconds
#
#
#
# 	119 - Key: d8207429e
# 		Skipping d8207429e, no table found ...
#
# 	120 - Key: d81be6600
# Debt and Equity Composition. This table shows the composition of debt and equity for the company from 2016 to 2018. Total common shareholders\ debt,  'equity,  'common shareholders,  'long-term debt,  'redeemable preferred stock,  'short-term debt,  'current portion of long-term debt,  'composition,  'trends
# Time: 20.91 seconds
#
#
#
# 	121 - Key: d8291ab28
# Interest Rate and Derivative Assets and Liabilities. This table shows the notional amounts and current market or fair value of various interest rate and derivative assets and liabilities as of December 31, 2007 and December 31, 2006. Interest rate swaps,  'Interest rate floors,  'Interest rate caps,  'Financial futures,  'Foreign currency swaps,  'Foreign currency forwards,  'Options,  'Financial forwards,  'Credit default swaps,  'Synthetic GICs,  'Notional amount,  'Current market value,  'Assets,  'Liabilities
# Time: 17.76 seconds
#
#
#
# 	122 - Key: d8269a16e
# Total Assets, Liabilities, and Maximum Exposure to Loss by Investment Vehicle. This table shows the total assets, total liabilities, and maximum exposure to loss for CDOs, limited partnerships, and the total for both investment vehicles for the years 2010 and 2011. CDOs,  'limited partnerships,  'total assets,  'total liabilities,  'maximum exposure to loss,  '2010,  '2011
# Time: 17.32 seconds
#
#
#
# 	123 - Key: d84dc5eaa
# Citigroup Income Statement. This table shows the income statement for Citigroup from 2009 to 2010. Key trends include a decrease in net income from 2009 to 2010, with a loss of $7,579 million in 2010 compared to a net income of $2,168 million in 2009. The earnings per share (EPS) also decreased from $0.09 in 2009 to $0.04 in 2010. Citigroup,  'income statement,  'net income,  'earnings per share,  '2009,  '2010
# Time: 37.86 seconds
#
#
#
# 	124 - Key: d81ffb9e8
# Citigroup Stockholders’ Equity and Tangible Common Equity (TCE) Analysis. This table provides the total stockholders’ equity, Tangible Common Equity (TCE), and related ratios for Citigroup for the years 2008 and 2009. The TCE ratio and TCE/RWA ratio show a significant increase from 2008 to 2009, indicating a strengthening of Citigroup\ Citigroup,  'stockholders’ equity,  'Tangible Common Equity (TCE),  'TCE ratio,  'TCE/RWA ratio,  '2008,  '2009
# Time: 17.76 seconds
#
#
#
# 	125 - Key: d8190ffb2
# Net Revenues Growth by Quarter. This table shows the net revenues for each quarter from 2006 to 2009. The table includes the net revenues for each quarter and the growth rate compared to the previous quarter. net revenues,  'quarter,  'growth,  '2006,  '2007,  '2008,  '2009
# Time: 19.83 seconds
#
#
#
# 	126 - Key: d828caa88
# Impact of Adverse Changes on Financial Metrics. This table shows the impact of adverse changes in discount rate and constant prepayment rate on various financial metrics for a portfolio of retained interests. The table includes the fair value of retained interests, weighted average life, constant prepayment rate, and the impact of 10% and 20% adverse changes in discount rate and constant prepayment rate. adverse change,  'discount rate,  'constant prepayment rate,  'fair value,  'weighted average life,  'portfolio,  'retained interests
# Time: 14.45 seconds
#
#
#
# 	127 - Key: d81486d60
# AIG Parent Liquidity Sources. This table shows the liquidity sources available to AIG Parent as of December 31, 2010 and February 16, 2011. Key trends include a decrease in total liquidity sources from $38,333 million to $14,453 million between the two dates. AIG,  'liquidity,  'sources,  'cash,  'short-term investments,  'Syndicated Credit Facility,  'Contingent Liquidity Facility,  'Department of the Treasury Commitment,  'Series G,  'Series F,  'FRBNY Credit Facility
# Time: 16.15 seconds
#
#
#
# 	128 - Key: d811fbf64
# Cross-border Exposure Exceeding One Percent of Total Assets. This table shows the cross-border exposure exceeding one percent of total assets for the public sector, banks, and private sector in the United Kingdom, Japan, and Germany for the years 2010 and 2011. Cross-border Exposure,  'Total Assets,  'Public Sector,  'Banks,  'Private Sector,  'United Kingdom,  'Japan,  'Germany,  '2010,  '2011
# Time: 24.24 seconds
#
#
#
# 	129 - Key: d811d0e9a
# 		Skipping d811d0e9a, no table found ...
#
# 	130 - Key: d813a40b4
# Operating Expenses and Headcount for Selected Years. This table shows the operating expenses and headcount for the company from 2016 to 2018. Key trends include an increase in total operating expenses from $20.304 billion in 2016 to $23.461 billion in 2018, and a corresponding increase in headcount from 32,400 in 2016 to 36,600 in 2018. operating expenses,  'headcount,  '2016,  '2017,  '2018,  'compensation and benefits,  'brokerage fees,  'market development,  'communications and technology,  'depreciation and amortization,  'occupancy,  'professional fees,  'other expenses
# Time: 19.84 seconds
#
#
#
# 	131 - Key: d82e4ef72
# 		Skipping d82e4ef72, no table found ...
#
# 	132 - Key: d81907006
# 		Skipping d81907006, no table found ...
#
# 	133 - Key: d81f402d8
# Balance Sheet. This table shows the balance sheet of a company for the years 2010 and 2011. Key trends include a decrease in cash and cash equivalents, current investments, and total debt, as well as a decrease in unsettled fund receivables and payables. There is also a slight increase in non-current investments and a slight decrease in intangible assets, goodwill, and total equity. cash,  'cash equivalents,  'unsettled fund receivables,  'current investments,  'assets held for policyholders,  'non-current investments,  'investments of consolidated investment products,  'intangible assets,  'goodwill,  'unsettled fund payables,  'policyholder payables,  'current maturities of total debt,  'long-term debt,  'total debt,  'total equity
# Time: 27.2 seconds
#
#
#
# 	134 - Key: d8199c9bc
# Derivatives Financial Performance. This table shows the financial performance of various types of derivatives for the years ended December 31, 2011 and 2010. Key trends include a decrease in gains recognized in Other (income) expense, net on derivatives, and an increase in losses recognized in OCI on derivatives. derivatives,  'financial performance,  '2011,  '2010,  'gain,  'loss,  'Other (income) expense,  net,  'OCI
# Time: 20.7 seconds
#
#
#
# 	135 - Key: d82787b30
# 		Skipping d82787b30, no table found ...
#
# 	136 - Key: d837f6070
# Insurance Losses by Segment and Year. This table shows the total incurred losses for attritional and catastrophe events for each year from 2015 to 2017. The table also includes the percentage change from the prior year for each segment and the total segment. insurance,  'losses,  'attritional,  'catastrophe,  'year,  'total,  'segment,  'percentage change
# Time: 17.4 seconds
#
#
#
# 	137 - Key: d828a59b8
# Insurance Losses Over Three Years. This table shows the total incurred losses for attritional and catastrophes segments over three years. The table also includes the percentage change from the previous year for each segment and the total segment. insurance,  'losses,  'attritional,  'catastrophes,  'total segment,  'years,  'incurred,  'percentage change
# Time: 16.49 seconds
#
#
#
# 	138 - Key: d813cd23e
# 		Skipping d813cd23e, no table found ...
#
# 	139 - Key: d80ee2724
# US Treasury International Capital (USD billions). This table shows the balance of US Treasury International Capital at the beginning and end of 2008 and 2009, as well as net flows and market appreciation/depreciation. US Treasury International Capital,  'balance,  'net flows,  'market appreciation,  'depreciation
# Time: 10.47 seconds
#
#
#
# 	140 - Key: d829d9a14
# 		Skipping d829d9a14, no table found ...
#
# 	141 - Key: d8202fc70
# 		Skipping d8202fc70, no table found ...
#
# 	142 - Key: d81447c00
# Contractual Obligations by Period. This table shows the total contractual obligations, broken down by type and the period in which payments are due. The majority of obligations are long-term debt, with a significant portion due within the next year. Fixed rate interest and operating leases also contribute to the total. contractual obligations,  'payments,  'period,  'long-term debt,  'fixed rate interest,  'operating leases,  'purchase obligations
# Time: 12.65 seconds
#
#
#
# 	143 - Key: d8121854c
# 		Skipping d8121854c, no table found ...
#
# 	144 - Key: d812c0c38
# Trading Account Assets and Liabilities. This table shows the trading account assets and liabilities of a financial institution for the years 2009 and 2010. Key trends include an increase in total trading account assets from $182,206 million in 2009 to $194,671 million in 2010, and a decrease in total trading account liabilities from $65,432 million in 2009 to $71,985 million in 2010. trading account,  'assets,  'liabilities,  '2009,  '2010,  'U.S. government,  'agency securities,  'corporate securities,  'equity securities,  'non-U.S. sovereign debt,  'mortgage trading loans,  'asset-backed securities
# Time: 22.97 seconds
#
#
#
# 	145 - Key: d82384dda
# Warranty Liability and Expense. This table shows the warranty liability and expense for the years 2009 and 2010. Key trends include a decrease in warranty liability from $59.6 million in 2009 to $46.2 million in 2010, and a slight decrease in warranty expense from $1.7 million in 2009 to $1.8 million in 2010. warranty,  'liability,  'expense,  'settlements,  'pre-existing warranties,  '2009,  '2010
# Time: 16.56 seconds
#
#
#
# 	146 - Key: d820400fc
# Stock Option Grant and Vesting Schedule. This table shows the number of shares granted, vested, forfeited, and non-vested at the end of each year from 2008 to 2011, along with their respective fair values. stock options,  'grant,  'vesting,  'forfeited,  'fair value,  'year,  'number of shares
# Time: 18.81 seconds
#
#
#
# 	147 - Key: d827cc76c
# ...
# Time: 14.15 seconds
#
#
#
# 	828 - Key: d843a79dc
# 		Skipping d843a79dc, no table found ...
#
# 	829 - Key: d812ed40e
# 		Skipping d812ed40e, no table found ...
#
# 	830 - Key: d82a3a576
# Quarterly Financial Performance of a Bank. This table shows the quarterly financial performance of a bank for the years 2015 and 2016. Key trends include a slight decrease in net interest income, a steady increase in total revenue, and a consistent efficiency ratio. The return on average assets and equity, net charge-offs as a percentage of average loans, and allowance for loan and lease losses as a percentage of total loans all remain relatively stable. net interest income,  'total revenue,  'net interest yield,  'efficiency ratio,  'return on average assets,  'return on average equity,  'net charge-offs,  'allowance for loan and lease losses,  'nonperforming loans,  'net loans and leases,  'total assets
# Time: 78.5 seconds
#
#
#
# 	831 - Key: d81e74174
# Quarterly Financial Performance of Biogen Inc.. This table presents the quarterly financial performance of Biogen Inc. for the year 2014. Key trends include a steady increase in total revenues, gross profit, and net income throughout the year, with the highest net income in the fourth quarter ($882.6M). Biogen Inc.,  'financial performance,  'revenues,  'gross profit,  'net income,  'quarterly,  '2014
# Time: 24.61 seconds
#
#
#
# 	832 - Key: d82a3a51c
# Tax Positions Balance Sheet. This table shows the balance sheet of tax positions for the years 2014 and 2015. Key trends include an increase in the balance at January 1, additions for tax positions of prior years, and a decrease in reductions for tax positions of prior years. tax positions,  'balance sheet,  '2014,  '2015,  'additions,  'reductions,  'settlements,  'business combinations,  'lapse of statute of limitations,  'foreign currency translation
# Time: 13.48 seconds
#
#
#
# 	833 - Key: d81128434
# Weighted-average assumptions for stock options. This table shows the weighted-average assumptions for stock options over the years 2014 to 2016. Key trends include a decrease in expected volatility from 2014 to 2015, followed by an increase in 2016, and a steady term of stock options at 4.3 years. The risk-free interest rate decreased from 2014 to 2015 and then increased in 2016. weighted-average,  'assumptions,  'stock options,  'volatility,  'term,  'risk-free interest rate
# Time: 63.03 seconds
#
#
#
# 	834 - Key: d825900ac
# 		Skipping d825900ac, no table found ...
#
# 	835 - Key: d8140c1d2
# Con Edison Pension Obligation. This table shows the projected benefit obligation, plan assets, and funded status of Con Edison pension plan from 2013 to 2015. Key trends include a decrease in the funded status from 2013 to 2015, and a decrease in the net position over the same period. Con Edison,  'pension,  'obligation,  'projected benefit obligation,  'plan assets,  'funded status,  'net position
# Time: 30.61 seconds
#
#
#
# 	836 - Key: d82bd9e4a
# Income Statement. This table shows financial metrics for the company from 2016 to 2018. Key trends include a decrease in weighted average common shares outstanding for basic computations and diluted computations, as well as a slight increase in net income and earnings per share (EPS). income,  'net income,  'EPS,  'weighted average common shares,  'equity awards,  '2016,  '2017,  '2018
# Time: 19.34 seconds
#
#
#
# 	837 - Key: d814d947a
# Firm Sales and Transportation Revenues. This table shows the revenues for various categories of sales and transportation for the years ended December 31, 2017 and 2016. Key trends include a 6.9% increase in total firm sales and transportation revenues from 2016 to 2017, a 22.1% increase in total revenues from 2017, and a 20.2% increase in residential revenues from 2016 to 2017. revenues,  'sales,  'transportation,  '2017,  '2016,  'variation,  'percent variation,  'residential,  'general,  'firm transportation,  'total firm sales and transportation,  'interruptible sales,  'NYPA,  'generation plants,  'other,  'other operating revenues,  'total
# Time: 23.09 seconds
#
#
#
# 	838 - Key: d81a5d586
# Warranty and Related Costs. This table shows the accrued warranty and related costs, cost of warranty claims, and accruals for product warranties for the years 2005 to 2007. warranty,  'costs,  'accrued,  'claims,  'product,  'years
# Time: 11.22 seconds
#
#
#
# 	839 - Key: d827f3e34
# 		Skipping d827f3e34, no table found ...
#
# 	840 - Key: d827ba65c
# Stock Purchase Summary - Q3 2007. This table shows the number of shares purchased and the average price per share for a single stock during Q3 2007. The total number of shares purchased is 1,548, with an average price of $33.64 per share. stock,  'purchase,  'shares,  'Q3 2007,  'average price,  'total
# Time: 11.52 seconds
#
#
#
# 	841 - Key: d8135b1de
# 		Skipping d8135b1de, no table found ...
#
# 	842 - Key: d81d3a290
# Net Earnings by Business Segment. This table shows the net earnings of various business segments for the years 2012, 2013, and 2014. The total net revenues and operating expenses are also provided. Key trends include a decrease in net earnings from 2013 to 2014, and an increase in total net revenues from 2012 to 2014. net earnings,  'business segment,  'total net revenues,  'operating expenses,  '2012,  '2013,  '2014
# Time: 17.94 seconds
#
#
#
# 	843 - Key: d82a77b38
# Total Commissions by Asset Class. This table shows the total commissions for Equity and Fixed Income asset classes from 2007 to 2009. The Equity asset class has consistently dominated the total commissions, with a significant increase from 2007 to 2009. The Fixed Income asset class has shown a steady increase from 2007 to 2008, but a decrease from 2008 to 2009. Total Commissions,  'Equity,  'Fixed Income,  'Asset Class,  'Increase,  'Decrease
# Time: 15.46 seconds
#
#
#
# 	844 - Key: d815f4896
# Fiscal Year Payments Due By Contract Type. This table shows the total payments due by fiscal year for operating leases and purchase obligations, broken down by time period. The majority of payments are due within one year for both contract types. payments,  'fiscal year,  'contractual obligations,  'operating leases,  'purchase obligations,  'total obligations,  'less than 1 year,  '1-3 years,  '3-5 years,  'more than 5 years
# Time: 12.68 seconds
#
#
#
# 	845 - Key: d81332ff4
# Total Cost and Number of Shares Purchased Over Time. This table shows the total cost and number of shares purchased for each year from 2005 to 2008. The average price paid per share also is provided. The total cost and number of shares purchased decreased from 2005 to 2007, but increased in 2008. The average price paid per share decreased from 2006 to 2008. total cost,  'shares purchased,  'average price,  'year,  'trend
# Time: 16.19 seconds
#
#
#
# 	846 - Key: d82581ef8
# Financial Ratios of a Stock. This table shows the weighted-average fair value, risk-free interest rate, average expected option life, expected volatility, expected dividend yield, and expected growth rate for a stock from 2011 to 2013. weighted-average fair value,  'risk-free interest rate,  'average expected option life,  'expected volatility,  'expected dividend yield,  'expected growth rate
# Time: 14.5 seconds
#
#
#
# 	847 - Key: d816cac7a
# 		Skipping d816cac7a, no table found ...
#
# 	848 - Key: d8194e91a
# Railroad Performance Metrics. This table shows various performance metrics for a railroad company from 2008 to 2010. Key trends include a decrease in average train speed, average rail car inventory, and number of employees, while customer satisfaction index has increased. railroad,  'performance,  'metrics,  'train speed,  'terminal dwell time,  'rail car inventory,  'gross ton-miles,  'revenue ton-miles,  'operating ratio,  'employees,  'customer satisfaction index
# Time: 14.93 seconds
#
#
#
# 	849 - Key: d813b8f64
# Net Cash Flow for the Unit. This table shows the balance at the beginning and end of the year, unit redemptions, fair market value amortization, other expenses, and net cash inflow for the given years. balance,  'unit redemptions,  'fair market value amortization,  'other,  'net cash inflow,  '2008,  '2009
# Time: 12.67 seconds
#
#
#
# 	850 - Key: d812ed62a
# 		Skipping d812ed62a, no table found ...
#
# 	851 - Key: d8200a768
# 		Skipping d8200a768, no table found ...
#
# 	852 - Key: d81baf7b8
# Revenue Deferral and Recognition. This table shows the balance of deferred revenue at two points in time, as well as the deferral and recognition of deferred revenue for the fiscal year ended June 30, 2019. revenue,  'deferral,  'recognition,  'balance,  'fiscal year,  '2019
# Time: 10.6 seconds
#
#
#
# 	853 - Key: d838f1f74
# Bond Yield and Volatility. This table shows the risk-free interest rate, expected life, expected dividend yield, volatility, and expected return for a bond over the years 2005 to 2007. bond,  'interest rate,  'expected life,  'dividend yield,  'volatility,  'expected return
# Time: 12.69 seconds
#
#
#
# 	854 - Key: d81c09236
# Stock Financial Metrics. This table provides financial metrics for a stock over the years 2016 to 2018. The stock price, expected annual dividend yield, expected volatility, risk-free interest rate, fair value of stock-based performance units outstanding, and total number of shares outstanding are included. stock price,  'dividend yield,  'volatility,  'risk-free interest rate,  'fair value,  'shares outstanding
# Time: 16.39 seconds
#
#
#
# 	855 - Key: d811d0ef4
# Citigroup Debt, Equity, and Assets. This table shows the long-term, short-term, and total debt, equity, and assets for Citigroup and its subsidiaries. Key trends include a total debt of $396.9 billion, total equity of $400 billion, and total assets of $2,434 billion. Citigroup,  'debt,  'equity,  'assets,  'long-term,  'short-term,  'subsidiaries
# Time: 26.93 seconds
#
#
#
# 	856 - Key: d81be66a0
# 		Skipping d81be66a0, no table found ...
#
# 	857 - Key: d8202fce8
# Financial Performance Over Three Years. This table shows the financial performance of a company over three years, with key metrics such as revenues, operating income, and net income. revenues,  'operating income,  'net income,  '2013,  '2014,  '2015
# Time: 20.42 seconds
#
#
#
# 	858 - Key: d81695034
# Current Assets and Liabilities. This table shows the amounts (in millions) for various current assets and liabilities for the years 2012 and 2013. current assets,  'current liabilities,  '2012,  '2013,  'millions
# Time: 11.77 seconds
#
#
#
# 	859 - Key: d825902a0
# 		Skipping d825902a0, no table found ...
#
# 	860 - Key: d8177aa1c
# Balance Sheet as of March 2, 2012. This table presents the balance sheet of an unnamed entity as of March 2, 2012. The table shows the recognized amounts of identifiable assets and liabilities at fair value, as well as the total assets and total fair value of identifiable net assets. Key trends include significant investments in investment securities, net loans, and other assets, as well as large deposits and other borrowed funds. Balance Sheet,  'March 2,  2012,  'Fair Value,  'Assets,  'Liabilities,  'Investment Securities,  'Net Loans,  'Other Assets,  'Deposits,  'Borrowed Funds,  'Goodwill
# Time: 18.83 seconds
#
#
#
# 	861 - Key: d816223ea
# Cash Flow Statement. This table shows the cash flow statement for the company from 2006 to 2008. The net cash provided by operating activities increased from 2006 to 2008, while net cash used in investing activities and net cash used in financing activities decreased. The net cash provided by (used in) financing activities excluding cash dividends remained constant. cash flow,  'statement,  'operating activities,  'investing activities,  'financing activities,  'net cash,  '2006,  '2007,  '2008
# Time: 27.72 seconds
#
#
#
# 	862 - Key: d819100c0
# Bond Characteristics. This table shows the characteristics of a bond over three years. The risk-free interest rate decreases significantly from 2006 to 2008. The expected life of the bond increases slightly, while the dividend yield remains at 0%. The expected volatility fluctuates slightly, and the expected return decreases significantly. risk-free interest rate,  'expected life,  'dividend yield,  'expected volatility,  'expected return
# Time: 14.14 seconds
#
#
#
# 	863 - Key: d81cc5a80
# Revenue and Growth of Selected Companies (2012-2014). This table shows the revenue of five companies from 2012 to 2014. Silicon Systems Group has the highest revenue and the highest growth rate in all years. Applied Global Services has the second-highest revenue and growth rate, while Display and Energy and Environmental Solutions have the lowest revenue and growth rate. revenue,  'growth,  'Silicon Systems Group,  'Applied Global Services,  'Display,  'Energy and Environmental Solutions
# Time: 14.22 seconds
#
#
#
# 	864 - Key: d818a3a7e
# 		Skipping d818a3a7e, no table found ...
#
# 	865 - Key: d827ba5ee
# 		Skipping d827ba5ee, no table found ...
#
# 	866 - Key: d819e64e0
# 		Skipping d819e64e0, no table found ...
#
# 	867 - Key: d8232f1aa
# Yearly Revenue. This table shows the yearly revenue for a company from 2013 to the present and future. The revenue has been increasing since 2017 and is expected to significantly increase from 2018 onwards. revenue,  'yearly,  'company,  'increase,  '2013,  '2014,  '2015,  '2016,  '2017,  '2018,  'future
# Time: 12.49 seconds
#
#
#
# 	868 - Key: d83f65cc0
# Income Statement for Years Ended September 30. This table shows the financial performance of a company for the years 2010 to 2014. Key trends include an increase in revenues from homebuilding, a decrease in income before taxes for homebuilding, and a significant increase in net income. revenues,  'homebuilding,  'financial services,  'income,  'taxes,  'net income,  'dividends,  'shares
# Time: 26.38 seconds
#
#
#
# 	869 - Key: d828efc98
# 		Skipping d828efc98, no table found ...
#
# 	870 - Key: d818bcd58
# Mortgage Balances. This table shows the total mortgage balances for commercial and residential properties as of December 31, 2012 and December 31, 2011. mortgage,  'commercial,  'residential,  'balances,  'fair value,  'lower of cost or market,  'total
# Time: 10.28 seconds
#
#
#
# 	871 - Key: d8232efe8
# Revenue and Growth Analysis. This table shows the revenue and growth of a company from 2008 to 2010. The company experienced a significant increase in total revenue from 2009 to 2010, while there was a decrease from 2008 to 2009. The key trends are the growth in production and the decline in ad valorem and other revenues. revenue,  'growth,  'production,  'ad valorem,  'other,  '2008,  '2009,  '2010
# Time: 14.27 seconds
#
#
#
# 	872 - Key: d8194e7e4
# Special Items in Revenue by Year. This table shows the special items in revenue for the years 2012, 2013, and 2014. Key trends include a decrease in total special items from 2012 to 2013, followed by an increase in 2014. special items,  'revenue,  'year,  '2012,  '2013,  '2014
# Time: 12.55 seconds
#
#
#
# 	873 - Key: d8124326a
# 		Skipping d8124326a, no table found ...
#
# 	874 - Key: d81589514
# BorgWarner Inc. Financial Performance 2010. This table shows the financial performance of BorgWarner Inc. for the year 2010, with a focus on key income and earnings metrics, as well as net sales. BorgWarner Inc.,  'financial performance,  'operating income increase,  'net earnings increase,  'earnings per share increase,  'net sales increase
# Time: 14.25 seconds
#
#
#
# 	875 - Key: d81dec9c2
# Allowance for Doubtful Accounts. This table shows the balance and changes in the allowance for doubtful accounts for three different years. allowance,  'doubtful accounts,  'balance,  'changes,  'years
# Time: 8.81 seconds
#
#
#
# 	876 - Key: d827cc6a4
# RSUs and Grant-Date Fair Value Per Share. This table shows the number of Restricted Stock Units (RSUs) and their weighted average grant-date fair value per share for different years. Key trends include a decrease in the number of vested RSUs and an increase in the grant-date fair value per share over the years. RSUs,  'Grant-Date Fair Value,  'Per Share,  'Nonvested,  'Vested,  'Forfeited,  '2011,  '2012,  '2013,  '2014
# Time: 20.2 seconds

# %%
dataset = "MultiHeritt"
table_dict = np.load(f'table_summaries_{dataset}_short.npy', allow_pickle='TRUE').item()
len(table_dict)
# Out:
# 551

# %% [markdown]
# ----------------------------------------------------------------------------

# %%
# create_summaries("TATQA", template_short, "short")
# Out:
# CREATING SUMMARIES FOR TATQA, with template:
# You are a finance expert who specializes in analyzing tables.
#
# ### Task ###
# Summarize the table in a dictionary with the following keys:
# - 'title': A concise title for the table.
# - 'description': A brief description of the table's contents and key trends.
# - 'keywords': A list of relevant keywords.
#
# **Note**: Do not return the table, prompt, or any extra text. Return only the dictionary.
#
# ### Table ###
#
#
#
#
# Loaded extracted_tables_TATQA, it has 248 tables to process
#
#
#
# 	1 - Key: d1a71456c
# Financial Analysis of Trade Payables and Payments. This table provides a comparison of trade payables, payments received on account, other taxes and social security costs, other payables, accruals, government grants, and non-current payables for the years 2018 and 2019. trade payables,  'payments received on account,  'other taxes,  'other payables,  'accruals,  'government grants,  'non-current payables,  '2018,  '2019
# Time: 15.78 seconds
#
#
#
# 	2 - Key: d1a719738
# Golar Partners and Other Affiliates Financial Performance. This table shows the financial performance of Golar Partners and other affiliates for the years 2018 and 2019. Key trends include significant losses for Golar Partners, a large impairment of investment in Golar Partners, and decreased earnings in other affiliates. Golar Partners,  'financial performance,  'losses,  'impairment,  'investment,  'earnings,  'affiliates
# Time: 16.26 seconds
#
#
#
# 	3 - Key: d1a725a2e
# Group Share of Associates. This table shows the group share of associates Financial Year ended 31 March,  'Group share of associates,  'pre-tax proﬁts,  'share of post-tax proﬁts,  'Telkomsel,  'AIS,  'Globe,  'Intouch,  'Airtel,  'BTL,  'Regional associates,  'NetLink NBN Trust/ NetLink Trust,  'Other associates,  'S$ million,  '%,  'Change,  'Change in constant currency
# Time: 21.0 seconds
#
#
#
# 	4 - Key: d1a718d56
# Net Income and Shares Outstanding Over Three Years. This table shows the net income and average shares outstanding for three fiscal years ending on June 30, 2019, June 24, 2018, and June 25, 2017. Key trends include a decrease in net income per share-basic and per share-diluted from 2017 to 2018, followed by a slight increase in 2019. net income,  'average shares outstanding,  'basic average shares outstanding,  'diluted average shares outstanding,  'June 30,  '2017,  '2018,  '2019
# Time: 19.41 seconds
#
#
#
# 	5 - Key: d1a717e60
# Shareholder Distributions, Interest Expense, and Net Interest Income. This table shows the changes in shareholder distributions (dividends and buybacks), interest expense, and net interest income from FY18 to FY19. Shareholder distributions increased by 10% and 19% for dividends and buybacks respectively. Interest expense increased by 11%, while net interest income increased by 8%. Total debt increased by 6%. Shareholder distributions,  'Dividends,  'Buybacks,  'Interest expense,  'Net interest income,  'Total debt,  'FY18,  'FY19,  'Increase,  'Percentage
# Time: 20.98 seconds
#
#
#
# 	6 - Key: d1a72b690
# Stock Option Grant and Fair Value. This table shows the number of shares of common stock granted, the weighted average grant-date fair value per common stock, the fair value of common stock vested, and the fair value of common stock unvested for the years 2017, 2018, and 2019. stock,  'grant,  'fair value,  'common stock,  'vested,  'unvested,  'years
# Time: 12.77 seconds
#
#
#
# 	7 - Key: d1a71726c
# Executive Leadership. This table provides information about the key executives of the company, including their names, ages, and positions. Notable trends include Avi Katz serving as President, General Counsel and Secretary since December 2012, and John Capogrossi transitioning from Vice President and Controller to Vice President, Chief Financial Officer, Treasurer and Controller in March 2013. executives,  'names,  'ages,  'positions,  'Avi Katz,  'John Capogrossi,  'Joseph M. Sala,  'President,  'General Counsel,  'Secretary,  'Vice President,  'Chief Financial Officer,  'Treasurer,  'Controller
# Time: 20.02 seconds
#
#
#
# 	8 - Key: d1a7303b6
# Intangible Assets Valuation. This table provides the gross carrying value and weighted average estimated life for various intangible assets. Key trends include the significant value of client relationships and other intangible assets, as well as the relatively short life of trade names. intangible assets,  'gross carrying value,  'weighted average estimated life,  'client relationships,  'trade names,  'non-compete agreements,  'other intangible assets
# Time: 12.76 seconds
#
#
#
# 	9 - Key: d1a7244a8
# R&D and Innovation Expenditure. This table shows the expenditure on R&D and innovation for the given years. Key trends include an increase in total R&D expenditure and innovation center expenditure from FY 2018 to FY 2019. R&D,  'innovation,  'expenditure,  'FY 2019,  'FY 2018,  'capital,  'recurring,  'total,  'innovation center
# Time: 12.83 seconds
#
#
#
# 	10 - Key: d1a71b272
# Financial Performance for Three Months Ended 31 December. The table shows the financial performance of the company for the three months ended 31 December 2019 and 2018. Key trends include an increase in revenues, gross profit, and operating profit, as well as a decrease in interest income, selling and marketing expenses, general and administrative expenses, and finance costs, net. revenues,  'cost of revenues,  'gross profit,  'interest income,  'other gains,  'selling and marketing expenses,  'general and administrative expenses,  'operating profit,  'finance costs,  'income tax expense,  'profit for the period,  'equity holders,  'non-controlling interests
# Time: 17.69 seconds
#
#
#
# 	11 - Key: d1a73a852
# Current and Noncurrent Assets as of December 31, 2019 and 2018. This table shows the changes in current and noncurrent assets for the company from December 31, 2018 to December 31, 2019. Key trends include an increase in trade accounts receivable, net, current, inventories, net, and total assets. current assets,  'noncurrent assets,  'trade accounts receivable,  'inventories,  'total assets,  '2018,  '2019
# Time: 24.68 seconds
#
#
#
# 	12 - Key: d1a73ca80
# Executive Compensation Breakdown. This table shows the compensation breakdown for executive management and the board of directors for three fiscal years ending June 30. Key trends include a significant increase in share-based payments for executive management and a relatively stable cash remuneration for the board of directors. executive,  'compensation,  'management,  'board,  'directors,  'short-term,  'compensation,  'benefits,  'post-employment,  'benefits,  'share-based,  'payments,  'cash,  'remuneration,  'fiscal,  'year,  'trend
# Time: 16.46 seconds
#
#
#
# 	13 - Key: d1a7411b6
# Financial Performance and Objectives. Table shows the financial performance and strategic objectives of four individuals in terms of Target, Cap, Net Sales, Adjusted Operating Income, Strategic Objectives, Corporate Governance, and Business Unit/Individual Objectives. Key trends include high Target amounts for Barry Litwin and Eric Lerner, and zero percent for Net Sales, Adjusted Operating Income, Strategic Objectives, Corporate Governance, and Business Unit/Individual Objectives for Thomas Clark and Robert Dooley. Financial Performance,  'Target,  'Cap,  'Net Sales,  'Adjusted Operating Income,  'Strategic Objectives,  'Corporate Governance,  'Business Unit/Individual Objectives,  'Barry Litwin,  'Thomas Clark,  'Robert Dooley,  'Eric Lerner
# Time: 18.61 seconds
#
#
#
# 	14 - Key: d1a722c66
# Financial Performance Over Two Years. This table shows the financial performance of a company over two years, with a focus on cost of net revenue, gross profit, operating expenses, operating income, and net income. Key trends include a decrease in cost of net revenue, gross profit, operating income, and net income, while operating expenses increased slightly. financial performance,  'cost of net revenue,  'gross profit,  'operating expenses,  'operating income,  'net income,  'decrease,  'increase
# Time: 23.63 seconds
#
#
#
# 	15 - Key: d1a7218e8
# Net Sales and Operating Income by Fiscal Year. This table shows the net sales, surcharge revenue, net sales excluding surcharge revenue, gross profit, gross margin, operating expenses, operating income, and operating margin for the years 2018 and 2019. net sales,  'surcharge revenue,  'gross profit,  'operating expenses,  'operating income,  'gross margin,  'operating margin,  'fiscal year,  '2018,  '2019
# Time: 17.61 seconds
#
#
#
# 	16 - Key: d1a73b248
# Financial Analysis for 2019 vs 2018. This table shows the financial performance of the company for the year ended December 31, 2019, compared to the previous year, 2018. Key trends include an increase in research and development expenses, a decrease in net income, and an increase in total assets and total liabilities. financial analysis,  '2019,  '2018,  'research and development,  'selling,  general,  and administrative,  'total operating expenses,  'net income,  'total assets,  'total liabilities,  'total equity
# Time: 36.11 seconds
#
#
#
# 	17 - Key: d1a73ec0e
# Income Statement. This table shows the income statement for the years ended December 31, 2019, 2018, and 2017. Key trends include a significant increase in net realized gains from sales of trading securities from 2017 to 2019, a decrease in dividend and interest income from 2017 to 2018, and a large unrealized holding gain in 2019. Total comprehensive income also increased from 2017 to 2019. income statement,  'net realized gains,  'dividend and interest income,  'net unrealized holding gains,  'total comprehensive income,  'trends
# Time: 17.33 seconds
#
#
#
# 	18 - Key: d1a72cf18
# Prepaid Expenses Over Time. The table shows prepaid expenses for various categories over the years 2018 and 2019. Notable trends include a decrease in prepaid insurance and prepaid licenses, software tools, and support, while prepaid services and prepaid bonds for German statutory costs have slightly increased. prepaid expenses,  '2018,  '2019,  'insurance,  'services,  'bonds,  'German statutory costs,  'licenses,  'software,  'support
# Time: 11.91 seconds
#
#
#
# 	19 - Key: d1a73c7c4
# Operating Revenues by Product and Service. This table shows the operating revenues for the company in 2018 and 2019, broken down by product and service. Total operating service revenues increased by 2.5% and total operating product revenues increased by 6.5% year-over-year. revenues,  'service,  'product,  '2018,  '2019,  'increase,  'percent change
# Time: 12.71 seconds
#
#
#
# 	20 - Key: d1a73fa6e
# Service Revenue by Region. This table shows the service revenue for the years ended July 27, 2019, July 28, 2018, and July 29, 2017, for the Americas, EMEA, and APJC regions. The table also includes the percentage of service revenue for each region. service revenue,  'Americas,  'EMEA,  'APJC,  '2019,  '2018,  '2017,  'revenue variance,  'percentage of service revenue
# Time: 15.23 seconds
#
#
#
# 	21 - Key: d1a71ea1c
# Average Annual Income by Country (USD). This table shows the average annual income for five countries as of March 31, 2019 and 2018. The United States had the highest income in both years, while the United Kingdom saw a significant increase from 2018 to 2019. average income,  'annual,  '2019,  '2018,  'United States,  'United Kingdom,  'South Africa,  'Australia,  'Other
# Time: 12.88 seconds
#
#
#
# 	22 - Key: d1a71fc46
# Financial Performance Comparison (2019 vs 2018). The table shows the financial performance of the company for the years 2018 and 2019. Key trends include a significant increase in accrued revenue, net revenue, operating expenses, and net income from 2018 to 2019. financial performance,  'accrued revenue,  'net revenue,  'gross margin,  'operating expenses,  'operating income,  'net income
# Time: 18.99 seconds
#
#
#
# 	23 - Key: d1a7200d8
# Net Profit and Loss Analysis. This table provides a breakdown of net profit and loss for the company from 2017 to 2019. Key trends include a significant reversal of impairment losses on tangible, intangible assets, and goodwill in 2019, leading to a net profit of $166.0 million. The net interest expense remains constant at $10.0 million, while net income from operations shows a steady increase from $178.4 million in 2017 to $176.0 million in 2019. net profit,  'loss,  'reversal of impairment losses,  'tangible assets,  'intangible assets,  'goodwill,  'net interest expense,  'net income from operations
# Time: 31.05 seconds
#
#
#
# 	24 - Key: d1a740248
# Financial and User Metrics for the Years 2017-2019. This table shows the number of devices sold, active users, adjusted EBITDA, and net income for the years 2017-2019. The number of devices sold and active users has increased from 2017 to 2019, while adjusted EBITDA and net income have fluctuated. The company experienced a net loss in all three years. devices sold,  'active users,  'adjusted EBITDA,  'net income,  'financial metrics,  'user metrics,  'years 2017-2019
# Time: 17.39 seconds
#
#
#
# 	25 - Key: d1a739434
# Non-current Assets by Region. The table shows the non-current assets of the company for the years 2018 and 2019, broken down by region. The Americas region saw the largest increase in non-current assets, with a growth of approximately 8.3%. Asia Pacific and Europe, Middle East and Africa also experienced growth, but at a slower rate. non-current assets,  'Americas,  'Asia Pacific,  'Europe,  'Middle East,  'Africa,  'growth
# Time: 12.04 seconds
#
#
#
# 	26 - Key: d1a71d82e
# Revenue by Service Line. This table shows the revenue for developed technology, cloud services, and other services for the years ended May 31, 2019 and 2018. The table also includes the percent change and constant percent change for each service line. revenue,  'developed technology,  'cloud services,  'other,  'percent change,  'constant percent change
# Time: 12.51 seconds
#
#
#
# 	27 - Key: d1a73ffe6
# Financial Performance Over Two Periods. This table shows the financial performance of a company over two periods (53 weeks and 52 weeks). Key trends include a 4.3% increase in sales, a 3.9% increase in EBIT, and a 6.4% increase in sales per square metre. financial performance,  'sales,  'EBIT,  'gross margin,  'cost of doing business,  'EBIT to sales,  'sales per square metre
# Time: 13.91 seconds
#
#
#
# 	28 - Key: d1a719d6e
# Financial Instruments Balance Sheet and Cash Flows. This table shows the balance sheet items and cash flows for various financial instruments for Group 2018 and Group 2019. Key trends include significant foreign exchange movements, bond discount amortization, and interest expense. Bonds,  'Bank loans,  'Finance lease liabilities,  'Interest payable,  'Derivative financial instruments,  'Assets,  'Liabilities,  'Cash flows,  'Foreign exchange,  'Amortization,  'Interest expense
# Time: 42.1 seconds
#
#
#
# 	29 - Key: d1a73afdc
# Deferred Tax Assets and Liabilities for Company in 2018. The table shows the changes in deferred tax assets and liabilities for a company in 2018. Key trends include a decrease in deferred tax liabilities and an increase in deferred tax assets, with the total deferred tax assets and liabilities increasing from S$2.1 million to S$11.3 million and S$285.3 million to S$295.3 million respectively. deferred tax assets,  'deferred tax liabilities,  '2018,  'SFRS(I) 15,  'balance,  'credited to income statement,  'accelerated tax depreciation
# Time: 25.07 seconds
#
#
#
# 	30 - Key: d1a72a358
# Application Usage by Category. This table shows the percentage of application usage by category (Communication, Consumer, Computer, Others) for the years 2017, 2018, and 2019. Application,  'Usage,  'Category,  'Communication,  'Consumer,  'Computer,  'Others,  'Percentage,  'Year
# Time: 10.76 seconds
#
#
#
# 	31 - Key: d1a735816
# Financial Statements for Years Ended December 31. This table presents financial statements for the years 2015 to 2019, including revenues, operating income, net income, earnings per share (EPS), dividend per share, working capital, goodwill, total assets, total liabilities, and total equity. revenues,  'operating income,  'net income,  'earnings per share,  'dividend per share,  'working capital,  'goodwill,  'total assets,  'total liabilities,  'total equity
# Time: 24.41 seconds
#
#
#
# 	32 - Key: d1a72d99a
# Financial Comparison for July 27, 2019 and July 28, 2018. Comparison of various financial items for the given dates, with key trends being an increase in loan receivables and financed service contracts, and a decrease in lease receivables. lease receivables,  'loan receivables,  'financed service contracts,  'investments in associates,  'investments in subsidiaries
# Time: 14.95 seconds
#
#
#
# 	33 - Key: d1a73ba68
# Stock Options - Year-End 2018. This table shows the number of shares and their corresponding fair values for various categories of stock options as of December 31, 2018. Key trends include a decrease in the number of forfeited shares and an increase in the fair value of vested shares. stock options,  'shares,  'fair value,  'granted,  'vested,  'forfeited,  'year-end,  '2018
# Time: 12.04 seconds
#
#
#
# 	34 - Key: d1a731c70
# Cash Flow Statement. This table shows the cash flow statement for the company for the years 2018 and 2019. Key trends include a decrease in the balance at the end of the year, an increase in repurchases, and a decrease in stock-based compensation expense. cash flow,  'statement,  'balance,  'year,  '2019,  '2018,  'restricted stock unit,  'stock-based compensation,  'net cash used,  'operating activities,  'investing activities,  'financing activities
# Time: 24.0 seconds
#
#
#
# 	35 - Key: d1a7249da
# Financial Indicators Comparison. Comparison of financial indicators for two different years, showing a decrease in expected volatility and risk-free interest rate, and no change in dividend yield and equity risk premium. financial indicators,  'volatility,  'risk-free interest rate,  'dividend yield,  'equity risk premium
# Time: 10.48 seconds
#
#
#
# 	36 - Key: d1a7127d0
# Remuneration KPIs for 2019. This table shows the actual, threshold, target, and maximum values for various key performance indicators (KPIs) related to remuneration for the Group operating profit, Group cash generation, Group ROCE, and 2017-2019 EPS and ROCE for the Performance Share Plan. remuneration,  'KPIs,  '2019 actual,  '2019 threshold,  '2019 target,  '2019 maximum,  'Group operating profit,  'Group cash generation,  'Group ROCE,  '2017-2019 EPS,  '2017-2019 ROCE,  'Annual Incentive Plan,  'Performance Share Plan
# Time: 20.76 seconds
#
#
#
# 	37 - Key: d1a728c1a
# Revenue by Product and Service for Years Ended July 27, 2019, July 28, 2018, and July 29, 2017. The table shows the revenue for Infrastructure Platforms, Applications, Security, Other Products, and Services for the years ended July 27, 2019, July 28, 2018, and July 29, 2017. Key trends include an increase in total product revenue from 2017 to 2018, followed by a slight decrease in 2019, and a steady increase in services revenue across all years. Revenue,  'Infrastructure Platforms,  'Applications,  'Security,  'Other Products,  'Services,  'Product,  'Year,  'Growth,  'Decrease
# Time: 20.63 seconds
#
#
#
# 	38 - Key: d1a71d310
# Debt Composition. The table shows the composition of the company\ debt,  'composition,  'senior notes,  'maturities,  'interest rates,  'total debt,  'current portion,  'net debt,  '2019,  '2018
# Time: 15.36 seconds
#
#
#
# 	39 - Key: d1a7309a6
# Revenue Breakdown by Business Segment. This table shows the revenue breakdown by business segment for the years 2018 and 2019. The largest segment is VAS, which accounted for 53% and 56% of total revenues in 2019 and 2018 respectively. FinTech and Business Services is the second largest segment, with 27% and 23% of total revenues in 2019 and 2018 respectively. revenue,  'business segment,  'VAS,  'FinTech,  'Online Advertising,  '2019,  '2018
# Time: 16.56 seconds
#
#
#
# 	40 - Key: d1a7362fc
# Stock Share Information. This table shows the number of shares and their corresponding amounts for a company as of June 30, 2017 and 2018. Key trends include an increase in the total number of shares and a decrease in the amount of shares issued for settlement of RSUs. shares,  'amount,  '2017,  '2018,  'RSUs,  'exercise,  'issuance,  'conversion,  'balance
# Time: 12.51 seconds
#
#
#
# 	41 - Key: d1a72c40a
# Fair Value vs Carrying Value of Leases and Note Payable. This table compares the fair value and carrying value of leases and a note payable for two different dates. Key trends include a decrease in the carrying value of leases and note payable from 2018 to 2019, while the fair value of leases increased slightly. leases,  'note payable,  'carrying value,  'fair value,  '2018,  '2019
# Time: 15.07 seconds
#
#
#
# 	42 - Key: d1a71febc
# VMware, Inc. Financial Performance. The table shows the total revenue, net income, and net income per share for VMware, Inc. for the fiscal year 2020, broken down by quarters. Total revenue increased from $2,450 in Q1 to $3,073 in Q4. Net income fluctuated significantly, with a high of $5,303 in Q2 and a low of $321 in Q4. Net income per share also varied, with a high of $12.72 in Q2 and a low of $0.77 in Q4. VMware,  Inc.,  'revenue,  'net income,  'net income per share,  'fiscal year 2020,  'quarters,  'Q1,  'Q2,  'Q3,  'Q4
# Time: 17.94 seconds
#
#
#
# 	43 - Key: d1a719184
# U.S. Taxable Income and Expenses for Fiscal Years Ended March 31. This table shows the U.S. taxable income and expenses for the fiscal years ended March 31, 2019, 2018, and 2017. Key trends include significant changes in U.S. valuation allowance, foreign tax rate differential, and nondeductible expenses related to antitrust litigation. U.S. taxable income,  'U.S. tax expenses,  'fiscal years,  'March 31,  'valuation allowance,  'foreign tax rate,  'antitrust litigation
# Time: 18.09 seconds
#
#
#
# 	44 - Key: d1a730672
# Expenses Over Three Years. This table shows the depreciation and amortization expenses for three consecutive years, with a notable increase in total expenses over the period. expenses,  'depreciation,  'amortization,  'increase,  'trend
# Time: 10.76 seconds
#
#
#
# 	45 - Key: d1a731748
# Revenue Growth Over Time. This table shows the total revenue for a company in millions of dollars for the years 2018 and 2019. The revenue grew by approximately 2.1 billion dollars in one year, with the total revenue in 2019 being 28.6 billion dollars. revenue,  'growth,  '2018,  '2019,  'million,  'dollars
# Time: 12.54 seconds
#
#
#
# 	46 - Key: d1a7326f2
# Revenue by Country for Years Ended September 30. The table shows the revenue for the United States and all other countries for the years ended September 30, 2017, 2018, and 2019. The revenue for the United States has increased from $67,901,000 in 2017 to $78,553,000 in 2019. The revenue for all other countries has fluctuated slightly, from $6,047,000 in 2017 to $6,481,000 in 2019. revenue,  'United States,  'All Other Countries,  'year,  'September 30,  'increase,  'fluctuation
# Time: 17.1 seconds
#
#
#
# 	47 - Key: d1a722202
# Financial Statement Analysis. This table shows the financial performance of a company from 2017 to 2018. Key trends include significant increases in research and development expenses, total assets, and total equity, as well as a stable net income. financial,  'performance,  'research,  'development,  'expenses,  'net income,  'total assets,  'total liabilities,  'total equity
# Time: 32.67 seconds
#
#
#
# 	48 - Key: d1a731306
# Balance Sheet. This table shows the balance sheet of a company as of December 31, 2019 and December 31, 2018. Key trends include an increase in total assets from $1,012.9 to $1,512.8. balance sheet,  'assets,  '2019,  '2018,  'increase
# Time: 11.35 seconds
#
#
#
# 	49 - Key: d1a71b628
# Deferred Income Tax Assets and Liabilities. This table shows the deferred income tax assets and liabilities for the company as of December 31, 2019 and 2018. Key trends include an increase in net deferred income tax assets, a decrease in deferred income tax liabilities, and a shift in deferred income tax assets from noncurrent to current. deferred income tax assets,  'deferred income tax liabilities,  'net deferred income taxes,  'noncurrent,  'current,  '2019,  '2018
# Time: 19.57 seconds
#
#
#
# 	50 - Key: d1a7310a4
# Income Statement. This table shows the income tax benefit, interest expense, and net interest expense for the years 2018 and 2019. The income tax benefit saw a significant increase of 89% from 2018 to 2019, while interest expense and net interest expense remained constant. income tax benefit,  'interest expense,  'net interest expense,  '2018,  '2019,  'increase,  'constant
# Time: 14.88 seconds
#
#
#
# 	51 - Key: d1a72083a
# Share-based payment and employee benefits charges by year and scheme. This table shows the share-based payment and employee benefits charges for various schemes for a company, broken down by year (2018 and 2019) and scheme (SIP, SAYE, PSP, Deferred Annual Bonus and Single Incentive Plan). Key trends include a significant increase in the Total share-based payment charge and Total employee benefits charge from 2018 to 2019. Share-based payment,  'Employee benefits,  'SIP,  'SAYE,  'PSP,  'Deferred Annual Bonus,  'Single Incentive Plan,  '2018,  '2019,  'Charge,  'Increase
# Time: 19.48 seconds
#
#
#
# 	52 - Key: d1a73899e
# Net Cash Flow Statement. This table shows the net cash flow for the company from 2017 to 2019. The company had a net cash provided by operating and investing activities of $224 million in 2019, a decrease from $257 million in 2018, and an increase from $242 million in 2017. The net cash and cash equivalents increased from $408 million in 2017 to $409 million in 2018, and then decreased to $397 million in 2019. Net Cash Flow,  'Operating Activities,  'Investing Activities,  'Financing Activities,  'Balance,  'Cash Provided,  'Cash Used,  'Year Ended June 30
# Time: 31.76 seconds
#
#
#
# 	53 - Key: d1a72f362
# Liabilities Over Two Fiscal Years. This table shows the accrued and other current liabilities, other liabilities, and total liabilities for two fiscal years. The total liabilities have increased significantly from 2018 to 2019. liabilities,  'fiscal year,  'accrued,  'other,  'current,  'increase
# Time: 10.88 seconds
#
#
#
# 	54 - Key: d1a72d184
# Interest and Other Income and Expense. This table shows the interest income, interest expense, other income (expense), and net income for the years 2017, 2018, and 2019. The table indicates a significant decrease in interest expense and other income (expense) from 2017 to 2018, followed by a decrease in other income (expense) and an increase in net income from 2018 to 2019. interest income,  'interest expense,  'other income,  'net income,  'fiscal year,  '2017,  '2018,  '2019
# Time: 23.36 seconds
#
#
#
# 	55 - Key: d1a73e024
# Consolidated Financial Statements. This table presents the consolidated statements of operations and balance sheets for a company from fiscal years 2015 to 2019. Key trends include a significant increase in revenues, gross profit, and total assets, as well as a decrease in net income and stockholders revenues,  'gross profit,  'net income,  'balance sheets,  'consolidated statements,  'fiscal years,  'total assets,  'stockholders' equity
# Time: 15.29 seconds
#
#
#
# 	56 - Key: d1a73ccc4
# Warranty Reserve Over Three Years. This table shows the warranty reserve for three years, with the beginning and end of period amounts, as well as provisions made and charges against the reserve during the period. warranty reserve,  'beginning of period,  'end of period,  'provisions made,  'charges against,  '2017,  '2018,  '2019
# Time: 13.22 seconds
#
#
#
# 	57 - Key: d1a73e402
# Activision Blizzard King Revenue and Operating Income Comparison by Year. This table shows the net revenues from external customers, intersegment net revenues, segment net revenues, and segment operating income for Activision, Blizzard, and King for the years 2017, 2018, and 2019. Key trends include a decrease in net revenues from external customers for all segments from 2017 to 2018, followed by a slight increase in 2019. Operating income also decreased for Activision and Blizzard from 2017 to 2018, but increased for all segments in 2019. Activision,  'Blizzard,  'King,  'Revenue,  'Operating Income,  '2017,  '2018,  '2019
# Time: 23.63 seconds
#
#
#
# 	58 - Key: d1a720542
# Cash Flows from Operating, Investing, and Financing Activities. The table shows the net cash provided or used by operating, investing, and financing activities for two years (2019 and 2018). Key trends include a decrease in net cash from financing activities, an increase in net cash from capital expenditures, and a stable net cash provided by increase in cash and cash equivalents. cash flows,  'operating activities,  'investing activities,  'financing activities,  'net cash,  'acquisitions,  'divestitures,  'capital expenditures
# Time: 41.7 seconds
#
#
#
# 	59 - Key: d1a715e30
# Balance Sheet Comparison (2019 vs 2018). This table compares the balance sheet of the company for May 26, 2019, and May 27, 2018. Key trends include a significant increase in assets for 2019, particularly in property, plant and equipment, goodwill, trademarks and other intangible assets, and other liabilities that will give rise to future tax deductions. There is also a notable increase in liabilities for 2019, primarily in goodwill, trademarks and other intangible assets, and other liabilities. Balance Sheet,  'Assets,  'Liabilities,  '2019,  '2018,  'Property,  plant and equipment,  'Inventory,  'Goodwill,  'Trademarks,  'Intangible assets,  'Accrued expenses,  'Compensation related liabilities,  'Pension and other postretirement benefits,  'Investment in unconsolidated subsidiaries,  'Other liabilities,  'Valuation allowance
# Time: 25.92 seconds
#
#
#
# 	60 - Key: d1a73715c
# Revenue by Region. The table shows the revenue for each region in millions of pounds for the years 2018 and 2019. The UK has the highest revenue, followed by the rest of the world, with all other regions having similar revenue levels. revenue,  'UK,  'Ireland,  'France,  'Germany,  'Spain,  'Italy,  'Rest of Europe,  'Rest of World
# Time: 17.01 seconds
#
#
#
# 	61 - Key: d1a73ab0e
# Stock Compensation by Year. This table shows the total value of stock compensation for a company from 2017 to 2019. Key trends include a decrease in performance share awards from 2017 to 2018, followed by an increase in 2019. Nonvested stock units and stock options have generally decreased from 2017 to 2018, but increased slightly in 2019. stock compensation,  'nonvested stock units,  'stock options,  'performance share awards,  'nonvested restricted stock awards,  'non-management directors’ deferred compensation,  'trends,  '2017,  '2018,  '2019
# Time: 15.97 seconds
#
#
#
# 	62 - Key: d1a72ff9c
# Deferred Tax Assets and Liabilities. This table shows the deferred tax assets and liabilities for the company in 2018 and 2019. Key trends include an increase in deferred revenue, a decrease in deferred tax assets, and a decrease in deferred tax liabilities. deferred tax assets,  'deferred tax liabilities,  '2018,  '2019,  'tax credits,  'accruals,  'pension liabilities,  'inventory valuations,  'deferred revenue,  'equity compensation,  'vacation accrual,  'investment impairment,  'net operating loss carryforwards,  'marketable securities,  'other,  'gross deferred tax assets,  'valuation allowance
# Time: 19.13 seconds
#
#
#
# 	63 - Key: d1a714224
# Net Earnings by Affiliate. This table shows the net earnings for Golar Partners and other affiliates for the years 2017 and 2018. Notably, there was a significant decrease in the share of net earnings for Golar Partners, while there was a substantial increase in the net earnings for other affiliates. net earnings,  'Golar Partners,  'other affiliates,  'decrease,  'increase,  'impairment,  'deemed disposal
# Time: 16.48 seconds
#
#
#
# 	64 - Key: d1a73fcc6
# Salary Changes for Executives. This table shows the annual salaries for four executives in FY18 and FY19, with the change in salary for one executive (Samir Kapuria) also provided. salary,  'executives,  'FY18,  'FY19,  'change,  'annual
# Time: 9.11 seconds
#
#
#
# 	65 - Key: d1a71f084
# Deferred Tax Assets and Liabilities as of December 31. This table shows the changes in deferred tax assets and liabilities from 2018 to 2019. Key trends include a significant increase in deferred tax assets, primarily due to an increase in lease liability and net operating loss carryforward, as well as a decrease in deferred tax liabilities, primarily due to a decrease in debt discount and deferred state taxes. deferred tax assets,  'deferred tax liabilities,  'lease liability,  'net operating loss carryforward,  'debt discount,  'deferred state taxes
# Time: 15.7 seconds
#
#
#
# 	66 - Key: d1a7118d0
# Financial Analysis of R&D, Sales & Marketing, and General & Administrative Expenses. This table shows the financial performance of Research and Development (R&D), Sales and Marketing, and General and Administrative expenses for three years ending on July 27, 2019, July 28, 2018, and July 29, 2017. The table includes the total expenses, percentage of revenue, and the variance in dollars and percentage for each expense category. Overall, there is a 1% increase in total expenses from 2017 to 2019. Financial Analysis,  'R&D,  'Sales and Marketing,  'General and Administrative,  'Expenses,  'Total,  'Variance,  'Dollars,  'Percentage,  'Revenue
# Time: 21.19 seconds
#
#
#
# 	67 - Key: d1a733a98
# Revenue by Market Sector and Reportable Segment. This table shows the total revenue for each market sector (Healthcare/Life Sciences, Industrial/Commercial, Aerospace/Defense, Communications) and reportable segment (AMER, APAC, EMEA) for the fiscal year ended September 28, 2019. Revenue,  'Market Sector,  'Reportable Segment,  'AMER,  'APAC,  'EMEA,  'Healthcare/Life Sciences,  'Industrial/Commercial,  'Aerospace/Defense,  'Communications
# Time: 19.27 seconds
#
#
#
# 	68 - Key: d1a73d944
# Audit and Consulting Fees for Years Ended December 31, 2018 and 2019. This table shows the audit fees, audit-related fees, tax fees, and consulting fees for the years ended December 31, 2018 and 2019. The total fees for 2019 increased from 2018, with the most significant increase in audit fees. audit fees,  'audit-related fees,  'tax fees,  'consulting fees,  'increase,  'decrease,  '2018,  '2019
# Time: 19.0 seconds
#
#
#
# 	69 - Key: d1a724228
# Semiconductor Process Technology Market Share by Nanometer Size, 2017-2019. This table shows the market share of various semiconductor process technologies by nanometer size from 2017 to 2019. The market share for technologies under 14 nanometers has decreased significantly, while the share for 28 nanometers has also decreased but at a slower rate. The 40 nanometer and 65 nanometer categories have experienced a slight decrease, while the 90 nanometer category has seen a significant increase. The 0.11/0.13 micron, 0.15/0.18 micron, 0.25/0.35 micron, and 0.50 micron or higher categories have remained relatively stable. semiconductor,  'process technology,  'market share,  'nanometer,  'micron,  '2017,  '2018,  '2019
# Time: 22.64 seconds
#
#
#
# 	70 - Key: d1a7177a8
# Sales of Oxaydo and Nexafed for the Years 2018 and 2019. The table shows the sales figures for two drugs, Oxaydo and Nexafed, for the years 2018 and 2019. Oxaydo sales decreased from $386 thousand in 2018 to $351 thousand in 2019. Nexafed sales remained constant at $24 thousand for both years. Oxaydo,  'Nexafed,  'sales,  '2018,  '2019,  'decrease,  'constant
# Time: 17.69 seconds
#
#
#
# 	71 - Key: d1a741ec2
# OpenText Earnings Per Share. This table shows the basic and diluted earnings per share (EPS) for OpenText for the years ended June 30, 2019, 2018, and 2017. The table also includes the net income attributable to OpenText and the weighted-average number of shares outstanding. OpenText,  'earnings per share,  'net income,  'weighted-average number of shares outstanding
# Time: 12.77 seconds
#
#
#
# 	72 - Key: d1a73cf94
# Financial Statements. This table presents the financial statements of a company for the years 2017, 2018, and 2019. The company incurred a net loss in all years, with the largest loss in 2017. The loss per common share was highest in 2017 as well. Total assets, liabilities, revenue, and shares outstanding remained constant across the years. net loss,  'loss per common share,  'total assets,  'total liabilities,  'total revenue,  'total shares outstanding
# Time: 29.96 seconds
#
#
#
# 	73 - Key: d1a7265a0
# Global Revenue by Year and Location. This table shows the revenue for the United States and Foreign locations for the years 2017, 2018, and 2019. The trend is a significant decrease in revenue for the United States from 2017 to 2018, followed by a slight increase in 2019. Foreign revenue has been relatively stable over the years. revenue,  'United States,  'Foreign,  'years,  'trend,  'stability
# Time: 14.76 seconds
#
#
#
# 	74 - Key: d1a71a764
# Accounts Receivable Balance Sheet. This table shows the accounts receivable balance sheet for two different years. The total accounts receivable decreased from $68,309 in 2019 to $59,290 in 2018. The provision for doubtful receivables also decreased from $16,377 in 2019 to $16,086 in 2018. Accounts Receivable,  'Balance Sheet,  '2019,  '2018,  'Provision for Doubtful Receivables
# Time: 16.35 seconds
#
#
#
# 	75 - Key: d1a732a94
# Dividend Payments and Shares. This table shows the cents per share, total amount, and date of payment for dividends in the current and prior years. It also includes information about shares issued to satisfy the dividend reinvestment plan and dividends received from shares held in trust. dividends,  'shares,  'payment,  'amount,  'cents per share,  'reinvestment plan,  'trust
# Time: 12.14 seconds
#
#
#
# 	76 - Key: d1a73e6aa
# Financial Income and Expenses. This table shows the breakdown of other financial income and expenses for the years 2017/2018 and 2018/2019. Key trends include a decrease in other financial income and expenses, with currency effects and hedging transactions contributing to these changes. financial income,  'financial expenses,  'currency effects,  'hedging transactions,  'IFRS 9,  'cash flow hedges,  'foreign currency risks,  'interest rate risks
# Time: 15.56 seconds
#
#
#
# 	77 - Key: d1a71fa20
# Balance Sheet - Debt. This table shows the balance sheet of a debt for the years 2018 and 2019. The principal amount remains constant at $300,000. The unamortized debt discount decreases from $4,348 to $2,691. The net carrying amount before unamortized debt issuance costs increases from $295,652 to $297,309. The unamortized debt issuance costs decrease from $6,685 to $4,135. The net carrying amount after unamortized debt issuance costs increases from $288,967 to $293,174. The interest expense remains constant at $14,625. debt,  'balance sheet,  'principal amount,  'unamortized debt discount,  'net carrying amount,  'unamortized debt issuance costs,  'interest expense
# Time: 23.69 seconds
#
#
#
# 	78 - Key: d1a7261ea
# Employee Benefits Expenses. This table shows the expenses for various employee benefits for the years 2018 and 2019. Key trends include an increase in short-term employee benefits, share-based payments, and long-term employee benefits, while termination benefits remained constant. employee benefits,  'expenses,  'short-term,  'share-based payments,  'termination benefits,  'pension contributions,  'long-term
# Time: 11.95 seconds
#
#
#
# 	79 - Key: d1a71da5e
# Operating Expenses of a Company. This table shows the operating expenses of a company for the years 2017/2018 and 2018/2019. Key trends include an increase in wages and salaries, social security expenses, and other operating expenses. Interest expenses remained constant. wages,  'salaries,  'social security,  'post-employment benefits,  'employee benefits,  'operating expenses,  'interest expenses
# Time: 16.49 seconds
#
#
#
# 	80 - Key: d1a739e3e
# Liabilities and Purchase Obligations. This table shows the total liabilities and purchase obligations for a company. The liabilities are broken down into accounts payable, income tax payable, accrued expenses and other payables, lease liabilities, and pension liabilities. The purchase obligations are broken down into purchase commitments to suppliers and capital expenditure and other commitments. liabilities,  'purchase obligations,  'accounts payable,  'income tax payable,  'accrued expenses,  'lease liabilities,  'pension liabilities,  'purchase commitments,  'capital expenditure,  'suppliers
# Time: 15.29 seconds
#
#
#
# 	81 - Key: d1a7250b0
# Equity and Debt Outstanding. This table shows the number of shares of common stock issuable under equity incentive plans outstanding, as well as the amount of convertible senior notes for the years 2017, 2018, and 2019. shares,  'common stock,  'equity incentive plans,  'outstanding,  'year,  '2017,  '2018,  '2019,  'convertible senior notes
# Time: 11.11 seconds
#
#
#
# 	82 - Key: d1a7138d8
# Outstanding Obligations and Commitments. The table shows the outstanding obligations and commitments of a company, categorized by payment due period and type of obligation. Key trends include high amounts for Term Loan Facility, Revolving Credit Facility, and Senior Notes. obligations,  'commitments,  'payments,  'due,  'period,  'less,  'than,  '1 year,  '1 – 3 years,  '3 – 5 years,  'more,  'than,  '5 years,  'operating lease obligations,  'capital purchase obligations,  'other purchase obligations,  'term loan facility,  'revolving credit facility,  'senior notes,  'senior convertible debt,  'pension obligations,  'transition tax obligation
# Time: 18.36 seconds
#
#
#
# 	83 - Key: d1a72135c
# Restaurant Financial Performance. The table shows the financial performance of a restaurant chain from 2018 to 2019. Key trends include a decrease in restructuring costs, an increase in costs of closed restaurants and other, and a significant increase in operating restaurant impairment charges in 2019. There is also a notable decrease in accelerated depreciation and gains/losses on disposition of property and equipment, net. Restaurant,  'Financial,  'Performance,  'Restructuring,  'Costs,  'Closed,  'Restaurants,  'Depreciation,  'Impairment,  'Gains,  'Losses
# Time: 15.62 seconds
#
#
#
# 	84 - Key: d1a736054
# Financial Statements Comparison. Comparison of financial statements for the years 2017, 2018, and 2019. Key trends include a decrease in net income and gross margin percentage, and an increase in revenue. revenue,  'cost of goods sold,  'gross margin,  'operating income,  'net income,  'year,  '2017,  '2018,  '2019
# Time: 20.21 seconds
#
#
#
# 	85 - Key: d1a7289ae
# 2018 FULL-YEAR RESULTS COMPARED TO 2017. Comparison of various financial metrics for the years 2018 and 2017. Key trends include a 5% increase in total revenue, a 9% increase in Adjusted EBITDA, and an 12% increase in net income. revenue,  'ebitda,  'net income,  'capital expenditures,  'free cash flow,  '2018,  '2017
# Time: 27.21 seconds
#
#
#
# 	86 - Key: d1a73c530
# Financial Statement - Losses and Income. This table shows the financial losses and income for the year ended December 31, 2019, compared to 2018. Key trends include an increase in interest expense, a decrease in interest income, and a significant increase in other loss. Interest expense,  'Interest income,  'Losses,  'Income,  '2019,  '2018,  'Foreign exchange,  'Derivative instruments,  'Deconsolidation,  'Altera
# Time: 14.36 seconds
#
#
#
# 	87 - Key: d1a7161fa
# Financial Statements. This table shows the financial statements of a company for the years 2015 to 2019. Key trends include an increase in net sales, operating income, and net income, as well as a decrease in working capital and stockholders’ equity. net sales,  'operating income,  'net income,  'working capital,  'stockholders’ equity,  'financial statements
# Time: 13.17 seconds
#
#
#
# 	88 - Key: d1a72e818
# Financial Statements. This table shows the financial statements of a company for the years ended March 31, with key trends including a decrease in net income and operating income, and an increase in total revenue. Financial Statements,  'Net Income,  'Operating Income,  'Total Revenue
# Time: 34.02 seconds
#
#
#
# 	89 - Key: d1a736f40
# Net Periodic Benefit Cost. This table shows the net periodic benefit cost for the company from 2018 to 2019. The main trends are a significant decrease in total net periodic benefit cost (84.9%), a decrease in other components of net periodic benefit cost (79.6%), and an increase in interest income (28.7%). net periodic benefit cost,  'interest income,  'other components,  'debt extinguishment costs,  'decrease,  'increase
# Time: 15.18 seconds
#
#
#
# 	90 - Key: d1a728e36
# Precious Metals Prices. This table shows the prices of copper, gold, and silver in pounds, Troy ounces, and dollars for the fiscal years 2018 and 2019. Key trends include a slight increase in copper prices, a significant increase in gold prices, and a moderate increase in silver prices. copper,  'gold,  'silver,  'prices,  'fiscal,  'years,  '2018,  '2019
# Time: 12.77 seconds
#
#
#
# 	91 - Key: d1a740c66
# Cash Flow Statement. This table shows the cash flow statement for the company from fiscal years 2017 to 2019. The net cash provided by operating activities improved significantly from 2017 to 2018, but decreased slightly in 2019. Investing activities saw a decrease in cash provided from 2017 to 2018, but increased in 2019. Financing activities showed a net cash used in all three years. The effect of exchange rate changes on cash and cash equivalents was positive in 2019, but negative in 2018. cash flow,  'operating activities,  'investing activities,  'financing activities,  'exchange rate changes,  'cash and cash equivalents
# Time: 24.68 seconds
#
#
#
# 	92 - Key: d1a735078
# Interest Rate and Volatility Over Time. The table shows the risk-free interest rate, expected life, and expected volatility for three years (2017, 2018, and 2019). The interest rate has increased from 0.94%-2.14% in 2017 to 2.68% in 2019. The expected volatility has decreased from 35.25%-40.22% in 2017 to 32.42% in 2018, but slightly increased to 32.42% in 2019. interest rate,  'volatility,  'time,  'trend,  'finance
# Time: 16.03 seconds
#
#
#
# 	93 - Key: d1a739632
# Financial Summary. The table shows financial figures for 2019 and 2018. Key trends include a significant decrease in accrued interest and accrued expenses, while settlement deferred compensation liabilities remain stable. Accrued Interest,  'Accrued Expenses,  'Settlement Deferred Compensation Liabilities,  'Settlement Deferred Compensation Expenses,  '2019,  '2018
# Time: 12.59 seconds
#
#
#
# 	94 - Key: d1a727e1e
# Revenue and Operating Income by Year. This table shows the revenue and operating income for Products and Licensing, Technology Development, and Total for the years 2018 and 2019. Revenue,  'Operating Income,  'Products and Licensing,  'Technology Development,  '2018,  '2019
# Time: 19.72 seconds
#
#
#
# 	95 - Key: d1a717032
# Financial Adjustments and Income Trends. This table shows the financial adjustments and income trends for the company from 2015 to 2019. Key trends include a significant increase in adjusted EBITDA from 2015 to 2019, a decrease in net income from 2018 to 2019, and a decrease in total adjustments from 2018 to 2019. Keywords: Adjusted EBITDA, Net income, Interest expense, Income taxes, Amortization and depreciation expense, Stock-based compensation expense, Acquisition-related expense, Litigation expense, Total adjustments. Adjusted EBITDA,  'Net income,  'Interest expense,  'Income taxes,  'Amortization and depreciation expense,  'Stock-based compensation expense,  'Acquisition-related expense,  'Litigation expense,  'Total adjustments
# Time: 21.8 seconds
#
#
#
# 	96 - Key: d1a7253e4
# ...
# Time: 16.53 seconds
#
#
#
# 	220 - Key: d1a713c66
# Reconciliation of Non-GAAP Measure - Operating Expenses and Operating Income from Continuing Operations. This table shows the reconciliation of Non-GAAP measure for operating expenses and operating income from continuing operations for the years 2018 and 2019. Key trends include a decrease in Non-GAAP gross margin and an increase in Non-GAAP operating margin. Non-GAAP,  'gross profit,  'operating expenses,  'operating income,  '2018,  '2019,  'stock-based compensation,  'amortization of intangible assets,  'acquisition-related costs,  'facility expansion and relocation costs,  'restructuring charges
# Time: 30.72 seconds
#
#
#
# 	221 - Key: d1a7131e4
# Jabil Inc. Financial Performance. This table shows the financial performance of Jabil Inc. for the fiscal years 2018 and 2019. Key trends include an increase in net revenue and net income from November 2018 to August 2019, with a decrease in operating income during the same period. Jabil Inc.,  'financial performance,  'net revenue,  'gross profit,  'operating income,  'net income,  'earnings per share
# Time: 15.11 seconds
#
#
#
# 	222 - Key: d1a73bfc2
# Deferred Tax Assets and Liabilities. This table shows the changes in deferred tax assets and liabilities from December 31, 2018 to December 31, 2019. Notable trends include a decrease in deferred tax assets and an increase in income taxes payable. deferred tax assets,  'deferred tax liabilities,  'income taxes payable,  'reserves and accruals,  'research and development credits,  'net operating loss carry forward,  'stock based compensation,  'valuation allowance
# Time: 23.61 seconds
#
#
#
# 	223 - Key: d1a72471e
# Financial Performance Comparison. Comparison of financial performance between September 30, 2018, and September 30, 2017. Key trends include a decrease in net sales, income from operations, and net income, as well as a decrease in net income per share (both basic and diluted). financial performance,  'net sales,  'income from operations,  'net income,  'net income per share,  'comparison,  '2018,  '2017
# Time: 13.35 seconds
#
#
#
# 	224 - Key: d1a71e79c
# Revenue and Operating Expenses for Data Centre Services from 30 June 2018 to 30 June 2019. The table shows the revenue and operating expenses for data centre services from 30 June 2018 to 30 June 2019. The total revenue increased from $161,529 in 2018 to $179,260 in 2019, driven by an increase in data centre services revenue and other revenue. The operating expenses also increased from $136,456 in 2018 to $144,426 in 2019. The operating income increased from $25,073 in 2018 to $34,834 in 2019. revenue,  'operating expenses,  'data centre services,  'increase,  '2018,  '2019,  'gains
# Time: 25.2 seconds
#
#
#
# 	225 - Key: d1a736cca
# Net Derivative Gains and Losses. This table shows the net derivative gains and losses for various reporting segments and corporate expenses for three fiscal years. Net derivative gains,  'Net derivative losses,  'Fiscal Years Ended,  'Grocery & Snacks,  'Refrigerated & Frozen,  'International Foods,  'Foodservice,  'Pinnacle Foods,  'Commercial,  'Other
# Time: 14.29 seconds
#
#
#
# 	226 - Key: d1a723a30
# Revenue Breakdown by Year. This table shows the breakdown of revenue for the company from 2017 to 2019. Subscription revenue is the primary source of income, with a steady increase from 2017 to 2019. Professional services revenue has fluctuated over the years, with a decrease in 2018 and an increase in 2019. revenue,  'subscription,  'professional services,  'growth,  '2017,  '2018,  '2019
# Time: 17.2 seconds
#
#
#
# 	227 - Key: d1a72c798
# U.S. Company Tax Expense and Credits. This table shows the federal statutory tax expense, valuation allowance, foreign taxes at rates greater (less) than U.S. rates, net, stock-based compensation, state income taxes, net of federal income tax benefit, research and development credit, deferred compensation, release of unrecognized tax benefits, release of interest accrued for unrecognized tax benefits, U.S. tax reform impact, deferred taxes on foreign earnings, write-off of withholding tax credits, and other, net for the years 2017, 2018, and 2019. tax expense,  'credits,  'federal,  'statutory,  'valuation allowance,  'foreign taxes,  'stock-based compensation,  'state income taxes,  'research and development credit,  'deferred compensation,  'unrecognized tax benefits,  'U.S. tax reform impact,  'deferred taxes on foreign earnings,  'write-off of withholding tax credits,  'other
# Time: 23.47 seconds
#
#
#
# 	228 - Key: d1a72bce4
# Financial Performance Over Two Years. This table shows the financial performance of a company over two years, with a focus on changes in cost of revenues, gross profit, operating expenses, and operating income. The company experienced a decrease in cost of revenues, gross profit, and operating income, while operating expenses increased slightly. financial performance,  'cost of revenues,  'gross profit,  'operating expenses,  'operating income,  'decrease,  'increase
# Time: 15.44 seconds
#
#
#
# 	229 - Key: d1a715a70
# Stock-Based Compensation by Type of Award. This table shows the stock-based compensation by type of award for the years ended December 31, 2019 and 2018. The key trend is a decrease in stock options and RSUs from 2018 to 2019. stock-based compensation,  'type of award,  'stock options,  'RSUs,  'other,  'decrease,  '2019,  '2018
# Time: 13.71 seconds
#
#
#
# 	230 - Key: d1a7322b0
# Net Income Attributable to Common Shareholders. This table shows the net income (loss) attributable to common shareholders for the years 2017, 2018, and 2019. The table shows a significant decrease in net income from 2017 to 2018, followed by a slight increase in 2019. The net income per common share also shows a similar trend. net income,  'common shareholders,  '2017,  '2018,  '2019,  'decrease,  'increase
# Time: 16.69 seconds
#
#
#
# 	231 - Key: d1a71a9bc
# Net Earnings from Operations and EPS. This table shows the net earnings from operations and earnings per share (EPS) for the years 2018 and 2019. The net earnings from operations increased significantly from 157,133 in 2018 to 329,013 in 2019. The basic net earnings per share (EPS) also increased from 3.00 in 2018 to 6.66 in 2019, while the diluted EPS increased from 2.95 to 6.54. net earnings,  'operations,  'net income per common share,  'basic net earnings per share,  'diluted net earnings per share,  '2018,  '2019
# Time: 20.42 seconds
#
#
#
# 	232 - Key: d1a711510
# Current Assets and Liabilities. This table shows the current assets and liabilities of the company, with and without the adoption of Topic 606. Key trends include a decrease in total current liabilities due to adjustments. current assets,  'current liabilities,  'Topic 606,  'receivables,  'inventories,  'prepaid expenses,  'other accrued liabilities,  'deferred income tax liabilities
# Time: 15.59 seconds
#
#
#
# 	233 - Key: d1a734e2a
# Deferred Income Tax Assets and Liabilities. This table shows the deferred income tax assets and liabilities for the company as of March 31, 2019 and March 31, 2018. Key trends include a decrease in deferred tax liabilities and an increase in deferred tax assets, particularly in deferred revenue and share-based payments. deferred income tax assets,  'deferred income tax liabilities,  'deferred revenue,  'carry forward losses,  'UK subsidiaries,  'overseas subsidiaries,  'advanced capital allowances,  'share-based payments,  'temporary differences
# Time: 15.83 seconds
#
#
#
# 	234 - Key: d1a741756
# Stock Ownership of Directors and Named Executive Officers. Table shows the number of shares and percentage owned by directors and named executive officers of the company, as well as the total ownership of officers and directors as a group. It also lists the top two institutional shareholders. stock ownership,  'directors,  'named executive officers,  'shares,  'percentage,  'Benchmark Capital Partners VI,  L.P,  'DAG Ventures
# Time: 12.91 seconds
#
#
#
# 	235 - Key: d1a726870
# Financial Overview of Company. This table shows the total bookings, total customers, and total employees for the years 2015 to 2019. Total bookings have increased from $1,914.2 million in 2015 to $3,401.2 million in 2019. The number of total customers has also grown from 13,774 thousand in 2015 to 19,274 thousand in 2019. The total number of employees has increased from 788 thousand in 2015 to 1,022 thousand in 2019. bookings,  'customers,  'employees,  'growth,  'year,  'financial
# Time: 20.42 seconds
#
#
#
# 	236 - Key: d1a7334da
# Deferred Tax Assets and Liabilities. This table shows the deferred tax assets and liabilities for the company in 2018 and 2019. Key trends include a decrease in deferred tax liabilities and an increase in deferred tax assets, particularly in employee benefits, inventory, and accounts receivable. deferred tax assets,  'deferred tax liabilities,  'employee benefits,  'inventory,  'accounts receivable,  'property,  plant and equipment,  'other liabilities,  'deferred state income tax,  'valuation allowance
# Time: 16.65 seconds
#
#
#
# 	237 - Key: d1a731a4a
# Product Sales and Growth. This table shows the sales of various products for the years 2018 and 2019, along with the percentage change between the two years. Key trends include significant growth in Altium Designer licenses, Octopart search advertising, and TASKING licenses, as well as a decrease in service sales. Product Sales,  'Altium Designer,  'TASKING,  'Octopart,  'growth,  'decrease,  '2018,  '2019
# Time: 13.01 seconds
#
#
#
# 	238 - Key: d1a72a812
# Trade Receivables. This table shows the balance of trade receivables for the company, including billed and unbilled amounts, as well as the allowance for doubtful accounts. The total trade receivables increased slightly from 2018 to 2019, while the allowance for doubtful accounts remained the same. trade receivables,  'billed,  'unbilled,  'allowance for doubtful accounts,  '2019,  '2018
# Time: 14.0 seconds
#
#
#
# 	239 - Key: d1a73d426
# Regional Market Share of Global Revenue (2017-2019). This table shows the market share of global revenue for different regions from 2017 to 2019. Taiwan and Singapore have maintained a steady market share, while China, Japan, USA, Europe, and Others have seen fluctuations. market share,  'global revenue,  'Taiwan,  'Singapore,  'China,  'Japan,  'USA,  'Europe,  'Others
# Time: 12.46 seconds
#
#
#
# 	240 - Key: d1a72e1ec
# Global Revenue by Region (2017-2019). This table shows the revenue for various regions from 2017 to 2019. The United States has the highest revenue, followed by Europe, Middle East and Africa. Asia and Pacific Rim, South America, Canada, and All other regions follow in descending order. revenue,  'global,  'regions,  '2017,  '2018,  '2019,  'United States,  'Europe,  'Middle East,  'Africa,  'South America,  'Canada,  'Asia,  'Pacific Rim,  'All other
# Time: 15.78 seconds
#
#
#
# 	241 - Key: d1a711fd8
# Capital Expenditures and Capital Intensity by Business Segment. This table shows the capital expenditures and capital intensity for the wireless, cable, media, and corporate segments of a company for the years 2018 and 2019. The wireless segment saw a significant increase in capital expenditures and capital intensity, while the cable segment experienced a decrease in both areas. The media and corporate segments showed modest growth in capital expenditures and capital intensity. capital expenditures,  'capital intensity,  'wireless,  'cable,  'media,  'corporate,  'growth,  'decrease
# Time: 25.05 seconds
#
#
#
# 	242 - Key: d1a72fbe6
# Financial Income and Costs. This table shows the financial income and costs for the years 2017, 2018, and 2019. Key trends include an increase in total financial income and a significant increase in total financial costs. financial income,  'interest income,  'total financial income,  'financial costs,  'amortization,  'interest expense,  'lease charge,  'loss arising on bond repurchases,  'unrealized foreign exchange losses
# Time: 16.21 seconds
#
#
#
# 	243 - Key: d1a712ec4
# FY19 EAIP NEO Payout Amounts. Table shows the base salary, annual incentive target, company performance funding, individual performance factor, and individual payout amount for select NEOs. FY19,  'EAIP,  'NEO,  'payout,  'amounts,  'base salary,  'annual incentive,  'company performance,  'individual performance,  'Gregory S. Clark,  'Nicholas R. Noviello,  'Amy L. Cappellanti-Wolf,  'Samir Kapuria
# Time: 14.54 seconds
#
#
#
# 	244 - Key: d1a734402
# Company Financial Analysis 2018-2019. This table shows the company\ financial analysis,  'expenses,  '2018,  '2019,  'salaries,  'wages,  'benefits,  'professional fees,  'acquisition costs,  'board compensation,  'investor relations,  'consultants,  'advertising,  'depreciation,  'research,  'development,  'maintenance,  'integration incentives,  'office,  'facility,  'travel,  'stock-based compensation,  'total compensation expense
# Time: 21.11 seconds
#
#
#
# 	245 - Key: d1a7337aa
# Financial Obligations Over Time. This table shows the financial obligations of the company over different periods. The main obligations are operating lease obligations, purchase obligations, liability for uncertain tax positions, and investment commitments. The table shows a significant increase in operating lease obligations from 2020 to 2023, followed by a decrease in 2025 and thereafter. Purchase obligations are expected to decrease from 2021 to 2022, with a small increase in 2023, and a significant decrease thereafter. Liability for uncertain tax positions is a one-time payment in 2023. Investment commitments are minimal for the next few years. financial obligations,  'operating lease obligations,  'purchase obligations,  'liability for uncertain tax positions,  'investment commitments,  '2020,  '2021,  '2022,  '2023,  '2024,  '2025,  'thereafter
# Time: 21.02 seconds
#
#
#
# 	246 - Key: d1a716452
# Target Allocations of Plan Assets. This table shows the percentage of plan assets allocated to different asset categories for the years 2018, 2019, and 2020. The allocation to equity securities and debt securities remains relatively stable, while the allocation to other categories remains consistent across all years. Target Allocations,  'Plan Assets,  'Equity securities,  'Debt securities,  'Other,  'Percentage,  '2018,  '2019,  '2020
# Time: 13.26 seconds
#
#
#
# 	247 - Key: d1a71cca8
# Post-employment Benefit Obligations for DB Pension Plans and OPEB Plans. The table shows the post-employment benefit obligations for DB pension plans and OPEB plans for the years 2018 and 2019. Key trends include a decrease in the discount rate, a constant rate of compensation increase, and a constant cost of living indexation rate. The actuarial present value of benefits decreased from $900,000,000 in 2018 to $1,000,000,000 in 2019. DB Pension Plans,  'OPEB Plans,  'Post-employment Benefit Obligations,  'Discount Rate,  'Rate of Compensation Increase,  'Cost of Living Indexation Rate,  'Actuarial Present Value of Benefits,  '2018,  '2019
# Time: 21.48 seconds
#
#
#
# 	248 - Key: d1a71be0c
# Pension Plan Financial Analysis. This table shows the financial analysis of a pension plan for the years 2017, 2018, and 2019. Key trends include a decrease in the discount rate and an increase in the rate of compensation increase. The expected long-term return on plan assets varies across sections, with a decrease from 2017 to 2018 and an increase from 2018 to 2019. pension,  'financial analysis,  'net periodic benefit cost,  'expected long-term return on plan assets,  'rate of compensation increase,  'discount rate,  'projected benefit obligation,  'actual return on plan assets
# Time: 20.37 seconds

# %%
dataset = "TATQA"
table_dict = np.load(f'table_summaries_{dataset}_short.npy', allow_pickle='TRUE').item()
len(table_dict)
# Out:
# 248

# %% [markdown]
# ----------------------------------------------------------------------------

# %%
# create_summaries("FinQA", template_long, "long")
# Out:
# CREATING SUMMARIES FOR FinQA, with template:
# You are a finance expert specialized in analyzing financial tables.
#
# ### Task ###
# Analyze the table and transcribe its contents into a well-structured summary. Generate a detailed paragraph that captures all relevant information, including numerical data, trends, and observations.
# If the table contains acronyms, provide their concise definitions where possible.
# Return the output in the form of a dictionary with the following keys:
# - 'title': A concise title for the table.
# - 'description': A brief description of the table's contents and key trends.
# - 'keywords': A list of the most relevant keywords of the table.
#
# **Note**: Do not return the table, prompt, or any extra text. Return only the dictionary.
#
# ### Table ###
#
#
#
#
# Loaded extracted_tables_FinQA, it has 247 tables to process
#
#
#
# 	1 - Key: d6167ace8
# Revenue (in millions) for the years ending December 31, 2018-2022. The table displays the revenue figures (in millions) for the years 2018 to 2022. A significant decline in revenue is observed from 2018 to 2020, with a drop from $64 million to $52 million. However, a slight recovery is noted in 2021 with a revenue of $19 million, followed by a further increase in 2022 to $25 million. revenue,  'millions,  '2018,  '2019,  '2020,  '2021,  '2022,  'decline,  'recovery
# Time: 20.85 seconds
#
#
#
# 	2 - Key: d61650380
# Revenue Growth Over Time (in millions, as of December 2015). The table displays the revenue growth of a company from 2016 to 2021 and beyond, with the data presented in millions and as of December 2015. The revenue has shown a downward trend from 2016 to 2019, with a significant drop from 2019 to 2020. However, there is a projected increase in revenue from 2021 onwards. revenue,  'growth,  'trend,  '2016,  '2017,  '2018,  '2019,  '2020,  '2021,  'millions,  'decrease,  'increase
# Time: 17.67 seconds
#
#
#
# 	3 - Key: d6166eb32
# Net Revenue and Cost Breakdown for Years 2003-2005. The table presents the net revenue and cost breakdown for three consecutive years (2003-2005). Key trends include a steady increase in net revenue from $973.7 million in 2003 to $988.6 million in 2005. Costs such as price applied to unbilled sales, deferred fuel cost revisions, and rate refund provisions show a consistent decrease in expenses over the years. Weather-related volume and summer capacity charges also exhibit an upward trend. Other costs remain relatively stable. net revenue,  'costs,  'price applied to unbilled sales,  'deferred fuel cost revisions,  'rate refund provisions,  'volume/weather,  'summer capacity charges,  'other
# Time: 32.75 seconds
#
#
#
# 	4 - Key: d616785a6
# Long-term debt maturities and obligations. This table presents the maturities of long-term debt, debt obligations with right of offset, lease obligations, purchase obligations, and the total of these categories from 2010 to thereafter. Notably, there is a significant increase in long-term debt maturities, purchase obligations, and the total from 2010 to 2014, followed by a steady increase thereafter. Lease obligations and debt obligations with right of offset show a decrease from 2010 to 2014, with a slight increase thereafter. long-term debt,  'maturities,  'debt obligations,  'right of offset,  'lease obligations,  'purchase obligations,  'total,  'increase,  'decrease
# Time: 18.71 seconds
#
#
#
# 	5 - Key: d61655808
# Financial Balance Sheet for 2005-2007. This table presents the financial balance sheet for the years 2005-2007. It includes expenses, cash payments, foreign currency revaluation, and the balance at the beginning and end of each year. Notable trends include a decrease in cash payments from 2005 to 2006, followed by a slight increase in 2007. Expenses increased from 2005 to 2006, but decreased in 2007. Foreign currency revaluation resulted in a loss in 2005 and 2006, but a gain in 2007. expenses,  'cash payments,  'foreign currency revaluation,  'balance,  '2005,  '2006,  '2007
# Time: 19.87 seconds
#
#
#
# 	6 - Key: d616540de
# Cash Flows from Operating, Investing, and Financing Activities. The table presents cash flows from operating, investing, and financing activities for three consecutive years (2010, 2009, and 2008). The table shows a decrease in net cash provided by operating activities from $559.7 million in 2009 to $455.6 million in 2010. Cash flows provided by investing activities have significantly decreased from -581.4 million in 2009 to -418.0 million in 2010. Financing activities have shown a consistent negative trend, with net cash used in financing activities increasing from -459.6 million in 2008 to -205.5 million in 2010. Overall, net cash provided by operating, investing, and financing activities decreased from $627.6 million in 2008 to $195.4 million in 2010. cash flows,  'operating activities,  'investing activities,  'financing activities,  'net cash,  'millions,  'trend,  'decrease,  'increase
# Time: 37.92 seconds
#
#
#
# 	7 - Key: d616760d0
# Financial Analysis of Costs and Expenses. The table presents the costs and expenses of a company for three fiscal years ended March 31, 2018, 2017, and 2016. The costs are broken down into six categories: costs of services (excluding depreciation, amortization, and restructuring costs), selling, general, and administrative expenses (excluding depreciation, amortization, and restructuring costs), depreciation and amortization, restructuring costs, interest expense net, debt extinguishment costs, and other income net. The table shows a significant increase in total costs and expenses from 2016 to 2017, with a slight decrease from 2017 to 2018. Keywords: costs, expenses, depreciation, amortization, restructuring, interest expense, debt extinguishment, other income. costs,  'expenses,  'depreciation,  'amortization,  'restructuring,  'interest expense,  'debt extinguishment,  'other income
# Time: 26.53 seconds
#
#
#
# 	8 - Key: d61660f64
# Financial Performance Over Three Years. This table presents the financial performance of a company over a three-year period, from 2004 to 2006. The table includes six categories of financial data, with values given in millions. The key trends observed are a decrease in unrealized gain ( loss ) on hedges of net investments in non-U.S. subsidiaries, a decrease in unrealized loss on available-for-sale securities, and an increase in total. The acronyms used are FXTT (Foreign Currency Translation), UGHNINUS (Unrealized Gain ( Loss ) on Hedges of Net Investments in Non-U.S. Subsidiaries), ULAS (Unrealized Loss on Available-for-Sale Securities), MPL (Minimum Pension Liability), ULCFH (Unrealized Loss on Cash Flow Hedges), and TOTAL (Total). Financial Performance,  'Three Years,  '2004,  '2005,  '2006,  'Foreign Currency Translation,  'Unrealized Gain ( Loss ),  'Hedges,  'Net Investments,  'Non-U.S. Subsidiaries,  'Unrealized Loss,  'Available-for-Sale Securities,  'Minimum Pension Liability,  'Unrealized Loss on Cash Flow Hedges,  'Total
# Time: 29.24 seconds
#
#
#
# 	9 - Key: d61650524
# Stock Price Performance of Altria Group Inc. and S&P 500 from December 2011 to December 2020. The table displays the stock price performance of Altria Group Inc., its peer group, and the S&P 500 index from December 2011 to December 2020. Over this period, Altria Group Inc. showed a significant increase in stock price, with the highest value recorded in December 2020 at $550.00. The peer group of Altria Group Inc. also experienced growth, with the highest value recorded in December 2020 at $262.00. The S&P 500 index also showed growth, with the highest value recorded in December 2020 at $278.28. Altria Group Inc.,  'stock price,  'peer group,  'S&P 500,  'performance,  'growth,  'decrease,  'increase,  'December,  '2011,  '2020
# Time: 34.64 seconds
#
#
#
# 	10 - Key: d6165a4d4
# Financial Performance of Global Banking Sectors (2006-2007). The table presents the financial performance of three sectors in the banking industry for the years 2006 and 2007. The sectors are global cards, consumer banking, and icg. The table shows the pretax and after-tax totals for each sector and year in millions of dollars. The global cards sector saw a significant increase in both pretax and after-tax totals from 2006 to 2007. Consumer banking also experienced growth in both categories, while icg showed a slight increase in after-tax total but a decrease in pretax total. The total for all sectors also increased in both years. financial performance,  'global cards,  'consumer banking,  'icg,  'pretax total,  'after-tax total,  '2006,  '2007,  'millions of dollars
# Time: 19.69 seconds
#
#
#
# 	11 - Key: d6168290c
# Tax Positions Balance Sheet. The table presents the balance sheet of tax positions for two different years. The balance at the beginning of the year, additions and reductions based on tax positions related to prior and current periods, reductions related to settlements with tax authorities, and expiration of statute of limitations are included. Notably, there is a significant increase in additions based on tax positions related to the current period from 2007 to 2008, while there is a decrease in reductions based on tax positions related to prior years. Additionally, there is a settlement with tax authorities in 2007 that resulted in a reduction of $7.6. tax positions,  'balance sheet,  'additions,  'reductions,  'prior years,  'current period,  'settlements with tax authorities,  'statute of limitations
# Time: 19.18 seconds
#
#
#
# 	12 - Key: d6165f736
# Total Expense and Tax Benefit Related to Awards. The table presents the total expense pre-tax, tax benefit related to awards, and total expense net of tax for the years ended December 31, 2015, 2014, and 2013. The total expense pre-tax decreased from $49.4 in 2014 to $46.4 in 2015, while the total expense net of tax decreased from $33.9 in 2014 to $31.9 in 2015. The tax benefit related to awards remained constant at -$15.6 for all three years. total expense pre-tax,  'tax benefit related to awards,  'total expense net of tax,  'years ended December 31,  'decrease
# Time: 17.94 seconds
#
#
#
# 	13 - Key: d6165cdec
# Loans and Unearned Income Balance Sheet. The table presents a balance sheet for loans and unearned income for the years 2006 and 2007. The total loans increased from $50,900 million in 2006 to $69,309 million in 2007. The commercial loan category saw the most significant increase, rising from $20,584 million to $28,607 million. The residential mortgage category also experienced growth, from $6,337 million to $9,557 million. Unearned income decreased from -$795 million in 2006 to -$990 million in 2007. loans,  'unearned income,  'commercial,  'commercial real estate,  'consumer,  'residential mortgage,  'lease financing,  'other,  'total loans,  'balance sheet,  'increase,  'decrease,  'millions
# Time: 21.35 seconds
#
#
#
# 	14 - Key: d61651758
# Financial Performance of U.S. and Non-U.S. Operations. The table presents the financial performance of U.S. and Non-U.S. operations for the years 2010, 2009, and 2008. Key trends include a significant increase in net income for the U.S. operations from 2009 to 2010, while Non-U.S. operations saw a decrease in net income during the same period. The table also shows a decrease in income tax expense for all years compared to 2008. Financial Performance,  'U.S.,  'Non-U.S.,  'Net Income,  'Income Tax Expense,  '2010,  '2009,  '2008
# Time: 25.99 seconds
#
#
#
# 	15 - Key: d61658206
# Stock Price Performance from 2010 to 2015. The table displays the stock price performance of four entities from January 2, 2010, to January 3, 2015. The entities are Cadence Design Systems Inc., Nasdaq Composite, S&P 400 Information Technology, and S&P 500. The table shows the stock prices on specific dates: December 31, 2011, December 29, 2012, December 28, 2013, and January 3, 2015. The stock prices have shown an overall upward trend, with the highest price recorded for Cadence Design Systems Inc. on January 3, 2015, at $314.36. stock price,  'performance,  'Cadence Design Systems Inc.,  'Nasdaq Composite,  'S&P 400 Information Technology,  'S&P 500,  'trend,  'upward,  '2010,  '2011,  '2012,  '2013,  '2015
# Time: 29.37 seconds
#
#
#
# 	16 - Key: d61665460
# Balance Sheet with SFAF No. 158 Adjustments. The table presents a balance sheet with and without the application of SFAF No. 158. The table shows changes in various asset categories, including other assets, deferred income tax liability, accrued pensions, other postretirement benefits, and accumulated other comprehensive loss. The application of SFAF No. 158 results in an increase in total assets from $1000 to $1000. balance sheet,  'SFAF No. 158,  'assets,  'deferred income tax liability,  'accrued pensions,  'other postretirement benefits,  'accumulated other comprehensive loss,  'increase
# Time: 18.97 seconds
#
#
#
# 	17 - Key: d616556b4
# Equity Compensation Plans Approved and Not Approved by Security Holders. The table provides a breakdown of equity compensation plans approved and not approved by security holders. The table includes the number of securities to be issued upon exercise of outstanding options (a), the weighted-average exercise price of outstanding options (b), and the number of securities remaining available for future issuance under equity compensation plans (excluding securities reflected in column (a)) (c). The table shows that a total of 12,171,213 securities are involved in these plans, with 12,111,433 securities approved by security holders and an average exercise price of $308.10, and 5978 securities not approved by security holders with an average exercise price of $22.00. equity compensation plans,  'security holders,  'number of securities,  'exercise price,  'approved,  'not approved
# Time: 20.84 seconds
#
#
#
# 	18 - Key: d6166041a
# Financial Table: Stock Option Valuation. This table presents the valuation of stock options for three different years (2012, 2013, and 2014). The table includes the expected term in years, risk-free rate of return, expected volatility, expected dividend yield, and the fair value per option granted. The table shows a decrease in the fair value per option granted from $44.11 in 2014 to $29.65 in 2012, while the expected term, risk-free rate of return, expected volatility, and expected dividend yield have varying trends. Stock Options,  'Valuation,  'Expected Term,  'Risk-Free Rate,  'Volatility,  'Dividend Yield,  'Fair Value
# Time: 18.64 seconds
#
#
#
# 	19 - Key: d616749e2
# Yearly Cost Breakdown (in millions). The table presents a breakdown of yearly costs for employee-related expenses, real estate consolidation, and information technology costs. From 2010 to 2011, employee-related costs decreased from $105 million to $85 million, while real estate consolidation costs increased from $51 million to $58 million. Information technology costs remained constant at $41 million. The total costs for 2010 were $156 million, and for 2011, they were $133 million. yearly,  'costs,  'employee-related expenses,  'real estate consolidation,  'information technology costs,  'millions,  'decrease,  'increase,  'total
# Time: 17.09 seconds
#
#
#
# 	20 - Key: d6166c440
# Weighted Average Shares Outstanding and Dilutive Effect of Equity Awards. The table presents the weighted average number of common shares outstanding for basic and diluted computations, as well as the weighted average dilutive effect of equity awards for the years 2012, 2013, and 2014. The number of shares outstanding for basic computations decreased from 323.7 in 2012 to 316.8 in 2014. The number of shares outstanding for diluted computations increased from 328.4 in 2012 to 322.4 in 2014. The weighted average dilutive effect of equity awards remained relatively stable, with a slight decrease from 4.7 in 2012 to 5.6 in 2013, but then increased to 5.6 in 2014. weighted average common shares outstanding,  'basic computations,  'diluted computations,  'equity awards,  'dilutive effect,  '2012,  '2013,  '2014
# Time: 24.21 seconds
#
#
#
# 	21 - Key: d61666450
# Balance Sheet - Tax and Currency Translation Adjustments. The table presents the balance sheet of a company for the fiscal years 2016, 2017, and 2018. It shows the beginning and ending balances, as well as various additions and reductions related to tax positions and currency translation adjustments. The key trends include a decrease in the balance at the end of the fiscal year from 2016 to 2017, followed by a slight increase in 2018. The additions for tax positions taken in the current year and prior fiscal years have increased from 2016 to 2018, while the reductions for tax positions taken in prior fiscal years have decreased. The additions related to purchase accounting and reductions due to settlement have fluctuated over the years. The reductions for currency translation adjustments have remained negative throughout the period. balance,  'fiscal year,  'additions,  'reductions,  'tax positions,  'currency translation adjustments,  'purchase accounting,  'settlement
# Time: 23.53 seconds
#
#
#
# 	22 - Key: d61652ff4
# Total Securities by Category and Valuation Method. This table presents the total securities available for sale, held to maturity, and the total securities for the years 2012, categorized by valuation method (amortized cost and fair value). The table shows a slight increase in total securities for all categories and valuation methods from December 31, 2012 to December 31, 2012. total securities,  'available for sale,  'held to maturity,  'amortized cost,  'fair value,  'increase,  '2012
# Time: 14.34 seconds
#
#
#
# 	23 - Key: d616950b6
# Total Freight and Operating Revenues by Sector (Millions). The table displays total freight and operating revenues for various sectors in millions for the years 2014, 2015, and 2016. Key trends include a general increase in total freight revenues and total operating revenues across all sectors, with the exception of coal, which experienced a significant increase in 2016 but a decrease in 2015 compared to 2014. The sectors with the highest total freight revenues in 2016 were industrial products, intermodal, and chemicals. total freight revenues,  'total operating revenues,  'agricultural products,  'automotive,  'chemicals,  'coal,  'industrial products,  'intermodal,  'revenues,  'trends,  'years
# Time: 19.27 seconds
#
#
#
# 	24 - Key: d61655132
# Currency Exchange Rates and Total Impact from 2010 to 2012. The table displays the exchange rates of four currencies (real, euro, pound sterling, and Indian rupee) from 2010 to 2012. The total impact, calculated as the sum of the exchange rates, is also provided for each year. The real currency had the highest exchange rate in 2012 ($ 40.4), while the Indian rupee had the lowest exchange rate in 2010 (INR 2.6). currency,  'exchange rate,  'real,  'euro,  'pound sterling,  'Indian rupee,  'total impact,  '2010,  '2011,  '2012
# Time: 17.51 seconds
#
#
#
# 	25 - Key: d61656fc8
# Stock-based Compensation Over Three Years. This table presents the stock-based compensation data for a company over a three-year period (2005-2007). The table includes the number of shares granted, vested, forfeited, and unvested at the end of each year. The weighted average grant date fair value is also provided for stock-based performance awards and restricted stock awards. Key trends include a decrease in the number of shares vested and an increase in the number of shares unvested from 2005 to 2007. stock-based compensation,  'shares,  'granted,  'vested,  'forfeited,  'unvested,  'average grant date,  'fair value,  'trends,  '2005,  '2006,  '2007
# Time: 28.75 seconds
#
#
#
# 	26 - Key: d616619d2
# Real Estate Properties and Ownership Status. The table provides information about the company\ real estate,  'properties,  'locations,  'corporate headquarters,  'data center,  'lease administration site,  'broadcast division headquarters,  'leased,  'owned,  'square feet
# Time: 13.76 seconds
#
#
#
# 	27 - Key: d6165e656
# Stock Price Trends (2000-2001). The table displays the high and low stock prices for a given period from 2000 first quarter to 2001 fourth quarter. The stock prices show a significant drop from the first quarter to the third quarter in both years, with the lowest point in 2001 third quarter at $11.60. However, the stock price recovers in the fourth quarter, with a slight increase in 2001 compared to 2000. stock price,  'trends,  '2000,  '2001,  'high,  'low,  'first quarter,  'second quarter,  'third quarter,  'fourth quarter
# Time: 16.81 seconds
#
#
#
# 	28 - Key: d6165385a
# Stock Prices of Goldman Sachs Group Inc., S&P 500 Index, and S&P 500 Financials Index from 12/26/08 to 12/31/13. The table displays the stock prices of three entities over a period of six years, from 12/26/08 to 12/31/13. The entities are: 1) The Goldman Sachs Group Inc., a global investment banking firm, 2) S&P 500 Index, a stock market index that measures the stock performance of 500 large companies listed on stock exchanges in the United States, and 3) S&P 500 Financials Index, a sub-index of the S&P 500 that measures the stock performance of financial sector companies. The table shows a significant increase in the stock prices of all three entities over the six-year period, with the Goldman Sachs Group Inc. experiencing the most dramatic increase, from $100.00 to $248.36. Goldman Sachs Group Inc.,  'S&P 500 Index,  'S&P 500 Financials Index,  'stock prices,  'increase,  'performance,  'financial sector,  'time series
# Time: 27.47 seconds
#
#
#
# 	29 - Key: d61652536
# Projected Revenue Growth (2014-2028). This table displays the projected revenue growth from 2014 to 2028. The growth is significant, with a steady increase in revenue from 2018 to 2028, with the highest projected revenue in 2028 at $10,000. revenue,  'growth,  'projected,  '2014,  '2028,  'increase
# Time: 18.85 seconds
#
#
#
# 	30 - Key: d6167bf94
# Stock Option Grant and Fair Value Over Time. The table shows the number of shares granted, the average grant date fair value per share, and the changes in these values over the year. The total number of shares at the beginning of the year was 7328, and it increased to 4999 by the end of the year. The average grant date fair value per share was $49.17 at the beginning of the year, peaked at $51.91 with the granted shares, and decreased to $50.33 by the end of the year. There were 2134 shares granted, 4372 shares earned/vested (with a negative sign indicating a decrease), 91 shares canceled, and no shares were exercised. The parentheses indicate that the shares earned/vested and the shares canceled represent a decrease in the total number of shares. shares,  'grant date,  'fair value,  'beginning of year,  'end of year,  'granted,  'earned/vested,  'canceled
# Time: 21.82 seconds
#
#
#
# 	31 - Key: d6165e3e0
# Land Improvements and Asset Distribution. The table presents a breakdown of assets and land improvements for a given period. The assets are categorized into buildings, furniture fixtures and equipment, land, machinery, office equipment, and other. The distribution of assets ranges from 1 to 40, with buildings and land improvements having the highest values (39-40 and 1-2 respectively). assets,  'land improvements,  'buildings,  'furniture fixtures and equipment,  'land,  'machinery,  'office equipment,  'other
# Time: 15.84 seconds
#
#
#
# 	32 - Key: d61679b40
# Market Share of Infraserv Gmbh & Co. Subsidiaries as of December 31, 2013. The table displays the market share of Infraserv Gmbh & Co. subsidiaries as of December 31, 2013, expressed as percentages. The subsidiaries are Infraserv Gmbh & Co. Gendorf KG, Infraserv Gmbh & Co. Knapsack KG, Infraserv Gmbh & Co. Hoechst KG, and Infraserv Gmbh & Co. Kulz KG. The Gendorf KG subsidiary holds the largest market share at 39%, followed by Knapsack KG with 27%, Hoechst KG with 32%, and Kulz KG with 2%. Infraserv Gmbh & Co,  'subsidiaries,  'market share,  'December 31 2013,  'Gendorf KG,  'Knapsack KG,  'Hoechst KG,  'Kulz KG
# Time: 24.62 seconds
#
#
#
# 	33 - Key: d61657de2
# Financial Performance Over Three Years. The table displays the financial performance of a company over a three-year period, from 2004 to 2006. The key financial metrics include sales, operating profit, and net profit, all presented in millions. The sales figure shows a slight decrease from $7170 million in 2005 to $6930 million in 2006. In contrast, the operating profit and net profit both increased significantly from 2004 to 2005, with operating profit rising from $508 million to $473 million, and net profit increasing from $385 million to $345 million. However, both operating profit and net profit saw a slight increase from 2005 to 2006. sales,  'operating profit,  'net profit,  'increase,  'decrease,  'financial performance,  'three-year period
# Time: 21.06 seconds
#
#
#
# 	34 - Key: d61665db6
# Operating Working Capital Analysis. The table presents a financial analysis of operating working capital for a given period. Key observations include an increase in trade receivables net from $2512 million in 2011 to $2568 million in 2012, a slight increase in inventories FIFO from $1839 million in 2011 to $1930 million in 2012, a minor decrease in trade creditor trade receivables net,  'inventories FIFO,  'trade creditor's liabilities,  'operating working capital,  'sales,  'percentage
# Time: 23.46 seconds
#
#
#
# 	35 - Key: d6166b2c0
# Financial Table: Liabilities and Receivables for Different Categories. This table presents the financial data for various categories of liabilities and receivables as of December 31 for the years 2005, 2006, and 2007. Key trends include a significant increase in breast implant receivables, respirator mask/asbestos receivables, and other environmental liabilities. On the other hand, liabilities for breast implants, respirator mask/asbestos, and environmental remediation have decreased over the years. liabilities,  'receivables,  'breast implant,  'respirator mask/asbestos,  'environmental remediation,  'financial data,  'trends,  'decrease,  'increase
# Time: 19.23 seconds
#
#
#
# 	36 - Key: d6167c4bc
# Financial Acquisition Summary (February 17, 2006). The table presents a summary of financial assets acquired and liabilities assumed during an unspecified acquisition. The total assets acquired amount to $1,706 million, with consumer loans accounting for $1,316 million. Other assets, goodwill, and amortizable intangible assets contribute $20 million, $247 million, and $123 million, respectively. The total liabilities assumed are $30 million. The net assets acquired are $1,676 million. acquisition,  'assets,  'liabilities,  'consumer loans,  'goodwill,  'amortizable intangible assets,  'other assets,  'total assets acquired,  'total liabilities assumed,  'net assets acquired
# Time: 17.32 seconds
#
#
#
# 	37 - Key: d6165f344
# Error: Could not extract information
# Time: 80.93 seconds
#
#
#
# 	38 - Key: d61659c0a
# Total Revenue and Discontinued Operations (2003-2007). The table presents the total revenue and discontinued operations from 2003 to 2007. Total revenue decreased from $30 in 2003 to $84 in the "thereafter" period. Discontinued operations followed a similar trend, with a decrease from $4 in 2003 to $1 in the "thereafter" period. The total revenue and discontinued operations for the years 2004 to 2007 are also provided. total revenue,  'discontinued operations,  '2003,  '2004,  '2005,  '2006,  '2007,  'thereafter
# Time: 17.16 seconds
#
#
#
# 	39 - Key: d6165c82e
# Financial Performance Over Three Years. The table presents the financial performance of a company over a three-year period (2011-2013). Key trends include an increase in reported gross profit, underlying gross profit, and underlying net income, while reported net income shows a decrease. Mark-to-market losses are observed in both cost of goods sold (cogs) and selling, general, and administrative (sga) expenses. Project K impacts both cost of goods sold and selling, general, and administrative expenses, with costs incurred in 2013. financial performance,  'gross profit,  'sga,  'cost of goods sold,  'project k,  'net income,  'trends,  'three years
# Time: 27.76 seconds
#
#
#
# 	40 - Key: d6166f3e8
# Total Reserves by Cession. The table displays the total reserves by cession, breaking down the gross reserves into direct, assumed reinsurance, London market, total, ceded, and net reserves. The total gross reserves amount to $367, with a net value of $320 after ceding $47 from the total. total reserves,  'cession,  'gross reserves,  'direct,  'assumed reinsurance,  'London market,  'total,  'ceded,  'net reserves
# Time: 16.47 seconds
#
#
#
# 	41 - Key: d61657130
# Quarterly Share Purchase Data. This table presents the total number of shares purchased, average price paid per share, total number of shares purchased as part of publicly announced plans or programs, and the approximate dollar value of shares that may yet be purchased under the plans or programs for the fourth quarter of 2012. The table shows a significant increase in the total number of shares purchased from October to November, followed by a decrease in December. The average price paid per share remains relatively stable throughout the quarter. total number of shares purchased,  'average price paid per share,  'publicly announced plans or programs,  'dollar value of shares,  'fourth quarter,  '2012
# Time: 15.96 seconds
#
#
#
# 	42 - Key: d61676c2e
# Land Improvements and Asset Distribution. The table provides a breakdown of various land improvements and assets within a specific context. The assets are categorized into buildings, furniture, fixtures, and equipment, land, machinery, office equipment, and vehicles. The number of each asset category varies, with buildings ranging from 39 to 40, furniture and fixtures from 3 to 10, land from 10 to 15, machinery from 11 to 15, office equipment from 1 to 5, and vehicles from 1 to 5. landimprovements,  'buildings,  'furniture,  'fixtures,  'equipment,  'land,  'machinery,  'officeequipment,  'vehicles
# Time: 19.0 seconds
#
#
#
# 	43 - Key: d61654d5e
# Net Tangible Assets Acquired as of September 18, 2007. The table presents the net tangible assets acquired as of September 18, 2007, with a total estimated purchase price of $73,200. The assets are categorized into developed technology and know-how ($12,300), customer relationship ($17,000), trade name ($2,800), deferred income tax liabilities net ($-9,500), and goodwill ($47,800). net tangible assets,  'September 18,  2007,  'purchase price,  'developed technology,  'customer relationship,  'trade name,  'deferred income tax liabilities,  'goodwill
# Time: 17.64 seconds
#
#
#
# 	44 - Key: d61670572
# Yearly Amount of Investment. The table shows the yearly amount of investment from 2019 to 2025. The investment amount has been decreasing each year, with a significant drop from 2023 to 2024. investment,  'year,  'amount,  'decrease,  'trend
# Time: 10.57 seconds
#
#
#
# 	45 - Key: d61663a84
# Equity Compensation Plans Approved by Security Holders and Board of Directors. The table presents data on equity compensation plans approved by security holders and the board of directors. The table shows the number of securities to be issued upon exercise of outstanding options, warrants, and rights (columns a and b), the weighted-average exercise price of these outstanding options, warrants, and rights, and the number of securities remaining available for future issuance under equity compensation plans (excluding securities reflected in column a) (column c). equity compensation plans,  'security holders,  'board of directors,  'number of securities,  'outstanding options,  'exercise price,  'warants,  'rights,  'future issuance
# Time: 24.67 seconds
#
#
#
# 	46 - Key: d61667648
# Number of Locations by State. The table displays the number of locations in various states across the United States. California has the highest number of locations with 57, followed by Florida with 26. Texas, Georgia, and Minnesota, New York have 19, 22, and 9 locations respectively. Illinois, Ohio, and Maryland have 8 locations collectively. Pennsylvania has 7 locations, while other states have 63 locations in total. locations,  'state,  'California,  'Florida,  'Georgia,  'Texas,  'Minnesota,  'New York,  'Illinois,  'Ohio,  'Maryland,  'Pennsylvania,  'number
# Time: 15.07 seconds
#
#
#
# 	47 - Key: d61653e4a
# Equity Compensation Plans Approved by Security Holders. The table provides a summary of equity compensation plans approved by security holders. It includes the number of securities to be issued upon exercise of outstanding options, warrants, and rights (a), the weighted-average exercise price of these options, warrants, and rights (b), and the number of securities remaining available for future issuance under these plans (excluding securities reflected in column (a)) (c). The table shows that 766,801 securities will be issued, with an average exercise price of $40.85, and 8,945,694 securities remain available for future issuance. equity compensation plans,  'security holders,  'number of securities,  'exercise price,  'available securities
# Time: 18.79 seconds
#
#
#
# 	48 - Key: d616687c8
# Balance Sheet: Basel III Capital Adequacy Ratio as of December 2013. The table presents the balance sheet of an unspecified financial institution, focusing on Basel III Capital Adequacy Ratio as of December 2013. Key components include Common Shareholders 2019 Equity, Goodwill, Identifiable Intangible Assets, Deferred Tax Liabilities, and various adjustments. The table also includes the Basel III Common Equity Tier 1 (CET1) and Advanced RWA (Risk-Weighted Assets) figures, as well as the corresponding ratios. Basel III,  'Capital Adequacy Ratio,  'Common Shareholders 2019 Equity,  'Goodwill,  'Identifiable Intangible Assets,  'Deferred Tax Liabilities,  'Basel III CET1,  'Basel III Advanced RWAs,  'Basel III Advanced CET1 Ratio,  'Basel III Total CET1 Ratio
# Time: 23.73 seconds
#
#
#
# 	49 - Key: d61679a14
# Financial Performance of Key Products and Business Units (2011-2013). The table presents the financial performance of various products and business units for the years 2011 to 2013. Total sales decreased from $48,047 million in 2011 to $44,033 million in 2013. The pharmaceutical segment, which accounted for the majority of the total sales, also experienced a decline from $41,289 million in 2011 to $37,437 million in 2013. Key products such as Januvia, Zetia, Remicade, Gardasil, Janumet, Isentress, Vytorin, Nasonex, Proquad/m-m-rii/Varivax, Singulair, and Animal Health showed varying trends. The "other revenues" category increased from $1,665 million in 2011 to $1,340 million in 2013. total sales,  'pharmaceutical,  'Januvia,  'Zetia,  'Remicade,  'Gardasil,  'Janumet,  'Isentress,  'Vytorin,  'Nasonex,  'Proquad/m-m-rii/Varivax,  'Singulair,  'Animal Health,  'Consumer Care,  'other revenues
# Time: 30.83 seconds
#
#
#
# 	50 - Key: d616515c8
# Unrecognized Tax Benefits and Balances from December 1, 2007 to November 28, 2008. The table displays the changes in unrecognized tax benefits, settlements with taxing authorities, lapse of statute of limitations, and foreign exchange gains and losses from December 1, 2007 to November 28, 2008. The table also includes the beginning and ending balances. The gross increases in unrecognized tax benefits for prior year tax positions were $140,090, while the gross increases for current year tax positions were $113,500. Settlements with taxing authorities resulted in a decrease of $81,213. The lapse of statute of limitations led to a decrease of $3,512. Foreign exchange gains and losses resulted in a decrease of $2,893. The beginning balance was $201,808, and the ending balance was $139,549. unrecognized tax benefits,  'gross increases,  'prior year tax positions,  'current year tax positions,  'settlements with taxing authorities,  'lapse of statute of limitations,  'foreign exchange gains and losses,  'beginning balance,  'ending balance
# Time: 34.64 seconds
#
#
#
# 	51 - Key: d6167950a
# Financial Performance of Ball Corporation (2009-2011). The table displays the financial performance of Ball Corporation for the years 2009 to 2011. Net sales increased from $6710.4 million in 2009 to $8630.9 million in 2011, representing a growth of approximately 30%. Net earnings attributable to Ball Corporation followed a similar trend, rising from $387.9 million in 2009 to $444.0 million in 2011, an increase of around 15%. Operating cash flow also showed growth, increasing from $1800.0 million in 2009 to $2200.0 million in 2011, a growth of around 22%. net sales,  'net earnings,  'operating cash flow,  'Ball Corporation,  'growth,  'millions
# Time: 24.07 seconds
#
#
#
# 	52 - Key: d6166751c
# Yearly Amount Over Time. This table displays the yearly amount in dollars from 2016 to 2020, with a subsequent lump sum for the years thereafter. The total amount over the given period is $1203. year,  'amount,  'dollars,  'trend,  'total,  '2016,  '2017,  '2018,  '2019,  '2020,  'thereafter
# Time: 12.22 seconds
#
#
#
# 	53 - Key: d6165a8e4
# Financial Assets and Liabilities Breakdown. The table provides a breakdown of various financial assets and liabilities for a company. The assets are categorized by their duration, while the liabilities are listed by their type. The total value of long-term debt is $6,609,866, with the majority ($1,767,383) falling under the "more than 5 years" category. Operating leases amount to 128,550, with the largest portion ($52,626) belonging to the "more than 5 years" category. Ship construction contracts total $5,141,441, with the largest portion ($1,589,673) falling under the "more than 5 years" category. Port facilities amount to $1,738,036, with the largest portion ($1,366,636) falling under the "more than 5 years" category. Interest amounts to $974,444, with the largest portion ($182,465) falling under the "more than 5 years" category. Other assets total $1,381,518, with the largest portion ($345,796) falling under the "more than 5 years" category. The total value of all assets is $15,973,855. financial assets,  'liabilities,  'long-term debt,  'operating leases,  'ship construction contracts,  'port facilities,  'interest,  'other,  'duration,  'total
# Time: 33.32 seconds
#
#
#
# 	54 - Key: d61654fe8
# Total Future Minimum Sponsorship and Other Marketing Payments. The table shows the total future minimum sponsorship and other marketing payments in thousands for the years 2008 to 2012 and thereafter. The payments have been decreasing from 2008 ($14684) to 2011 ($10125), with a significant drop in 2012 to $1005. The payments are expected to remain constant at $1005 from 2012 onwards. payments,  'sponsorship,  'marketing,  'years,  'decreasing,  'constant
# Time: 14.82 seconds
#
#
#
# 	55 - Key: d6165f5ec
# Weighted Average Shares Outstanding and Dilutive Effects. The table presents the weighted average number of common shares outstanding for basic and diluted computations, as well as the weighted average dilutive effect of stock options and restricted stock units for the years 2010, 2011, and 2012. The number of common shares outstanding for basic computations decreased from 364.2 in 2010 to 323.7 in 2012. The number of common shares outstanding for diluted computations followed a similar trend, decreasing from 368.3 in 2010 to 328.4 in 2012. The weighted average dilutive effect of stock options and restricted stock units remained relatively stable, with a slight increase from 4.0 in 2011 to 4.7 in 2012. weighted average common shares outstanding,  'basic computations,  'diluted computations,  'stock options,  'restricted stock units,  'trend,  'decrease,  'increase,  '2010,  '2011,  '2012
# Time: 24.85 seconds
#
#
#
# 	56 - Key: d6166a47e
# U.S. Corporation Tax Rates and Credits (2015-2017). The table presents the U.S. corporation tax rates and credits for the years 2015, 2016, and 2017. The statutory U.S. rate remained constant at 35.0% for all years. One-time transition tax was applied in 2017 with a value of 9.1%. State income taxes net of federal benefit decreased from 0.9 in 2016 to 0.4 in 2017. Foreign operations showed a negative trend, with a decrease from -8.0 in 2016 to -7.4 in 2017. Domestic manufacturing deduction and R&D credit showed small fluctuations, while the change in valuation allowance and audit settlements and refunds showed a negative trend. Excess stock benefits, worthless stock deduction, and Venezuela charges were not applicable in certain years. The effective income tax rate decreased from 24.4% in 2016 to 13.7% in 2017. statutory U.S. rate,  'one-time transition tax,  'state income taxes,  'foreign operations,  'domestic manufacturing deduction,  'R&D credit,  'change in valuation allowance,  'audit settlements and refunds,  'excess stock benefits,  'change in federal tax rate,  'Venezuela charges,  'worthless stock deduction,  'other net,  'effective income tax rate
# Time: 33.88 seconds
#
#
#
# 	57 - Key: d61669894
# Yearly Revenue Growth (2002-2006) and Total Revenue (2002-2006). The table displays the yearly revenue growth from 2002 to 2006, as well as the total revenue for the same period. The revenue growth shows a decline from 2003 to 2006, with a significant drop in 2004. However, after 2006, the revenue growth increases significantly. The total revenue for the given period is $22,258. revenue,  'growth,  'year,  '2002,  '2003,  '2004,  '2005,  '2006,  'total,  '$
# Time: 16.78 seconds
#
#
#
# 	58 - Key: d6166d64c
# Lease and Purchase Obligations Over Time. The table displays lease and purchase obligations in millions of dollars from 2010 to thereafter. Lease obligations have decreased from $177 million in 2010 to $79 million in 2014 and then increased to $184 million. Purchase obligations (a) have fluctuated significantly, starting at $2262 million in 2010, dropping to $3729 million thereafter. Total obligations have followed a similar trend, with a decrease from $2439 million in 2010 to $611 million in 2014 and then increasing to $3913 million thereafter. lease obligations,  'purchase obligations,  'millions,  '2010,  '2011,  '2012,  '2013,  '2014,  'thereafter,  'trend,  'fluctuation
# Time: 20.69 seconds
#
#
#
# 	59 - Key: d61651f82
# Employee Breakdown by Department and Ownership. The table provides a breakdown of the workforce in terms of departments and ownership (mainline operations, wholly-owned regional carriers, and total). The largest department is passenger service personnel with 23,000 employees, followed by pilots and flight crew training instructors with 16,800 employees. The smallest department is administrative and other with 18,600 employees. employees,  'departments,  'mainline operations,  'wholly-owned regional carriers,  'total,  'pilots,  'flight crew,  'flight attendants,  'maintenance personnel,  'fleet service personnel,  'passenger service personnel,  'administrative,  'other
# Time: 16.88 seconds
#
#
#
# 	60 - Key: d61673cb8
# Total Cash Obligations and Unamortized Discounts/Premiums. The table displays the total cash obligations and unamortized discounts/premiums for the years 2010 to 2013, as well as the years thereafter, and the total cash obligations. The total cash obligations show a significant increase from 2010 to 2012, with a sharp decrease in 2013 and a steady increase thereafter. The unamortized discounts and premiums net remain relatively low throughout the period. total cash obligations,  'unamortized discounts and premiums net,  '2010,  '2011,  '2012,  '2013,  'thereafter
# Time: 16.99 seconds
#
#
#
# 	61 - Key: d6165a042
# Assets and Liabilities Acquired. The table presents the financial breakdown of assets and liabilities acquired by the company. The total assets acquired amount to $19,427, with the majority coming from goodwill ($13,536). Other significant assets include customer-related intangible assets ($4,091), contract-based intangible assets ($1,031), property and equipment ($267), and other current assets ($502). The total liabilities acquired are negative ($2,347), indicating a reduction in liabilities. The net assets acquired are $16,594. assets,  'liabilities,  'goodwill,  'customer-related intangible assets,  'contract-based intangible assets,  'property and equipment,  'other current assets,  'net assets acquired,  'acquired
# Time: 18.09 seconds
#
#
#
# 	62 - Key: d6167743a
# Shipment Volume of Smokeless Products (Millions) for the Years Ended December 31, 2014, 2013, and 2012. The table displays the shipment volume (in millions) of smokeless products for three years: 2012, 2013, and 2014. The products are categorized into Copenhagen, Skoal, Copenhagen and Skoal, and Other. The total shipment volume for all smokeless products increased from 763.3 million in 2012 to 787.5 million in 2013 and further to 793.3 million in 2014. shipment volume,  'smokeless products,  'Copenhagen,  'Skoal,  '2012,  '2013,  '2014,  'millions
# Time: 21.09 seconds
#
#
#
# 	63 - Key: d61650830
# Financial Table: Securities Financing and Related Agreements. The table presents financial data for the years 2006 and 2007, focusing on four types of financial agreements related to securities financing. The most significant increase is observed in indemnified securities financing, which grew from $506,032 million in 2006 to $558,368 million in 2007, a rise of approximately 10.4%. Liquidity asset purchase agreements saw a more modest increase from $30,251 million to $35,339 million, a growth of around 16.9%. Unfunded commitments to extend credit and standby letters of credit showed a slight decrease in value from 2006 to 2007, with the former dropping from $16,354 million to $17,533 million, and the latter decreasing from $4,926 million to $4,711 million. indemnified securities financing,  'liquidity asset purchase agreements,  'unfunded commitments to extend credit,  'standby letters of credit,  'millions,  'growth,  'decrease,  '2006,  '2007
# Time: 26.02 seconds
#
#
#
# 	64 - Key: d6166bc7a
# Capital Expenditure Overview. This table provides a comparison of capital expenditure for various assets between the years 2016 and 2015. Notable trends include a decrease in vehicles expenditure from $74 million in 2015 to $68 million in 2016, a slight increase in aircraft expenditure from 2289 units in 2015 to 2291 units in 2016, a decrease in buildings expenditure from 207 units in 2015 to 190 units in 2016, and a decrease in accumulated amortization from -$849 million in 2015 to -$896 million in 2016. The property plant and equipment subject to capital leases increased from $1721 million in 2015 to $1653 million in 2016. capital expenditure,  'vehicles,  'aircraft,  'buildings,  'accumulated amortization,  'property plant and equipment,  'capital leases,  '2016,  '2015
# Time: 23.38 seconds
#
#
#
# 	65 - Key: d61666b6c
# Tax Balance Sheet. The table presents a tax balance sheet for two years, 2008 and 2007. The balance at the beginning of the period decreased from $266.9 in 2007 to $134.8 in 2008. This decrease is due to tax positions taken during a prior year (-21.3) and lapse of statutes of limitation (-1.7). There were also settlements with taxing authorities (-4.5). However, the balance increased as a result of tax positions taken during the current year (18.7). The balance at the end of the period was $148.8 in 2008 and $134.8 in 2007. tax balance sheet,  '2008,  '2007,  'balance at beginning of period,  'balance at end of period,  'tax positions,  'settlements with taxing authorities,  'lapse of statutes of limitation
# Time: 21.83 seconds
#
#
#
# 	66 - Key: d6166299a
# ...
# Time: 15.04 seconds
#
#
#
# 	226 - Key: d6165ec6e
# Bank Capitalization and Ratios as of December 2012 and 2011. The table presents the financial data of a bank, comparing its capitalization and ratios for the years 2011 and 2012. The bank experienced an increase in tier 1 capital from $19,251 million to $20,704 million, a rise of approximately 6.3%. The total capital also increased from $19,257 million to $20,743 million, a growth of around 7.1%. The risk-weighted assets saw a slight increase from $112,824 million to $109,669 million, a decrease of about 2.1%. The tier 1 capital ratio improved from 17.1% to 18.9%, indicating a stronger financial position. Similarly, the total capital ratio and tier 1 leverage ratio also improved, rising from 17.1% to 18.9% and 18.5% to 17.6% respectively. tier 1 capital,  'tier 2 capital,  'total capital,  'risk-weighted assets,  'tier 1 capital ratio,  'total capital ratio,  'tier 1 leverage ratio,  'increase,  'decrease,  'financial data,  'bank
# Time: 27.89 seconds
#
#
#
# 	227 - Key: d6165cc84
# Revenue Evolution from 2015 to 2019 and Beyond. The table displays the annual revenue from 2015 to 2019, with a further projection for the years beyond 2019. The revenue has shown a downward trend from 2015 to 2019, with a decrease of approximately 10% each year. The total revenue from 2015 to 2019 is $ 6,903,188. The revenue for the years beyond 2019 is projected to be $ 4,214,600. revenue,  'trend,  'annual,  '2015,  '2019,  'decrease,  'total,  'projection
# Time: 17.48 seconds
#
#
#
# 	228 - Key: d6165fb0a
# Stock Performance of Abiomed Inc, Nasdaq Composite Index, and Nasdaq Medical Equipment SIC Code 3840-3849 from 2007 to 2012. The table displays the stock performance of Abiomed Inc, Nasdaq Composite Index, and Nasdaq Medical Equipment SIC Code 3840-3849 from March 31, 2007, to March 31, 2012. Abiomed Inc showed a significant increase in stock price from 2007 to 2012, with the highest value recorded in 2012 at 162.45. The Nasdaq Composite Index also experienced growth, but with a lower rate compared to Abiomed Inc, with the highest value in 2012 at 127.66. In contrast, the Nasdaq Medical Equipment SIC Code 3840-3849 showed a decline in stock price from 2007 to 2012, with the lowest value recorded in 2012 at 74.40. SIC Code stands for Standard Industrial Classification Code. Abiomed Inc,  'Nasdaq Composite Index,  'Nasdaq Medical Equipment SIC Code 3840-3849,  'stock performance,  'growth,  'decline,  'SIC Code
# Time: 29.24 seconds
#
#
#
# 	229 - Key: d6168ba0c
# Yearly Revenue Growth. The table displays the yearly revenue growth of a company from 2015 to 2020 and beyond. The revenue has shown a significant increase from 2015 to 2020, with a notable jump in 2020 and thereafter. The revenue in 2015 was $1432, and it is projected to be $7263 in 2020 and beyond. revenue,  'yearly,  'growth,  '2015,  '2016,  '2017,  '2018,  '2019,  '2020,  'increase,  'projected
# Time: 16.12 seconds
#
#
#
# 	230 - Key: d6165c4fa
# Net Derivative Losses by Strategy (2002-2003). The table displays the net derivative losses for various strategies from 2002 to 2003. The most significant loss was observed in the mitigate price risk strategy, with a decrease of $112 million from 2002 to 2003. Protecting carrying values of excess inventories and crack spread values also resulted in losses, while protecting margin on fixed price sales and trading activities showed gains. The total net derivative losses for the period decreased from $124 million in 2002 to $162 million in 2003. net derivative losses,  'mitigate price risk,  'protect carrying values,  'excess inventories,  'margin on fixed price sales,  'trading activities,  'crack spread values,  'total net derivative losses
# Time: 18.65 seconds
#
#
#
# 	231 - Key: d6165b10e
# Assets Pledged by Year. This table shows the assets pledged by the company for the years 2009 and 2010. The assets are categorized into securities, loans, trading assets, and total assets pledged (a). The total assets pledged decreased from $525.4 billion in 2009 to $450.1 billion in 2010. The most significant decrease was observed in the securities category, which dropped from $155.3 billion in 2009 to $112.1 billion in 2010. The loans category also saw a decrease, from $285.5 billion in 2009 to $214.8 billion in 2010. The trading assets category increased slightly from $84.6 billion in 2009 to $123.2 billion in 2010. assets,  'pledged,  'securities,  'loans,  'trading assets,  'total assets,  'decrease,  'increase,  '2009,  '2010
# Time: 26.38 seconds
#
#
#
# 	232 - Key: d616868fe
# Net Tangible Assets Acquired as of July 13, 2006. The table displays the net tangible assets acquired as of July 13, 2006, with a total value of $220,600. The assets are categorized into in-process research and development ($10,200), developed technology and know-how ($39,500), customer relationship ($15,700), trade name ($3,300), order backlog ($800), deferred income taxes ($6,700), and goodwill ($143,200). The final purchase price is also provided ($220,600). net tangible assets,  'July 13,  2006,  'in-process research and development,  'developed technology and know-how,  'customer relationship,  'trade name,  'order backlog,  'deferred income taxes,  'goodwill,  'final purchase price
# Time: 20.99 seconds
#
#
#
# 	233 - Key: d6166bb62
# Approximate Number and Size of Facilities. The table provides an overview of the approximate number and size in square feet of various facilities. The facilities include switching centers, data centers, call centers, and warehouses. The switching centers have approximately 61 units with a total size of 1,300,000 square feet. Data centers have 6 units with a total size of 500,000 square feet. The call center has 17 units with a total size of 1,400,000 square feet. Lastly, warehouses have 15 units with a total size of 500,000 square feet. facilities,  'switching centers,  'data centers,  'call center,  'warehouses,  'approximate number,  'approximate size,  'square feet
# Time: 17.47 seconds
#
#
#
# 	234 - Key: d6165d8fa
# Quarterly Financial Performance. The table displays the quarterly financial performance of a company in millions for the years 2011 and 2012. The key trends include a decrease in the total assets from $47 in January 2012 to $43 in December 2012, and a net loss of $8 in 2013 loan repurchases and settlements for both years. Reserve adjustments net show an increase from $1 in 2011 to $4 in 2012. total assets,  'quarterly,  'financial performance,  '2011,  '2012,  'reserve adjustments net,  'losses,  '2013 loan repurchases and settlements
# Time: 32.52 seconds
#
#
#
# 	235 - Key: d6165fd12
# Tax Positions Balance Sheet for Year 2007. The table presents the tax positions balance sheet for the year 2007. The balance at January 1, 2007, is $53. Throughout the year, there were additions based on tax positions related to the current year amounting to $4. Additions for tax positions of prior years totaled $24. Reductions for tax positions of prior years resulted in a decrease of $6 ($6 increase). Settlements led to a decrease of $5 ($5 increase). The balance at December 31, 2007, is $70. tax positions,  'balance sheet,  '2007,  'additions,  'reductions,  'settlements,  'dollars
# Time: 17.39 seconds
#
#
#
# 	236 - Key: d616662b6
# Senior Secured Transition Bonds Series A and B. The table displays the amounts (in thousands) for senior secured transition bonds series A and B, with their respective tranches, interest rates, and due dates. Both series have tranche 1 due in October 2013, tranche 2 due in October 2018, tranche 3 due in June 2022, and tranche 4 due in June 2027. Series A has higher amounts for tranches 2, 3, and 4 compared to Series B. The interest rates for all tranches are the same for both series. senior secured transition bonds,  'series A,  'series B,  'tranches,  'amounts,  'interest rates,  'due dates
# Time: 32.24 seconds
#
#
#
# 	237 - Key: d6166ba4a
# Stock Issuance and Repurchase Over Time. The table shows the stock issuance and repurchase activities of a company from January 1, 2010 to December 31, 2012. Key events include acquisitions, share sales to optionees, employee stock purchase plans, stock repurchases, and conversions of debentures. The total number of shares outstanding decreases from 1395 to 1328 over the period. stock issuance,  'stock repurchase,  'shares outstanding,  'acquisition,  'employee stock purchase plan,  'debentures,  'optionees,  'treasury,  'vesting
# Time: 23.28 seconds
#
#
#
# 	238 - Key: d6168493c
# Crude Oil and Natural Gas Prices. This table presents the prices of WTI crude oil, Brent crude oil, Henry Hub natural gas, and Nymex natural gas from 2011 to 2013. WTI and Brent crude oil prices show an increase from 2011 to 2012, but a slight decrease in 2013. In contrast, both natural gas prices have an upward trend from 2011 to 2013. The acronyms used in the table are: a) Henry Hub natural gas, b) Nymex natural gas. WTI crude oil,  'Brent crude oil,  'Henry Hub natural gas,  'Nymex natural gas,  'prices,  '2011,  '2012,  '2013,  'dollars per bbl,  'dollars per mmbtu
# Time: 22.34 seconds
#
#
#
# 	239 - Key: d616a1e56
# Stock Performance from 2009 to 2014. The table displays the stock performance of State Street Corporation, S&P 500 Index, and S&P Financial Index from 2009 to 2014. State Street Corporation shows a steady increase in stock price from $100 in 2009 to $190 in 2014. The S&P 500 Index exhibits a more significant growth trend, with a starting price of 100 in 2009 and reaching 208 in 2014. The S&P Financial Index also shows a growth trend, but with some fluctuations, starting at 100 in 2009 and reaching 183 in 2014. State Street Corporation,  'S&P 500 Index,  'S&P Financial Index,  'stock performance,  '2009,  '2010,  '2011,  '2012,  '2013,  '2014
# Time: 22.34 seconds
#
#
#
# 	240 - Key: d61667a3a
# Trading Assets and Liabilities for the Years 2007-2009. The table presents the trading assets and liabilities for the years 2007, 2008, and 2009. The trading assets include debt and equity instruments and derivative receivables. The trading liabilities consist of debt and equity instruments (a) and derivative payables. Notable trends include a decrease in trading assets (2013 debt and equity instruments and trading assets derivative receivables) and trading liabilities (trading liabilities debt and equity instruments (a) and trading liabilities derivative payables) from 2008 to 2009. trading assets,  '2007,  '2008,  '2009,  'debt and equity instruments,  'derivative receivables,  'trading liabilities,  'debt and equity instruments (a),  'derivative payables
# Time: 20.14 seconds
#
#
#
# 	241 - Key: d6167fbbc
# Cash Flow Statement. The table presents a cash flow statement for a company, categorized into operating, investing, and financing activities. Operating activities show a negative cash flow of $799 million in 2017, a significant increase from $262 million in 2016 and $1277 million in 2015. Investing activities demonstrate a negative cash flow of $4130 million in 2017, a slight increase from $472 million in 2016 and a decrease from $466 million in 2015. Financing activities show a positive cash flow of $10919 million in 2017, a significant decrease from $102 million in 2016 and a significant increase from $515 million in 2015. The table also includes parentheses to denote negative cash flows. cash flow,  'operating activities,  'investing activities,  'financing activities,  'millions,  '2017,  '2016,  '2015
# Time: 21.98 seconds
#
#
#
# 	242 - Key: d6166ade8
# Weighted Average Useful Life of Intangible Assets. The table presents the weighted average useful life (in years) of various intangible assets owned by the company. The assets include purchased technology, localization, trademarks, customer contracts and relationships, and other intangibles. The useful life ranges from 1 to 6 years, with purchased technology having the longest useful life of 4 years and other intangibles having the shortest useful life of 3 years. intangible assets,  'useful life,  'purchased technology,  'localization,  'trademarks,  'customer contracts,  'relationships,  'other intangibles
# Time: 14.36 seconds
#
#
#
# 	243 - Key: d61659f02
# Accrued Balance Over Time. This table shows the accrued balance related to previous restructurings from November 27, 1998, to December 3, 1999. The total charges amounted to $10,867, while cash payments were $8,143. Adjustments resulted in a net decrease of $7,757 ($6,221 in decreases and $1,874 in increases). The accrued balance at the end of the period was $772. accrued balance,  'total charges,  'cash payments,  'adjustments,  'restructurings,  'November 27,  1998,  'December 3,  1999
# Time: 17.13 seconds
#
#
#
# 	244 - Key: d6166579e
# Financial Performance of a Company (2014-2016). The table presents the financial performance of a company for the years 2014, 2015, and 2016. Key financial metrics include net revenue, retail electric price, volume/weather, and various provisions. Notable items include Louisiana business combination customer credits, MISO deferral, Waterford 3 replacement steam generator provision, and other miscellaneous expenses. The table shows a steady increase in net revenue from $5735 million in 2014 to $5923 million in 2016. net revenue,  'retail electric price,  'volume/weather,  'Louisiana business combination customer credits,  'MISO deferral,  'Waterford 3 replacement steam generator provision,  'other
# Time: 31.62 seconds
#
#
#
# 	245 - Key: d61679f8c
# Financial Table: Debt Obligations and Notes. This table displays the financial data of various debt obligations and notes for two different years, 2010 and 2009. The table includes commercial mortgage pass-through certificates, revolving credit facilities, term loans, credit facilities, senior notes, convertible notes, senior subordinated notes, notes payable and capital leases. Notable trends include a decrease in the current portion of long-term obligations from $74896 in 2009 to $70521 in 2010. The total debt obligations increased from $4211581 in 2009 to $5587388 in 2010. The long-term obligations also increased from $4141060 in 2009 to $5512492 in 2010. debt obligations,  'notes,  'commercial mortgage pass-through certificates,  'revolving credit facility,  'term loan,  'xcel credit facility,  'colombian short-term credit facility,  'senior notes,  'convertible notes,  'senior subordinated notes,  'notes payable and capital leases,  'total,  'current portion of long-term obligations,  'long-term obligations
# Time: 28.68 seconds
#
#
#
# 	246 - Key: d61653f9e
# Currency Exchange Rates and Total Increase/Decrease from 2015 to 2017. The table displays the exchange rates of four currencies (pound sterling, euro, real, and Indian rupee) from 2015 to 2017. The pound sterling had the highest exchange rate in 2017 ($42), followed by the euro ($35), real ($39), and Indian rupee ($14). Compared to 2015, the pound sterling and euro experienced an increase in their exchange rates, while the real and Indian rupee saw a decrease. The total increase or decrease in exchange rates from 2015 to 2017 was $130. currency,  'exchange rate,  'pound sterling,  'euro,  'real,  'Indian rupee,  '2015,  '2016,  '2017,  'increase,  'decrease,  'total increase/decrease
# Time: 21.3 seconds
#
#
#
# 	247 - Key: d6165f254
# Financial Assets Balance Sheet. The table displays the balance sheet of financial assets for a company as of December 2017 and December 2016. The total financial assets decreased from $23,280 million in 2016 to $19,201 million in 2017. The decrease is primarily due to a reduction in cash instruments ($18,035 million to $15,395 million) and derivatives ($5,190 million to $3,802 million). Other financial assets remained constant at $55 million. financial assets,  'cash instruments,  'derivatives,  'balance sheet,  'decrease,  '2017,  '2016
# Time: 16.71 seconds

# %%
dataset = "FinQA"
table_dict = np.load(f'table_summaries_{dataset}_long.npy', allow_pickle='TRUE').item()
len(table_dict)
# Out:
# 247

# %% [markdown]
# -----------------------------------------------------------------------------------

# %%
create_summaries("MultiHeritt", template_long, "long")
# Out:
# CREATING SUMMARIES FOR MultiHeritt, with template:
# You are a finance expert specialized in analyzing financial tables.
#
# ### Task ###
# Analyze the table and transcribe its contents into a well-structured summary. Generate a detailed paragraph that captures all relevant information, including numerical data, trends, and observations.
# If the table contains acronyms, provide their concise definitions where possible.
# Return the output in the form of a dictionary with the following keys:
# - 'title': A concise title for the table.
# - 'description': A brief description of the table's contents and key trends.
# - 'keywords': A list of the most relevant keywords of the table.
#
# **Note**: Do not return the table, prompt, or any extra text. Return only the dictionary.
#
# ### Table ###
#
#
#
#
# Loaded extracted_tables_MultiHeritt, it has 876 tables to process
#
#
#
# 	1 - Key: d8327a646
# Total Contractual Obligations of a Company. The table presents the total contractual obligations of a company in millions of dollars, categorized by the duration of the obligations. The company has a total of $175,395 in obligations, with $65,279 of these obligations maturing within a year, $41,773 maturing between 1 and 3 years, $25,370 maturing between 3 and 5 years, and $42,973 maturing after 5 years. The table also includes specific categories of obligations such as long-term debt, pension and other postretirement cash requirements, capital lease obligations, operating lease obligations, purchase obligations not recorded on the Consolidated Statements of Financial Position, and purchase obligations recorded on the Consolidated Statements of Financial Position. Total Contractual Obligations,  'Long-term debt,  'Pension and other postretirement cash requirements,  'Capital lease obligations,  'Operating lease obligations,  'Purchase obligations,  'Consolidated Statements of Financial Position
# Time: 31.01 seconds
#
#
#
# 	2 - Key: d80ee2864
# 		Skipping d80ee2864, no table found ...
#
# 	3 - Key: d842dcf7a
# Total Minimum Lease Payments for Capital and Operating Leases. The table displays the total minimum lease payments for capital and operating leases from 2007 to later years. The payments are given in millions of dollars. The table shows a decreasing trend in lease payments from 2007 to 2011, with a significant increase in later years. The total minimum lease payments for capital leases are lower than those for operating leases in all years. The table also includes the present value of minimum lease payments, present value of lease payments excluding interest, and an amount representing interest for the later years. Total minimum lease payments,  'Capital leases,  'Operating leases,  'Millions of Dollars,  'Trend,  'Decrease,  'Increase,  'Present value,  'Interest
# Time: 21.26 seconds
#
#
#
# 	4 - Key: d82441b60
# 		Skipping d82441b60, no table found ...
#
# 	5 - Key: d82d2c6a8
# Financial Performance Comparison for Two Years. The table presents a comparison of total revenues, operating income, and net income for a specific segment between September 27, 2008, and September 29, 2007. Total revenues increased by 8% from $99,470 to $107,578. Operating income saw a significant jump of 461% from $845 to $4,742, while net income rose by 351% from $774 to $3,488. Total Revenues,  'Operating Income,  'Net Income,  'Comparison,  'Increase,  'Percentage Change
# Time: 21.19 seconds
#
#
#
# 	6 - Key: d81a04f30
# Net Sales by Product Category and Year. The table displays net sales for three years (2010, 2011, and 2012) for three product categories: Tools, Diagnostics and repair information, and Equipment. The Automotive and Industrial subcategories are also shown. Overall, there is a general increase in net sales across all categories and years. Net Sales,  'Product Category,  'Tools,  'Diagnostics and repair information,  'Equipment,  'Automotive,  'Industrial,  '2010,  '2011,  '2012
# Time: 24.53 seconds
#
#
#
# 	7 - Key: d819229aa
# 		Skipping d819229aa, no table found ...
#
# 	8 - Key: d812de4cc
# 		Skipping d812de4cc, no table found ...
#
# 	9 - Key: d815b510a
# Financial Performance of a Real Estate Company from 2003 to 2007. The table presents the financial performance of a real estate company from 2003 to 2007. Key trends include an increase in rental income, net income, and funds from operations, as well as a decrease in loss before minority interests and discontinued operations. The company also experienced growth in the number of apartment homes owned and the total assets, while the total debt and stockholders’ equity also increased. rental income,  'loss before minority interests,  'income from discontinued operations,  'net income,  'distributions to preferred stockholders,  'net income available to common stockholders,  'common distributions declared,  'real estate owned,  'accumulated depreciation,  'total real estate owned,  net of accumulated depreciation,  'total assets,  'secured debt,  'unsecured debt,  'total debt,  'stockholders’ equity,  'number of common shares outstanding,  'cash flow data,  'funds from operations,  'apartment homes owned,  'apartment homes under development,  'apartment homes under construction,  'apartment homes sold during the year,  'apartment homes delivered during the year
# Time: 67.01 seconds
#
#
#
# 	10 - Key: d81128272
# 		Skipping d81128272, no table found ...
#
# 	11 - Key: d8199c930
# 		Skipping d8199c930, no table found ...
#
# 	12 - Key: d80ee27b0
# Revenue and Expense Analysis for Years Ended December 31, 2009 and 2008. The table presents a comparison of revenues and expenses for the years ended December 31, 2009 and 2008. Total revenues increased by 2% from $3,288 million in 2008 to $3,349 million in 2009. The pretax loss decreased by 77% from $149 million in 2008 to $44 million in 2009. The net loss per share increased by 237% from $1.01 in 2008 to $0.28 in 2009. revenues,  'expenses,  'pretax loss,  'net loss,  'net loss per share,  '2009,  '2008,  'increase,  'decrease,  'percentage change
# Time: 32.98 seconds
#
#
#
# 	13 - Key: d81818a3c
# Financial Statements for the Year Ended December 31, 2009. The table presents the financial statements for the year ended December 31, 2009. It includes total operating revenues, total operating expenses, operating income, equity in earnings of unconsolidated affiliates, interest and dividend income, other investment income/(losses), interest expense, income before income taxes, income tax provision, net income, (gains)/losses attributable to noncontrolling interests in consolidated entities, net income attributable to common shareholders, net income per common share, basic and diluted, and weighted average number of common shares outstanding, basic and diluted. Key trends include a decrease in total operating revenues (-9.5%), a decrease in operating income (-9.5%), and an increase in equity in earnings of unconsolidated affiliates (2.5%). Financial Statements,  'Revenues,  'Expenses,  'Operating Income,  'Equity,  'Interest,  'Taxes,  'Net Income,  'Common Shareholders,  'Investment Income,  'Consolidated Entities,  'Noncontrolling Interests,  'Weighted Average Number of Common Shares
# Time: 35.6 seconds
#
#
#
# 	14 - Key: d812ed486
# 		Skipping d812ed486, no table found ...
#
# 	15 - Key: d811283ee
# 		Skipping d811283ee, no table found ...
#
# 	16 - Key: d8203ffd0
# Financial Summary of Shares for the Years 2010-2012. The table provides a financial summary of shares for the years 2010-2012. The number of shares outstanding remains constant at 221,474. The conversion rate per share varies, with a decrease from 76.2197 in 2012 to 73.1904 in 2010. The conversion price also decreases from $13.66 in 2010 to $13.12 in 2012. The total shares after conversion remain constant at 221,474. Cash and cash equivalents, accounts receivable, inventory, total assets, total liabilities, net income, and Earnings per share (EPS) all remain constant across the three years. shares outstanding,  'conversion rate,  'conversion price,  'conversion shares,  'total shares after conversion,  'cash and cash equivalents,  'accounts receivable,  'inventory,  'total assets,  'total liabilities,  'net income,  'Earnings per share (EPS)
# Time: 43.75 seconds
#
#
#
# 	17 - Key: d82267b64
# Revenue and Expense Analysis for 2011 and 2012. The table presents a comparison of revenues and expenses for two consecutive years, 2011 and 2012. The table shows a significant increase in net income margin from 23.4% to 26.8%, indicating improved profitability. Key expenses include employee compensation and benefits, depreciation and amortization, technology and communications, professional and consulting fees, occupancy, marketing and advertising, and general and administrative expenses. The table also shows the percentage of revenues and expenses for each category. revenues,  'expenses,  'employee compensation,  'depreciation,  'amortization,  'technology,  'communications,  'professional fees,  'consulting fees,  'occupancy,  'marketing,  'advertising,  'general administration,  'net income,  'net income margin,  '2011,  '2012
# Time: 29.89 seconds
#
#
#
# 	18 - Key: d842dce6c
# Quarterly Financial Summary of Credit Commitments. This table presents a summary of various credit commitments for the years 2009 and 2010. The table shows the total amount (in thousands) for Standby Letters of Credit, Open End Consumer Lines of Credit, Commercial Lines of Credit, Unfunded Loan Commitments - Variable Rate, and Unfunded Loan Commitments – Fixed Rate. There is a noticeable increase in Commercial Lines of Credit and a decrease in Standby Letters of Credit, Open End Consumer Lines of Credit, and Unfunded Loan Commitments - Variable Rate from 2009 to 2010. Credit Commitments,  'Standby Letters of Credit,  'Open End Consumer Lines of Credit,  'Commercial Lines of Credit,  'Undefunded Loan Commitments,  'Variable Rate,  'Fixed Rate,  '2009,  '2010,  'Thousands
# Time: 23.16 seconds
#
#
#
# 	19 - Key: d8327a81c
# 		Skipping d8327a81c, no table found ...
#
# 	20 - Key: d81cc5a1c
# 		Skipping d81cc5a1c, no table found ...
#
# 	21 - Key: d81decb70
# Stock Option Exercise and Expiration Data. This table presents the number of shares and the weighted average exercise price for stock options for a company from 2011 to 2014. The data shows a decrease in the number of outstanding shares from 4,792,409 in 2011 to 678,338 in 2014. The weighted average exercise price also decreases from $8.95 in 2011 to $13.21 in 2014. The table also includes the number of shares exercised, forfeited, and expired during each year. shares,  'weighted average exercise price,  'stock options,  'exercised,  'forfeited,  'expired,  '2011,  '2012,  '2013,  '2014
# Time: 24.4 seconds
#
#
#
# 	22 - Key: d8292c544
# 		Skipping d8292c544, no table found ...
#
# 	23 - Key: d8196f3f4
# Net Reserves of the Company from 2004 to 2006. The table presents the net reserves of the company in millions of dollars from 2004 to 2006. The net reserves are calculated by subtracting reinsurance receivable from gross reserves. The net reserves have increased from $506.7 million in 2004 to $511.4 million in 2006. The table also includes other reserves such as case reserves reported by ceding companies, additional case reserves established by the Company (assumed reinsurance), case reserves established by the Company (direct insurance), incurred but not reported reserves, and gross reserves. net reserves,  'gross reserves,  'reinsurance receivable,  'case reserves,  'incurred but not reported reserves,  '2004,  '2005,  '2006
# Time: 19.95 seconds
#
#
#
# 	24 - Key: d8373b14e
# Notional Amount and Contract Price for Various Fuel Contracts. The table displays the notional amount and contract price for several fuel contracts. The contracts range from 2007 to 2013, with varying terms and notional amounts. The contract price is given in a range for each contract, indicating the minimum and maximum price per gallon. Notable trends include a decrease in contract price over time and larger notional amounts for contracts with longer terms. Notional Amount,  'Contract Price,  'Gallons,  'Fuel Contracts,  'Term,  'Minimum Price,  'Maximum Price
# Time: 20.63 seconds
#
#
#
# 	25 - Key: d827068f0
# Net Charge-offs and Allowance for Loan and Lease Losses by Loan Type (Millions of Dollars). The table presents the net charge-offs and allowance for loan and lease losses for commercial and consumer lending for the years 2011 and 2012. The table shows a decrease in net charge-offs for both commercial and consumer lending from 2011 to 2012. The allowance for loan and lease losses to total loans also decreased for both loan types during the same period. The net charge-offs to average loans for commercial lending decreased significantly, while it remained relatively stable for consumer lending. net charge-offs,  'allowance for loan and lease losses,  'commercial lending,  'consumer lending,  'millions of dollars,  '2011,  '2012,  'decrease,  'increase,  'loan types
# Time: 21.86 seconds
#
#
#
# 	26 - Key: d829ed99c
# Cash Flow Statement for the Three Months Ended March 31, 2005 and 2004. The table presents a cash flow statement for the three months ended March 31, 2005 and 2004. The statement is divided into operating, investing, financing activities, and the effect of exchange rate changes on cash and cash equivalents. Key trends include a decrease in net cash used in operating activities from $11,975 million in 2005 to $11,561 million in 2004. Net cash used in investing activities decreased from $81,794 million in 2005 to $73,620 million in 2004. Net cash provided by financing activities increased from $93,554 million in 2005 to $84,397 million in 2004. The effect of exchange rate changes on cash and cash equivalents resulted in a decrease of $4,788 million in 2004. cash flow statement,  'operating activities,  'investing activities,  'financing activities,  'exchange rate changes,  'net income,  'provision for credit losses,  'gains on sales of debt securities,  'depreciation and premises improvements amortization,  'amortization of intangibles,  'deferred income tax benefit,  'net increase in trading and derivative instruments,  'net (increase) decrease in other assets,  'net decrease in accrued expenses and other liabilities,  'other operating activities,  net,  'net cash used in operating activities,  'investing activities,  'net (increase) decrease in time deposits placed and other short-term investments,  'net (increase) decrease in federal funds sold and securities purchased under agreements to resell,  'proceeds from sales of available-for-sale securities,  'proceeds from maturities of available-for-sale securities,  'purchases of available-for-sale securities,  'proceeds from maturities of held-to-maturity securities,  'proceeds from sales of loans and leases,  'other changes in loans and leases,  net,  'additions to mortgage servicing rights,  net,  'net purchases of premises and equipment,  'proceeds from sales of foreclosed properties,  'net cash paid for business acquisitions,  'other financing activities,  net,  'net cash provided by financing activities,  'effect of exchange rate changes on cash and cash equivalents,  'cash and cash equivalents
# Time: 64.05 seconds
#
#
#
# 	27 - Key: d81e4fb4e
# Notional Amounts and Derivative Receivables Mark-to-market as of December 31, 2004 and 2005. The table presents the notional amounts and derivative receivables mark-to-market (MTM) for various types of derivatives as of December 31, 2004 and 2005. The derivatives include interest rate, foreign exchange, equity, credit derivatives, commodity, and total. The table shows an increase in total notional amounts from $40.514 billion in 2004 to $43.593 billion in 2005. The derivative receivables MTM decreased from $66 billion in 2004 to $50 billion in 2005. Collateral held against derivative receivables decreased from $NA$ to -$6 billion, and the exposure net of collateral increased from $NA$ to $57 billion. Notional amounts,  'Derivative receivables MTM,  'Interest rate,  'Foreign exchange,  'Equity,  'Credit derivatives,  'Commodity,  'Total,  'Mark-to-market,  'Collateral,  'Exposure
# Time: 30.14 seconds
#
#
#
# 	28 - Key: d8247dfb6
# 		Skipping d8247dfb6, no table found ...
#
# 	29 - Key: d8373b22a
# U.S. Federal and State Taxes. The table displays the U.S. federal and state taxes from 2010 to 2012. The total tax for 2012 was $783.6 billion, a decrease from $822.1 billion in 2011 and an increase from $729.0 billion in 2010. The federal tax in 2012 was $228.7 billion, a decrease from $253.9 billion in 2010. State taxes in 2012 were $29.2 billion, a decrease from $50.2 billion in 2010. The "Federal and state deferred provision" increased significantly from 2010 to 2011, from $61.4 billion to $334.8 billion, but decreased in 2012 to $83.9 billion. taxes,  'federal,  'state,  '2010,  '2011,  '2012,  'billion,  'deferred provision,  'uncertain tax positions,  'income taxes
# Time: 26.3 seconds
#
#
#
# 	30 - Key: d82e4efe0
# 		Skipping d82e4efe0, no table found ...
#
# 	31 - Key: d80f34cfe
# U.S. Government Revenue by Tax Type and Year. This table displays the revenue collected by the U.S. government from federal, state and local, and foreign taxes for the years 2006, 2007, and 2008. The table shows current and deferred tax revenue, as well as a provision for income tax. Current tax revenue decreased from 2006 to 2008 for all tax types, while deferred tax revenue increased for federal and foreign taxes. State and local taxes saw a decrease in both current and deferred tax revenue from 2007 to 2008. revenue,  'tax,  'U.S. government,  'federal,  'state and local,  'foreign,  'current,  'deferred,  'income tax,  'years
# Time: 21.19 seconds
#
#
#
# 	32 - Key: d82787ad6
# Balance Sheet of Investments as of December 31, 2018 and 2017. The table presents the balance sheet of investments for two years, 2017 and 2018. The investments are categorized into short-term investments and cash equivalents, fixed maturities, and equity securities. The fixed maturities include corporate securities, commercial mortgage-backed securities, residential mortgage-backed securities, asset-backed securities, foreign government bonds, U.S. government authorities and agencies, and obligations of U.S. states. The table shows the AmortizedCost or Cost and FairValue for each category for both years. Key trends include an increase in the FairValue for total assets supporting experience-rated contractholder liabilities from $21,254 million in 2017 to $22,097 million in 2018. Balance Sheet,  'Investments,  'Short-term investments,  'Cash equivalents,  'Fixed maturities,  'Corporate securities,  'Commercial mortgage-backed securities,  'Residential mortgage-backed securities,  'Asset-backed securities,  'Foreign government bonds,  'U.S. government authorities and agencies,  'Obligations of U.S. states,  'AmortizedCost or Cost,  'FairValue,  '2017,  '2018,  'Increase
# Time: 37.8 seconds
#
#
#
# 	33 - Key: d8327a68c
# Pension and Other Postretirement Benefits. The table presents the financial breakdown of pension and other postretirement benefits for a given period. The recognized net actuarial loss is $1,128, while the other postretirement benefits show a gain of $10. The amortization of prior service credits results in a loss of $56 for pension benefits and $126 for other postretirement benefits. The total net loss for pension benefits is $1,072, while the total gain for other postretirement benefits is $136. Pension,  'Other Postretirement Benefits,  'Actuarial Loss,  'Actuarial Gain,  'Amortization,  'Credits,  'Net Loss,  'Net Gain
# Time: 16.5 seconds
#
#
#
# 	34 - Key: d8202fb30
# Financial Performance Over Three Years. The table displays the financial performance of a company over a three-year period (2010-2012). Key trends include a steady increase in net sales, cost of sales, and operating expenses, resulting in a fluctuating gross margin and operating income. The gross margin percentage shows a slight improvement from 2010 to 2012, while the net income shows a significant increase from 2010 to 2011, followed by a slight decrease in 2012. net sales,  'cost of sales,  'gross margin,  'gross margin percentage,  'operating expenses,  'operating income,  'net income
# Time: 21.95 seconds
#
#
#
# 	35 - Key: d810cc5e4
# 		Skipping d810cc5e4, no table found ...
#
# 	36 - Key: d830e4f70
# 		Skipping d830e4f70, no table found ...
#
# 	37 - Key: d83ac8726
# Plan Assets Fair Value Hierarchy. The table presents the distribution of plan assets subject to fair value hierarchy as of December 31, 2018 and December 31, 2017. The assets are categorized into Level 1, Level 2, and Level 3, with Level 1 being the most observable and Level 3 the least observable. The table shows a decrease in Level 1 assets and an increase in Level 3 assets from 2017 to 2018. The total plan assets increased from $453.7 in 2017 to $503.0 in 2018. Other investments measured at net asset value are also included, with a total increase from $366.2 in 2017 to $399.8 in 2018. plan assets,  'fair value hierarchy,  'Level 1,  'Level 2,  'Level 3,  'total plan assets,  'registered investment companies,  'limited partnerships,  'fixed income securities,  'insurance contracts,  'other,  'net asset value,  '2018,  '2017
# Time: 26.42 seconds
#
#
#
# 	38 - Key: d84dc5f18
# Financial Performance of a Company by Business Segment (2002-2004). The table presents the financial performance of a company by business segment from 2002 to 2004. The segments include Exploration and Production (E&P), Refining, Marketing, and Transportation (RM&T), Integrated Gas (IG), and Corporate. The E&P segment shows an increase in total revenue from domestic and international operations, with a significant jump in international revenue from 2003 to 2004. The RM&T segment also demonstrates an increase in total revenue, while the IG segment shows a significant increase in revenue from 2002 to 2003, followed by a decrease in 2004. The Corporate segment shows a slight increase in revenue from 2002 to 2004. Financial Performance,  'Exploration and Production,  'Refining,  Marketing,  and Transportation,  'Integrated Gas,  'Corporate,  'Revenue,  '2002,  '2003,  '2004
# Time: 26.82 seconds
#
#
#
# 	39 - Key: d8156667c
# Balance Sheet. The table represents a balance sheet for an unspecified company. The total assets amount to $75,723, with significant contributions from Goodwill ($29,405), Amortizable intangibles ($8,330), and Cash ($6,406). The total liabilities are $33,305, leaving a total equity of $42,418. Accounts receivable and Other assets, including investment in TradeHelm, contribute $3,568 to the total assets. Accounts payable, accrued expenses and deferred revenue are a liability of -$8,701. Balance Sheet,  'Total Assets,  'Total Liabilities,  'Total Equity,  'Cash,  'Goodwill,  'Amortizable intangibles,  'Accounts receivable,  'Accounts payable,  'Other assets,  'Investment in TradeHelm,  'Total purchase price
# Time: 23.67 seconds
#
#
#
# 	40 - Key: d811dc146
# Unsecured Borrowings and Net Income Over Three Years. The table displays the financial data of unsecured borrowings and net income for three consecutive years. Unsecured short-term borrowings decreased from -$1,028 million in 2016 to $346 million in 2015, and further to -$1,180 million in 2014. In contrast, unsecured long-term borrowings increased from $584 million in 2016 to $771 million in 2015, but decreased to -$592 million in 2014. Other liabilities and accrued expenses showed a significant decrease from -$55 million in 2016 to -$684 million in 2015, and further to -$441 million in 2014. The table also includes other categories, but they remained constant over the three years. Net income and earnings per share were the same for all three years at $1,023 million and $1.02, respectively. Unsecured borrowings,  'Short-term,  'Long-term,  'Net income,  'Earnings per share,  'Liabilities,  'Accrued expenses,  'Decrease,  'Increase
# Time: 31.38 seconds
#
#
#
# 	41 - Key: d824b7ec8
# Energy Generation by Location, Fuel Type, and Ownership Interest. The table provides a breakdown of energy generation by location, fuel type, ownership interest, gross capacity (in MW), and the percentage of gross capacity under long-term contracts. Key trends include 100% of the gross capacity in California, Michigan (Coal and Wood), and Connecticut (Scrap tire) being under long-term contracts. In Michigan, Natural gas has a higher gross capacity (710 MW) with 61% under long-term contracts, while Wood has lower gross capacity (78 MW) with 100% under long-term contracts. North Carolina has 50 MW of Wood energy generation with no long-term contracts. Location,  'Fuel Type,  'Ownership Interest,  'Gross Capacity,  'Long-Term Contract,  'California,  'Connecticut,  'Michigan,  'North Carolina,  'Wood,  'Coal,  'Scrap tire,  'Natural gas
# Time: 21.75 seconds
#
#
#
# 	42 - Key: d81143a0e
# 		Skipping d81143a0e, no table found ...
#
# 	43 - Key: d83b5a1d0
# Financial Expenses and Income for Selected Years. The table presents financial expenses and income for three selected years (2007, 2008, and 2009). The table includes total share-based compensation expense, research and development expense, selling, general and administrative expense, cost of revenue, operating income, net income, and earnings per share. The total share-based compensation expense increased from $11,731 in 2007 to $18,707 in 2009. The research and development expense, selling, general and administrative expense, and cost of revenue all showed an increase from 2007 to 2008, but decreased from 2008 to 2009. Operating income, net income, and earnings per share remained constant at $1,000 for all three years. total share-based compensation expense,  'research and development expense,  'selling,  general and administrative expense,  'cost of revenue,  'operating income,  'net income,  'earnings per share,  '2007,  '2008,  '2009
# Time: 40.39 seconds
#
#
#
# 	44 - Key: d83dd4b18
# 		Skipping d83dd4b18, no table found ...
#
# 	45 - Key: d81f401c0
# 		Skipping d81f401c0, no table found ...
#
# 	46 - Key: d838f1e52
# Derivative Assets by Type and Year. The table presents the derivative assets by type and year, with the values given in millions of dollars. The table shows a general increase in derivative assets from 2004 to 2005. The most significant increase is observed in Credit derivatives-2, followed by Equity contracts, Interest rate contracts, Commodity contracts, and Foreign exchange contracts. The table also includes credit risk and notional amounts for each type of derivative contract. derivative assets,  '2004,  '2005,  'Interest rate contracts,  'Swaps,  'Futures and forwards,  'Written options,  'Purchased options,  'Foreign exchange contracts,  'Equity contracts,  'Commodity contracts,  'Credit derivatives-2,  'Credit risk,  'Notional
# Time: 23.1 seconds
#
#
#
# 	47 - Key: d82074226
# 		Skipping d82074226, no table found ...
#
# 	48 - Key: d824419da
# 		Skipping d824419da, no table found ...
#
# 	49 - Key: d8202fac2
# 		Skipping d8202fac2, no table found ...
#
# 	50 - Key: d857773cc
# 		Skipping d857773cc, no table found ...
#
# 	51 - Key: d815b556a
# Capital Expenditures and Operating Expenses for the Years 2006 and 2007. The table presents the capital expenditures and operating expenses for the years 2006 and 2007. Key trends include a decrease in total capital expenditures (-9.9%) and net operating income (-13.6%). Notable increases are observed in asset preservation expenditures (+52.2%) and major renovations (+94.0%). capital expenditures,  'operating expenses,  '2006,  '2007,  'decrease,  'increase,  'net operating income
# Time: 35.32 seconds
#
#
#
# 	52 - Key: d817f63ce
# 		Skipping d817f63ce, no table found ...
#
# 	53 - Key: d8240078c
# Ameriprise Financial Income Statement for Years Ended December 31, 2011 and 2010. The table presents the income statement for Ameriprise Financial for the years ended December 31, 2011 and 2010. The table includes revenues, expenses, and net income. Key trends include a 10% increase in total revenues from $10,097 million in 2010 to $10,192 million in 2011. Net income also increased from $970 million in 2010 to $1,076 million in 2011, representing a 4% increase. The most relevant keywords are: revenues, expenses, net income, operating change, GAAP, and distribution fees. revenues,  'expenses,  'net income,  'operating change,  'GAAP,  'distribution fees
# Time: 37.69 seconds
#
#
#
# 	54 - Key: d8259f4bc
# 		Skipping d8259f4bc, no table found ...
#
# 	55 - Key: d8366a422
# Financial Performance Over Three Months in 2008. The table displays the financial performance of a company over three months in 2008. Total revenues show an increase from $245,052 to $268,447, with a slight decrease to $263,265 at the end of the year. Income before income taxes, equity income from unconsolidated joint ventures and minority interests revenues,  'income,  'discontinued operations,  'net income,  'dividends,  'earnings per share,  '2008
# Time: 33.51 seconds
#
#
#
# 	56 - Key: d825901a6
# Refinery Utilization by Refinery and Year. The table displays the refinery utilization for various refineries in different years. The utilization is measured as a percentage. The refineries include HOVENSA, Crude, Fluid catalytic cracker, Coker, Port Reading, Bayway, Delaware City, and Philadelphia. The table shows a general increase in utilization from 2006 to 2008 for all refineries except HOVENSA, which remained constant. Refinery Utilization,  'HOVENSA,  'Crude,  'Fluid catalytic cracker,  'Coker,  'Port Reading,  'Bayway,  'Delaware City,  'Philadelphia,  '2006,  '2007,  '2008,  'Percentage
# Time: 25.56 seconds
#
#
#
# 	57 - Key: d824fcf78
# Loans Receivable and Lending Commitments for Years Ended December 2018 and 2017. The table presents financial data for Loans Receivable and Lending Commitments for the years ended December 2018 and 2017. The table includes changes in the allowance for credit losses, beginning balance, net charge-offs, provision, other, and ending balance. Additionally, the table breaks down the allowance for losses by impairment methodology, including Specific, Portfolio, and PCI. The table shows an increase in Loans Receivable and Lending Commitments for both years, with a significant increase in the ending balance for both years. Loans Receivable,  'Lending Commitments,  'Year Ended December 2018,  'Year Ended December 2017,  'Changes in the allowance for credit losses,  'Beginning balance,  'Net charge-offs,  'Provision,  'Other,  'Ending balance,  'Allowance for losses by impairment methodology,  'Specific,  'Portfolio,  'PCI
# Time: 23.96 seconds
#
#
#
# 	58 - Key: d85173836
# 		Skipping d85173836, no table found ...
#
# 	59 - Key: d813b8ffa
# Carrying Amounts and Estimated Fair Value of Liabilities as of December 31, 2009 and 2008. The table displays the carrying amounts and estimated fair values of various liabilities for the years 2008 and 2009. The liabilities include marketable securities, notes payable, mortgages payable, construction payable, and mandatorily redeemable noncontrolling interests. The table shows a decrease in the carrying amounts and estimated fair values for all liabilities from 2008 to 2009. Carrying Amounts,  'Estimated Fair Value,  'Liabilities,  'Marketable Securities,  'Notes Payable,  'Mortgages Payable,  'Construction Payable,  'Mandatorily Redeemable Noncontrolling Interests,  '2008,  '2009,  'Decrease
# Time: 25.08 seconds
#
#
#
# 	60 - Key: d812184de
# 		Skipping d812184de, no table found ...
#
# 	61 - Key: d8187d63a
# Revenue and Expense Analysis for the Years Ended December 31, 2013 and 2012. The table presents a comparison of the company\ revenues,  'expenses,  'operating earnings,  'net earnings,  'management and financial advice fees,  'distribution fees,  'net investment income,  'premiums,  'other revenues,  'distribution expenses,  'benefits,  claims,  losses and settlement expenses,  'amortization of deferred acquisition costs,  'interest and debt expense,  'general and administrative expense,  'banking and deposit interest expense
# Time: 31.63 seconds
#
#
#
# 	62 - Key: d8151169a
# Financial Table: Property, Plant, and Equipment (PPE). The table presents the financial data for Property, Plant, and Equipment (PPE) for the years 2004 and 2005. The PPE includes land, buildings and leasehold improvements, furniture and equipment, timeshare properties, and construction in progress. The total PPE value decreased from $3,070 million in 2004 to $3,024 million in 2005. The accumulated depreciation increased from $681 million in 2004 to $785 million in 2005. Property,  Plant,  and Equipment (PPE),  'Land,  'Buildings and leasehold improvements,  'Furniture and equipment,  'Timeshare properties,  'Construction in progress,  'Accumulated depreciation,  '2004,  '2005,  'millions
# Time: 20.69 seconds
#
#
#
# 	63 - Key: d843a7b1c
# 		Skipping d843a7b1c, no table found ...
#
# 	64 - Key: d8186c024
# Stores Opened, Closed, and Total Stores at End of Fiscal Year by Region. The table presents the number of stores opened, closed, and the total number of stores at the end of each fiscal year for Best Buy, Future Shop, Best Buy Mobile, Five Star, and Best Buy-3 in various regions. The regions include Best Buy Europe (small box-1 and big box-2), Canada, China, Mexico, Turkey, and the International segment. The table also includes the total number of stores in the U.S. and globally. Stores Opened,  'Stores Closed,  'Total Stores,  'Best Buy,  'Future Shop,  'Best Buy Mobile,  'Five Star,  'Best Buy-3,  'Best Buy Europe,  'Canada,  'China,  'Mexico,  'Turkey,  'International segment,  'U.S.,  'Global
# Time: 29.41 seconds
#
#
#
# 	65 - Key: d80f34d62
# Moody. This table displays the cost of debt for various corporate bond ratings from Moody Moody,  'Corporate Bond,  'Cost of Debt,  'Credit Rating,  'Aaa,  'Aa,  'A,  'Baa,  'Below Investment Grade,  'Amortized Cost,  'Fair Value,  '2003,  '2004,  '2005,  '2006,  '2007,  '2008
# Time: 26.45 seconds
#
#
#
# 	66 - Key: d811fbece
# Stock Price Movement from 2014 to 2015. The table displays the high and low stock prices for each quarter from 2014 to 2015. The stock prices show an overall upward trend, with the highest high price in 2015 ($104.12) being higher than the highest high price in 2014 ($106.31). Similarly, the lowest low price in 2015 ($87.23) is lower than the lowest low price in 2014 ($90.20). stock price,  'high price,  'low price,  'trend,  '2014,  '2015
# Time: 16.89 seconds
#
#
#
# 	67 - Key: d8193ecc2
# Loews Common Stock Performance vs. S&P 500 Index and Peer Group. This table shows the performance of Loews Common Stock, S&P 500 Index, Loews Peer Group, and S&P 500 Equal-Weighted Index from 2011 to 2016. Loews Common Stock had the lowest average value in 2011 and 2015, while it had the highest average value in 2016. The S&P 500 Index had the highest average value in 2014. The Loews Peer Group had the highest average value in 2013 and 2016, while the S&P 500 Equal-Weighted Index had the highest average value in 2016. Loews Common Stock,  'S&P 500 Index,  'Loews Peer Group,  'S&P 500 Equal-Weighted Index,  'performance,  'average value,  '2011,  '2012,  '2013,  '2014,  '2015,  '2016
# Time: 37.77 seconds
#
#
#
# 	68 - Key: d8259025a
# 		Skipping d8259025a, no table found ...
#
# 	69 - Key: d8157da48
# 		Skipping d8157da48, no table found ...
#
# 	70 - Key: d81bf4174
# Assurant Group Financial Performance. The table displays the financial performance of Assurant Group for the years 2014 and 2015. Assurant Solutions and Assurant Specialty Property show a decrease in revenue from 2014 to 2015, with Assurant Solutions reporting $539,653 in 2014 and $529,093 in 2015, and Assurant Specialty Property reporting $301,586 in 2014 and $304,419 in 2015. No data is provided for Assurant Health and Assurant Employee Benefits for either year. Assurant Group,  'financial performance,  'revenue,  'Assurant Solutions,  'Assurant Specialty Property,  '2014,  '2015
# Time: 18.97 seconds
#
#
#
# 	71 - Key: d83ac85aa
# 		Skipping d83ac85aa, no table found ...
#
# 	72 - Key: d82384cae
# Purchase Price Allocation. The table presents the purchase price allocation for a company. The total non-current assets are $442, with property and equipment accounting for $64,564. Intangible assets are valued at $260,898, while current liabilities are -$360 and long-term liabilities are -$7,802. The fair value of net assets acquired is $317,742, with goodwill amounting to -$16,131. The total purchase price allocation is $639,123. Purchase Price Allocation,  'Non-current assets,  'Property and equipment,  'Intangible assets,  'Current liabilities,  'Long-term liabilities,  'Fair value of net assets acquired,  'Goodwill
# Time: 19.01 seconds
#
#
#
# 	73 - Key: d8259020a
# Loans by Banking Type and Product as of December 31. The table presents the total loans for Commercial Banking and Retail Banking as of December 31 for the years 2009 to 2013. Commercial Banking includes Commercial real estate, Commercial and industrial, Equipment financing, and Total Commercial Banking. Retail Banking includes Residential mortgage (Adjustable-rate and Fixed-rate), Consumer (Home equity and Other consumer), and Total Retail. The table shows a general increase in total loans for all categories from 2009 to 2013. loans,  'Commercial Banking,  'Retail Banking,  'Commercial real estate,  'Commercial and industrial,  'Equipment financing,  'Total Commercial Banking,  'Residential mortgage,  'Adjustable-rate,  'Fixed-rate,  'Home equity,  'Other consumer,  'Total retail,  'Total loans
# Time: 23.89 seconds
#
#
#
# 	74 - Key: d827f3dee
# 		Skipping d827f3dee, no table found ...
#
# 	75 - Key: d827f3c0e
# 		Skipping d827f3c0e, no table found ...
#
# 	76 - Key: d8366a4b8
# 		Skipping d8366a4b8, no table found ...
#
# 	77 - Key: d82aee6fc
# Financial Performance of Goldman Sachs Group, 2006. The table presents the financial performance of Goldman Sachs Group for the year ended December 31, 2006. The performance is broken down into five categories: Commodity trading, Investment management, Investment banking, Securities underwriting, and Securities trading. The table shows the average, high, and low values for each category in millions of dollars. The average values range from $0.20 to $1.61, with the highest average in Investment banking and the lowest in Securities underwriting. The high values range from $1.32 to $1.73, with the highest high in Commodity trading and the lowest in Securities underwriting. The low values range from $0.39 to $1.18, with the lowest low in Commodity trading and the highest in Investment management. Goldman Sachs Group,  'Financial Performance,  '2006,  'Commodity trading,  'Investment management,  'Investment banking,  'Securities underwriting,  'Securities trading,  'Average,  'High,  'Low
# Time: 45.5 seconds
#
#
#
# 	78 - Key: d824b7f9a
# Guarantees and Indemnifications Overview. The table provides an overview of various guarantees and indemnifications, including indemnifications from asset sales and other agreements, surety bonds, and put options. The table includes the guarantee description, issue date, expiration date, maximum obligation, FIN 45 carrying amount, and the respective amounts in millions. Key trends include the maximum obligation for guarantees and put options ranging from $1,445 to 1,000, with a consistent FIN 45 carrying amount of 1 million. guarantees,  'indemnifications,  'asset sales,  'surety bonds,  'put options,  'maximum obligation,  'FIN 45 carrying amount,  'millions
# Time: 41.25 seconds
#
#
#
# 	79 - Key: d8177aaf8
# 		Skipping d8177aaf8, no table found ...
#
# 	80 - Key: d83dd4c44
# Financial Analysis of Pension and Share-based Plans. The table presents a financial analysis of pension and share-based plans for the years 2015, 2016, and 2017. The table shows the total expenses and income for each category, as well as the subtotal included in core operating earnings*. The share-based plans have shown a decreasing trend in expenses from $77 in 2017 to $76 in 2015. On the other hand, pension expenses have increased significantly from $217 in 2016 to $1,308 in 2017. Postretirement expenses have also increased from $153 in 2016 to $188 in 2017. The core operating earnings* have shown a decrease from $740 in 2015 to $733 in 2016 and $1,055 in 2017. Financial Analysis,  'Share-based Plans,  'Pension,  'Postretirement,  'Core Operating Earnings,  'Expenses,  'Income,  'Trends
# Time: 26.58 seconds
#
#
#
# 	81 - Key: d81decc88
# 		Skipping d81decc88, no table found ...
#
# 	82 - Key: d82400930
# Assets and Liabilities Acquired. The table presents the financial breakdown of assets and liabilities acquired by the company. The total assets acquired amount to $1,848,575, with the majority coming from Property, plant and equipment ($438,140), Other assets ($124,450), and Trademarks ($138,000). Goodwill is the largest individual asset at $634,203. The total liabilities assumed is $805,914, with current liabilities at $310,919 and long-term liabilities at $494,995. The net assets acquired is $1,042,661. assets,  'liabilities,  'acquired,  'Property,  plant and equipment,  'Other assets,  'Trademarks,  'Goodwill,  'current liabilities,  'long-term liabilities,  'net assets acquired
# Time: 20.4 seconds
#
#
#
# 	83 - Key: d81d75aca
# 		Skipping d81d75aca, no table found ...
#
# 	84 - Key: d80f34dda
# Credit Quality and Cost of Funds - US Corporate Bond Market. This table presents the cost of funds for various credit ratings in the US corporate bond market from 2003 to 2007. The table shows a decrease in the cost of funds for all ratings from 2003 to 2007. In particular, the cost of funds for Aaa, Aa, A, and Baa ratings decreased from $217, $206, $130, and $123 million in 2003 & Prior to $132, $123, $17, and $9 million in 2007, respectively. The cost of funds for bonds below investment grade remained relatively stable at around $4 million in 2003 & Prior and $5 million in 2007. Credit Quality,  'Cost of Funds,  'US Corporate Bond Market,  'Aaa,  'Aa,  'A,  'Baa,  'Below Investment Grade,  '2003,  '2004,  '2005,  '2006,  '2007,  'Million
# Time: 26.92 seconds
#
#
#
# 	85 - Key: d83f65b1c
# Financial Performance Over Three Years. The table presents the financial performance of a company over a three-year period (2012-2014). Key trends include a significant increase in net income from $347.2 in 2012 to $4.6 in 2014, a decrease in income before taxes from $68.1 in 2012 to $.7 in 2014, and a substantial gain on sale of business and impairment/write-down, net of tax, from a loss of $13.6 in 2013 to a gain of $3.9 in 2014. Financial Performance,  'Net Income,  'Income before taxes,  'Gain on sale of business,  'Discontinued Operations
# Time: 20.49 seconds
#
#
#
# 	86 - Key: d815ddb0a
# 		Skipping d815ddb0a, no table found ...
#
# 	87 - Key: d82729ada
# Gain (Loss) Analysis of Assets and Liabilities from 2016 to 2018. The table presents the gain (loss) of assets and liabilities for the years ended December 31, 2016, 2017, and 2018. The table shows a significant decrease in gain for bond and equity securities from $1,646 million in 2017 to $343 million in 2018. Alternative investments, which include private equity, real estate, and hedge funds, also experienced a decrease in gain from $509 million in 2017 to $213 million in 2018. On the other hand, the gain from other assets, including short-term investments, remained constant at zero. Long-term debt, which includes long-term borrowings and capital lease obligations, showed a decrease in loss from $49 million in 2017 to $1 million in 2018. The total gain for the years decreased from $2,105 million in 2017 to $555 million in 2018. gain,  'loss,  'assets,  'liabilities,  'bond,  'equity,  'securities,  'alternative investments,  'private equity,  'real estate,  'hedge funds,  'long-term debt,  'long-term borrowings,  'capital lease obligations,  '2016,  '2017,  '2018
# Time: 33.52 seconds
#
#
#
# 	88 - Key: d82375240
# Net Charge-offs and Allowance for Loan and Lease Losses by Loan Type. This table presents the net charge-offs and allowance for loan and lease losses for commercial and consumer lending for the years 2016 and 2017. The table shows a decrease in total net charge-offs from $543 million in 2016 to $457 million in 2017. The net charge-offs to average loans also decreased from 0.26% in 2016 to 0.21% in 2017. The allowance for loan and lease losses to total loans decreased from 1.23% in 2016 to 1.18% in 2017. Commercial lending net charge-offs decreased from $185 million in 2016 to $105 million in 2017, while consumer lending net charge-offs decreased from $358 million in 2016 to $352 million in 2017. net charge-offs,  'allowance for loan and lease losses,  'commercial lending,  'consumer lending,  '2016,  '2017,  'millions,  'percentage
# Time: 27.7 seconds
#
#
#
# 	89 - Key: d82d2c9c8
# 		Skipping d82d2c9c8, no table found ...
#
# 	90 - Key: d815cd1ec
# 		Skipping d815cd1ec, no table found ...
#
# 	91 - Key: d83f65c16
# Portfolio Performance and Risk Analysis. This table presents the performance and risk analysis of a portfolio for the years ended September 30, 2014, 2013, and 2012. The table includes key financial metrics such as the risk-free interest rate, expected life, expected volatility, expected dividend yield, expected return, actual return, Sharpe ratio, Sortino ratio, Treynor ratio, Jensen Portfolio,  'Performance,  'Risk,  'Analysis,  'Risk-free interest rate,  'Expected life,  'Expected volatility,  'Expected dividend yield,  'Expected return,  'Actual return,  'Sharpe ratio,  'Sortino ratio,  'Treynor ratio,  'Jensen's alpha,  'Beta,  'R-squared
# Time: 38.65 seconds
#
#
#
# 	92 - Key: d828cab46
# 		Skipping d828cab46, no table found ...
#
# 	93 - Key: d816cab26
# Financial Performance of ONEOK Partners from 2005 to 2007. The table displays the financial performance of ONEOK Partners from 2005 to 2007. Key trends include a significant increase in incentive distributions, from $6,568 in 2005 to $50,627 in 2007. General partner distributions also increased, from $2,632 in 2005 to $7,842 in 2007. Net income, net income per unit, net income available for common units, net income available per unit, distributable cash flow, distributable cash flow per unit, cash and cash equivalents, total assets, total liabilities, and total equity remained constant at $10,100 for all years. ONEOK Partners,  'financial performance,  'distributions,  'net income,  'distributable cash flow,  'cash and cash equivalents,  'total assets,  'total liabilities,  'total equity
# Time: 44.01 seconds
#
#
#
# 	94 - Key: d81baf8ee
# Revenue and Operating Expenses Analysis for Fiscal Years 2018 and 2019. The table presents a comparison of the company Revenues,  'Operating expenses,  'EBITDA,  'Net income,  'Circulation and subscription,  'Advertising,  'Other,  'SG&A expenses,  'Fiscal years,  'Increase,  'Decrease
# Time: 33.53 seconds
#
#
#
# 	95 - Key: d815210b8
# Financial Performance and Employment Data. The table presents financial performance and employment data for a company from 2014 to 2016. Key trends include a slight increase in net sales, a fluctuating operating profit, a stable operating margin, a decrease in backlog at year-end, a negative backlog growth rate in 2015, a steady number of employees, and a fluctuating employee growth rate. R&D expenses and their percentage of net sales have increased, while capital expenditures and their percentage of net sales have remained relatively stable. net sales,  'operating profit,  'operating margin,  'backlog,  'backlog growth rate,  'number of employees,  'employee growth rate,  'R&D expenses,  'R&D expenses as % of net sales,  'capital expenditures,  'capital expenditures as % of net sales
# Time: 34.11 seconds
#
#
#
# 	96 - Key: d8259f318
# ...
# Time: 25.65 seconds
#
#
#
# 	846 - Key: d82581ef8
# Financial Modeling Parameters. The table presents key parameters for financial modeling, including the weighted-average fair value, risk-free interest rate, average expected option life, expected volatility, expected dividend yield, and beta. The weighted-average fair value has increased from $24.45 in 2011 to $37.08 in 2013. The risk-free interest rate decreased from 1.91% in 2011 to 0.86% in 2013. The average expected option life and expected volatility have remained relatively stable, while the expected dividend yield has slightly decreased from 0.60% in 2011 to 0.56% in 2013. Beta has slightly decreased from 1.05 in 2013 to 1.03 in 2011. weighted-average fair value,  'risk-free interest rate,  'average expected option life,  'expected volatility,  'expected dividend yield,  'beta
# Time: 24.42 seconds
#
#
#
# 	847 - Key: d816cac7a
# 		Skipping d816cac7a, no table found ...
#
# 	848 - Key: d8194e91a
# Railroad Performance Metrics Comparison (2008-2010). The table presents a comparison of various railroad performance metrics from 2008 to 2010. Key trends include a decrease in average train speed, average rail car inventory, and number of employees, while customer satisfaction index has increased. Gross ton-miles and revenue ton-miles have shown an increase, but a decrease in operating ratio indicates improved efficiency. No significant change was observed in average terminal dwell time. train speed,  'terminal dwell time,  'rail car inventory,  'gross ton-miles,  'revenue ton-miles,  'operating ratio,  'employees,  'customer satisfaction index
# Time: 17.31 seconds
#
#
#
# 	849 - Key: d813b8f64
# Net Cash Flow and Balance Sheet for a Unit. The table presents the balance sheet and net cash flow for a unit over two years (2008 and 2009). The balance sheet shows a decrease in the balance at January 1 and an increase in the balance at December 31. The net cash inflow increased significantly from 2008 to 2009. Unit redemptions, fair market value amortization, and other expenses also decreased from 2008 to 2009. balance sheet,  'net cash flow,  'unit,  '2008,  '2009,  'balance at January 1,  'balance at December 31,  'unit redemptions,  'fair market value amortization,  'other expenses,  'net cash inflow
# Time: 19.06 seconds
#
#
#
# 	850 - Key: d812ed62a
# 		Skipping d812ed62a, no table found ...
#
# 	851 - Key: d8200a768
# 		Skipping d8200a768, no table found ...
#
# 	852 - Key: d81baf7b8
# Revenue Deferral and Recognition for Fiscal Year Ended June 30, 2019. The table presents the balance of deferred revenue for the fiscal year ended June 30, 2019. The deferral of revenue amounted to $3,008 million, which was followed by the recognition of deferred revenue of $-3,084 million. The balance as of July 1, 2018, was $510 million, and the balance as of June 30, 2019, was $428 million. Other expenses totaled $-6 million. deferred revenue,  'revenue,  'recognition,  'balance,  'fiscal year,  'millions
# Time: 18.64 seconds
#
#
#
# 	853 - Key: d838f1f74
# Bond Yield and Volatility. The table presents the key financial characteristics of a bond, including the risk-free interest rate, expected life, expected dividend yield, volatility, and expected return. The risk-free interest rate has decreased from 4.7% in 2007 to a range of 4.4% to 5.3% in 2006 and further to 3.9% in 2005. The expected life of the bond has remained constant at 5.0 years for all years. The expected dividend yield is zero for all years. The volatility of the bond has fluctuated, with a decrease from 37.0% in 2005 to 35% in 2007, followed by an increase to 40.0% in 2006. The expected return of the bond has shown an upward trend, increasing from 8.0% in 2005 to a range of 8.0% to 11.0% in 2006 and further to 9.7% in 2007. risk-free interest rate,  'expected life,  'expected dividend yield,  'volatility,  'expected return
# Time: 27.17 seconds
#
#
#
# 	854 - Key: d81c09236
# Stock Performance Over Time. The table presents the performance of a stock over the years 2016, 2017, and 2018. The stock price, expected annual dividend yield, expected volatility, risk-free interest rate, fair value of stock-based performance units outstanding, and market capitalization are provided for each year. The stock price, dividend yield, and risk-free interest rate remained constant at $14.17, 1.4%, and 2.5%, respectively, across the years. The expected volatility increased from 39% in 2016 to 43% in 2017 and then decreased to 39% in 2018. The fair value of stock-based performance units outstanding decreased from $21.51 in 2016 to $19.60 in 2018, while the market capitalization remained constant at $100,000. stock price,  'dividend yield,  'volatility,  'risk-free interest rate,  'fair value,  'market capitalization,  '2016,  '2017,  '2018
# Time: 27.13 seconds
#
#
#
# 	855 - Key: d811d0ef4
# Citigroup. The table provides a summary of Citigroup Citigroup,  'long-term debt,  'short-term debt,  'total equity,  'total liabilities,  'total assets,  'return on equity,  'return on assets,  'Citigroup Funding Inc.,  'CGMHI-2,  'subsidiaries
# Time: 39.94 seconds
#
#
#
# 	856 - Key: d81be66a0
# 		Skipping d81be66a0, no table found ...
#
# 	857 - Key: d8202fce8
# Financial Performance Over Three Years. This table presents the financial performance of a company over a three-year period from 2013 to 2015. Key trends include a decrease in revenues from $4,710 million in 2014 to $4,695 million in 2015, a significant increase in adjusted operating income from $1,467 million in 2014 to $1,797 million in 2015, and a net income attributable to common stockholders of $1,245 million in 2015. The table also includes various financial metrics such as benefits and expenses, realized investment gains (losses), net, and related adjustments, income (loss) from continuing operations, income tax expense, and earnings per share (diluted). revenues,  'benefits and expenses,  'adjusted operating income,  'realized investment gains (losses),  'income (loss) from continuing operations,  'income tax expense,  'net income (loss) attributable to common stockholders,  'earnings per share (diluted)
# Time: 34.02 seconds
#
#
#
# 	858 - Key: d81695034
# Current Assets and Liabilities as of 2012 and 2013. The table displays the current assets and liabilities of a company for the years 2012 and 2013. The total current assets increased from $1,669.0 million in 2012 to $1,796.2 million in 2013. Notable changes include a $113.1 million decrease in notes payable and current maturities of long-term debt, a $155.6 million increase in accounts payable, and a $446.7 million increase in other current liabilities. Working capital also increased from $1,079.8 million in 2012 to $1,080.8 million in 2013. current assets,  'current liabilities,  '2012,  '2013,  'total current assets,  'notes payable,  'accounts payable,  'working capital
# Time: 22.26 seconds
#
#
#
# 	859 - Key: d825902a0
# 		Skipping d825902a0, no table found ...
#
# 	860 - Key: d8177aa1c
# Balance Sheet as of March 2, 2012. The table presents a balance sheet for an unspecified company as of March 2, 2012. The total assets amount to $16,441, with the majority of the assets being investment securities ($2,349), net loans ($14,512), and other assets ($3,383). The total liabilities, excluding goodwill, amount to -$16,766, with the largest liabilities being deposits (-$18,094) and other borrowed funds (-$1,321). Goodwill is listed separately at $950. Balance Sheet,  'March 2,  2012,  'Total Assets,  'Total Liabilities,  'Investment Securities,  'Net Loans,  'Other Assets,  'Deposits,  'Other Borrowed Funds,  'Goodwill
# Time: 21.71 seconds
#
#
#
# 	861 - Key: d816223ea
# Financial Statements for the Years 2006-2008. The table presents financial statements for the years 2006-2008, including balance sheets, income statements, and cash flow statements. The key trends observed are an increase in net income, net cash provided by operating activities, and total assets, while there is a decrease in cash and cash equivalents, total liabilities, and total equity. Acquisitions and other net expenses led to a decrease in balance at the end of the period and total equity. net income,  'net cash provided by operating activities,  'total assets,  'total liabilities,  'total equity,  'acquisitions,  'other net expenses
# Time: 35.78 seconds
#
#
#
# 	862 - Key: d819100c0
# Bond Portfolio Performance Over Three Years. This table presents the performance of a bond portfolio over a three-year period, from 2006 to 2008. The key metrics include the risk-free interest rate, expected life, dividend yield, expected volatility, and expected return. The risk-free interest rate decreased significantly from 4.7% in 2006 to 2.3% in 2008. The expected life of the portfolio increased from 3.0 years in 2006 to 3.8 years in 2008. The dividend yield remained at 0% throughout the period. The expected volatility fluctuated slightly, decreasing from 37% in 2007 to 34% in 2008. The expected return followed the same trend as the risk-free interest rate, decreasing from 4.7% in 2006 to 2.3% in 2008. bond portfolio,  'performance,  'risk-free interest rate,  'expected life,  'dividend yield,  'expected volatility,  'expected return,  '2006,  '2007,  '2008
# Time: 26.62 seconds
#
#
#
# 	863 - Key: d81cc5a80
# Financial Performance of Key Business Units (2012-2014). The table displays the financial performance of five key business units (Silicon Systems Group, Applied Global Services, Display, Energy and Environmental Solutions) for the years 2012, 2013, and 2014. The performance is measured in millions of dollars, except for percentages. The Silicon Systems Group shows a steady growth in revenue, with a 64% share in 2012, 66% in 2013, and 64% in 2014. Applied Global Services also demonstrates a consistent growth trend, with a 27% share in 2012, 24% in 2013, and 26% in 2014. The Display and Energy and Environmental Solutions units exhibit a decline in their share of the total revenue, from 7% and 7% in 2012 to 5% and 3% in 2014, respectively. Financial Performance,  'Silicon Systems Group,  'Applied Global Services,  'Display,  'Energy and Environmental Solutions,  'Revenue,  'Share,  'Growth,  'Decline
# Time: 25.88 seconds
#
#
#
# 	864 - Key: d818a3a7e
# 		Skipping d818a3a7e, no table found ...
#
# 	865 - Key: d827ba5ee
# 		Skipping d827ba5ee, no table found ...
#
# 	866 - Key: d819e64e0
# 		Skipping d819e64e0, no table found ...
#
# 	867 - Key: d8232f1aa
# Yearly Revenue Growth. The table displays the yearly revenue growth of a company from 2013 to an indefinite future. The revenue data is presented in thousands of dollars. From 2013 to 2016, the revenue remained constant at $3,189 per year. In 2017, there was a significant increase to $750 per year. From 2018 and beyond, the revenue is projected to grow exponentially to $6,725 per year. The total revenue from 2013 to an indefinite future is $11,664. revenue,  'growth,  'yearly,  '2013,  '2014,  '2015,  '2016,  '2017,  '2018,  'total
# Time: 18.17 seconds
#
#
#
# 	868 - Key: d83f65cc0
# Financial Performance of Homebuilding and Financial Services from 2010 to 2014. The table presents the financial performance of a company, with segments in Homebuilding and Financial Services, from 2010 to 2014. Key trends include a significant increase in revenues for the Homebuilding segment from $4,309.7 million in 2010 to $7,858.5 million in 2014. The Financial Services segment also saw a steady increase in revenues from $90.5 million in 2010 to $166.4 million in 2014. The Homebuilding segment showed a fluctuating net income, with a loss in 2011, while the Financial Services segment consistently reported positive net income. The company declared cash dividends per common share for all years. Revenues,  'Homebuilding,  'Financial Services,  'Net Income,  'Cash Dividends,  'Earnings Per Share,  '2010,  '2011,  '2012,  '2013,  '2014
# Time: 44.25 seconds
#
#
#
# 	869 - Key: d828efc98
# 		Skipping d828efc98, no table found ...
#
# 	870 - Key: d818bcd58
# Mortgage Balances as of December 31, 2012 and 2011. The table displays the balance of commercial and residential mortgages at fair value and lower of cost or market as of December 31, 2012 and 2011. Total commercial mortgages increased from $1,294 million in 2011 to $1,392 million in 2012. Total residential mortgages also saw an increase, rising from $1,522 million in 2011 to $2,220 million in 2012. Other balances decreased from $120 million in 2011 to $81 million in 2012. commercial mortgages,  'residential mortgages,  'fair value,  'lower of cost or market,  'balance,  'increase,  'decrease
# Time: 19.9 seconds
#
#
#
# 	871 - Key: d8232efe8
# Error: Could not extract information
# Time: 80.98 seconds
#
#
#
# 	872 - Key: d8194e7e4
# Financial Special Items Analysis. This table presents the financial special items for the years 2012, 2013, and 2014. The table includes five main categories: Other revenue special item, Mainline operating special items, Regional operating special items, Nonoperating special items, and Reorganization items. The Income tax special items are also listed. The total special items for each year are provided at the bottom of the table. The table shows a decrease in total special items from 2013 to 2014, while there was an increase from 2012 to 2013. Financial,  'Special Items,  'Other Revenue,  'Mainline Operating,  'Regional Operating,  'Nonoperating,  'Reorganization,  'Income Tax,  'Analysis,  'Trends,  'Decrease,  'Increase
# Time: 24.72 seconds
#
#
#
# 	873 - Key: d8124326a
# 		Skipping d8124326a, no table found ...
#
# 	874 - Key: d81589514
# BorgWarner Inc. Financial Performance by Quarter (2010). The table displays the financial performance of BorgWarner Inc. for the year 2010, broken down by quarter. Key trends include a steady increase in operating income, net earnings, and earnings per share for both basic and diluted shares. The net sales also show a consistent increase throughout the year, with a total increase of 6.0% for the full year. The operating margin, net earnings margin, and earnings per share margin also exhibit a positive trend, with the operating margin reaching 24.4% for the full year. BorgWarner Inc.,  'financial performance,  'operating income,  'net earnings,  'earnings per share,  'net sales,  'operating margin,  'net earnings margin,  'earnings per share margin,  '2010,  'quarter
# Time: 37.18 seconds
#
#
#
# 	875 - Key: d81dec9c2
# Income Tax Allowance Balance. The table displays the income tax allowance balance for three different years: September 30, 2006, September 24, 2005, and September 25, 2004. The table shows the beginning allowance balance, charged to costs and expenses, deductions, and ending allowance balance for each year. The deductions are for the current period\ Income Tax Allowance Balance,  'Beginning Allowance Balance,  'Charged to costs and expenses,  'Deductions,  'Ending Allowance Balance,  'September 30,  2006,  'September 24,  2005,  'September 25,  2004
# Time: 21.43 seconds
#
#
#
# 	876 - Key: d827cc6a4
# RSUs and Grant-Date Fair Value Per Share. The table presents the number of Restricted Stock Units (RSUs) and their weighted average grant-date fair value per share for different years. The table shows a significant increase in the grant-date fair value per share over the years, with a notable spike in 2013 and 2014. The number of RSUs granted and vested decreases over the years, while the number of forfeited RSUs remains relatively low. RSUs,  'Grant-Date Fair Value,  'Per Share,  'Nonvested,  'Vested,  'Forfeited,  'Increase,  'Decrease,  '2011,  '2012,  '2013,  '2014
# Time: 23.32 seconds

# %%
dataset = "MultiHeritt"
table_dict = np.load(f'table_summaries_{dataset}_long.npy', allow_pickle='TRUE').item()
len(table_dict)
# Out:
# 551

# %% [markdown]
# ----------------------------------------------------------------------------

# %%
create_summaries("TATQA", template_long, "long")
# Out:
# CREATING SUMMARIES FOR TATQA, with template:
# You are a finance expert specialized in analyzing financial tables.
#
# ### Task ###
# Analyze the table and transcribe its contents into a well-structured summary. Generate a detailed paragraph that captures all relevant information, including numerical data, trends, and observations.
# If the table contains acronyms, provide their concise definitions where possible.
# Return the output in the form of a dictionary with the following keys:
# - 'title': A concise title for the table.
# - 'description': A brief description of the table's contents and key trends.
# - 'keywords': A list of the most relevant keywords of the table.
#
# **Note**: Do not return the table, prompt, or any extra text. Return only the dictionary.
#
# ### Table ###
#
#
#
# table_summaries_TATQA_long.npy already created!	 It contains:  80  summary tables  ['d1a71456c', 'd1a719738', 'd1a725a2e', 'd1a718d56', 'd1a717e60', 'd1a72b690', 'd1a71726c', 'd1a7303b6', 'd1a7244a8', 'd1a71b272', 'd1a73a852', 'd1a73ca80', 'd1a7411b6', 'd1a722c66', 'd1a7218e8', 'd1a73b248', 'd1a73ec0e', 'd1a72cf18', 'd1a73c7c4', 'd1a73fa6e', 'd1a71ea1c', 'd1a71fc46', 'd1a7200d8', 'd1a740248', 'd1a739434', 'd1a71d82e', 'd1a73ffe6', 'd1a719d6e', 'd1a73afdc', 'd1a72a358', 'd1a735816', 'd1a72d99a', 'd1a73ba68', 'd1a731c70', 'd1a7249da', 'd1a7127d0', 'd1a728c1a', 'd1a71d310', 'd1a7309a6', 'd1a7362fc', 'd1a72c40a', 'd1a71febc', 'd1a719184', 'd1a730672', 'd1a731748', 'd1a7326f2', 'd1a722202', 'd1a731306', 'd1a71b628', 'd1a7310a4', 'd1a72083a', 'd1a73899e', 'd1a72f362', 'd1a72d184', 'd1a73e024', 'd1a73ccc4', 'd1a73e402', 'd1a720542', 'd1a715e30', 'd1a73715c', 'd1a73ab0e', 'd1a72ff9c', 'd1a714224', 'd1a73fcc6', 'd1a71f084', 'd1a7118d0', 'd1a733a98', 'd1a73d944', 'd1a724228', 'd1a7177a8', 'd1a741ec2', 'd1a73cf94', 'd1a7265a0', 'd1a71a764', 'd1a732a94', 'd1a73e6aa', 'd1a71fa20', 'd1a7261ea', 'd1a71da5e', 'd1a739e3e']
# Timing_TATQA_long.npy already created!	 It contains:  80  summary tables
#
# Loaded extracted_tables_TATQA, it has 248 tables to process
#
#
#
# 	1 - Key: d1a71456c
# 		Skipping d1a71456c, already processed ...
#
# 	2 - Key: d1a719738
# 		Skipping d1a719738, already processed ...
#
# 	3 - Key: d1a725a2e
# 		Skipping d1a725a2e, already processed ...
#
# 	4 - Key: d1a718d56
# 		Skipping d1a718d56, already processed ...
#
# 	5 - Key: d1a717e60
# 		Skipping d1a717e60, already processed ...
#
# 	6 - Key: d1a72b690
# 		Skipping d1a72b690, already processed ...
#
# 	7 - Key: d1a71726c
# 		Skipping d1a71726c, already processed ...
#
# 	8 - Key: d1a7303b6
# 		Skipping d1a7303b6, already processed ...
#
# 	9 - Key: d1a7244a8
# 		Skipping d1a7244a8, already processed ...
#
# 	10 - Key: d1a71b272
# 		Skipping d1a71b272, already processed ...
#
# 	11 - Key: d1a73a852
# 		Skipping d1a73a852, already processed ...
#
# 	12 - Key: d1a73ca80
# 		Skipping d1a73ca80, already processed ...
#
# 	13 - Key: d1a7411b6
# 		Skipping d1a7411b6, already processed ...
#
# 	14 - Key: d1a722c66
# 		Skipping d1a722c66, already processed ...
#
# 	15 - Key: d1a7218e8
# 		Skipping d1a7218e8, already processed ...
#
# 	16 - Key: d1a73b248
# 		Skipping d1a73b248, already processed ...
#
# 	17 - Key: d1a73ec0e
# 		Skipping d1a73ec0e, already processed ...
#
# 	18 - Key: d1a72cf18
# 		Skipping d1a72cf18, already processed ...
#
# 	19 - Key: d1a73c7c4
# 		Skipping d1a73c7c4, already processed ...
#
# 	20 - Key: d1a73fa6e
# 		Skipping d1a73fa6e, already processed ...
#
# 	21 - Key: d1a71ea1c
# 		Skipping d1a71ea1c, already processed ...
#
# 	22 - Key: d1a71fc46
# 		Skipping d1a71fc46, already processed ...
#
# 	23 - Key: d1a7200d8
# 		Skipping d1a7200d8, already processed ...
#
# 	24 - Key: d1a740248
# 		Skipping d1a740248, already processed ...
#
# 	25 - Key: d1a739434
# 		Skipping d1a739434, already processed ...
#
# 	26 - Key: d1a71d82e
# 		Skipping d1a71d82e, already processed ...
#
# 	27 - Key: d1a73ffe6
# 		Skipping d1a73ffe6, already processed ...
#
# 	28 - Key: d1a719d6e
# 		Skipping d1a719d6e, already processed ...
#
# 	29 - Key: d1a73afdc
# 		Skipping d1a73afdc, already processed ...
#
# 	30 - Key: d1a72a358
# 		Skipping d1a72a358, already processed ...
#
# 	31 - Key: d1a735816
# 		Skipping d1a735816, already processed ...
#
# 	32 - Key: d1a72d99a
# 		Skipping d1a72d99a, already processed ...
#
# 	33 - Key: d1a73ba68
# 		Skipping d1a73ba68, already processed ...
#
# 	34 - Key: d1a731c70
# 		Skipping d1a731c70, already processed ...
#
# 	35 - Key: d1a7249da
# 		Skipping d1a7249da, already processed ...
#
# 	36 - Key: d1a7127d0
# 		Skipping d1a7127d0, already processed ...
#
# 	37 - Key: d1a728c1a
# 		Skipping d1a728c1a, already processed ...
#
# 	38 - Key: d1a71d310
# 		Skipping d1a71d310, already processed ...
#
# 	39 - Key: d1a7309a6
# 		Skipping d1a7309a6, already processed ...
#
# 	40 - Key: d1a7362fc
# 		Skipping d1a7362fc, already processed ...
#
# 	41 - Key: d1a72c40a
# 		Skipping d1a72c40a, already processed ...
#
# 	42 - Key: d1a71febc
# 		Skipping d1a71febc, already processed ...
#
# 	43 - Key: d1a719184
# 		Skipping d1a719184, already processed ...
#
# 	44 - Key: d1a730672
# 		Skipping d1a730672, already processed ...
#
# 	45 - Key: d1a731748
# 		Skipping d1a731748, already processed ...
#
# 	46 - Key: d1a7326f2
# 		Skipping d1a7326f2, already processed ...
#
# 	47 - Key: d1a722202
# 		Skipping d1a722202, already processed ...
#
# 	48 - Key: d1a731306
# 		Skipping d1a731306, already processed ...
#
# 	49 - Key: d1a71b628
# 		Skipping d1a71b628, already processed ...
#
# 	50 - Key: d1a7310a4
# 		Skipping d1a7310a4, already processed ...
#
# 	51 - Key: d1a72083a
# 		Skipping d1a72083a, already processed ...
#
# 	52 - Key: d1a73899e
# 		Skipping d1a73899e, already processed ...
#
# 	53 - Key: d1a72f362
# 		Skipping d1a72f362, already processed ...
#
# 	54 - Key: d1a72d184
# 		Skipping d1a72d184, already processed ...
#
# 	55 - Key: d1a73e024
# 		Skipping d1a73e024, already processed ...
#
# 	56 - Key: d1a73ccc4
# 		Skipping d1a73ccc4, already processed ...
#
# 	57 - Key: d1a73e402
# 		Skipping d1a73e402, already processed ...
#
# 	58 - Key: d1a720542
# 		Skipping d1a720542, already processed ...
#
# 	59 - Key: d1a715e30
# 		Skipping d1a715e30, already processed ...
#
# 	60 - Key: d1a73715c
# 		Skipping d1a73715c, already processed ...
#
# 	61 - Key: d1a73ab0e
# 		Skipping d1a73ab0e, already processed ...
#
# 	62 - Key: d1a72ff9c
# 		Skipping d1a72ff9c, already processed ...
#
# 	63 - Key: d1a714224
# 		Skipping d1a714224, already processed ...
#
# 	64 - Key: d1a73fcc6
# 		Skipping d1a73fcc6, already processed ...
#
# 	65 - Key: d1a71f084
# 		Skipping d1a71f084, already processed ...
#
# 	66 - Key: d1a7118d0
# 		Skipping d1a7118d0, already processed ...
#
# 	67 - Key: d1a733a98
# 		Skipping d1a733a98, already processed ...
#
# 	68 - Key: d1a73d944
# 		Skipping d1a73d944, already processed ...
#
# 	69 - Key: d1a724228
# 		Skipping d1a724228, already processed ...
#
# 	70 - Key: d1a7177a8
# 		Skipping d1a7177a8, already processed ...
#
# 	71 - Key: d1a741ec2
# 		Skipping d1a741ec2, already processed ...
#
# 	72 - Key: d1a73cf94
# 		Skipping d1a73cf94, already processed ...
#
# 	73 - Key: d1a7265a0
# 		Skipping d1a7265a0, already processed ...
#
# 	74 - Key: d1a71a764
# 		Skipping d1a71a764, already processed ...
#
# 	75 - Key: d1a732a94
# 		Skipping d1a732a94, already processed ...
#
# 	76 - Key: d1a73e6aa
# 		Skipping d1a73e6aa, already processed ...
#
# 	77 - Key: d1a71fa20
# 		Skipping d1a71fa20, already processed ...
#
# 	78 - Key: d1a7261ea
# 		Skipping d1a7261ea, already processed ...
#
# 	79 - Key: d1a71da5e
# 		Skipping d1a71da5e, already processed ...
#
# 	80 - Key: d1a739e3e
# 		Skipping d1a739e3e, already processed ...
#
# 	81 - Key: d1a7250b0
# Outstanding Shares of Common Stock. The table displays the outstanding shares of common stock for the years ended December 31, 2019, 2018, and 2017. The shares issuable under equity incentive plans have decreased from 10,806 in 2017 to 6,832 in 2019. The total outstanding shares of common stock have decreased from 8,885 in 2017 to 9,022 in 2018 and further decreased to 10,737 in 2019. Convertible senior notes have increased from 0 in 2017 to 79 in 2018 and significantly increased to 1,905 in 2019. outstanding shares,  'common stock,  'equity incentive plans,  'decrease,  'increase,  'convertible senior notes,  'years
# Time: 23.64 seconds
#
#
#
# 	82 - Key: d1a7138d8
# Financial Obligations by Maturity. The table displays the company\ Financial Obligations,  'Maturity,  'Operating lease obligations,  'Capital purchase obligations,  'Other purchase obligations,  'Term Loan Facility,  'Revolving Credit Facility,  'Senior Notes,  'Senior Convertible Debt,  'Junior Convertible Debt,  'Pension obligations,  'Transition tax obligation
# Time: 23.79 seconds
#
#
#
# 	83 - Key: d1a72135c
# Restaurant Financial Performance Comparison (2018 vs 2019). The table presents a comparison of financial performance for a restaurant chain between 2018 and 2019. Key observations include a decrease in total expenses from $17,550 in 2018 to $17,943 in 2019, primarily due to a reduction in costs of closed restaurants and other. Additionally, there was an increase in restructuring costs and a decrease in gains/losses on disposition of property and equipment, net. No operating restaurant impairment charges were recorded in 2019. Restaurant,  'Financial Performance,  '2018,  '2019,  'Restructuring Costs,  'Costs of Closed Restaurants,  'Gains/Losses on Disposition,  'Accelerated Depreciation,  'Operating Restaurant Impairment Charges
# Time: 20.95 seconds
#
#
#
# 	84 - Key: d1a736054
# Financial Performance Over Three Years. The table presents the financial performance of a company over three years (2017-2019). Key trends include a decrease in revenue and net income from 2017 to 2019, while gross margin and operating income saw a decline in 2019 compared to 2018. The cost of goods sold, selling, general, and administrative expenses, research and development expenses, and other operating expense, net all increased from 2017 to 2019. Interest income (expense), net and other non-operating income (expense), net also increased from 2017 to 2019, while income tax (provision) benefit decreased from 2017 to 2019. revenue,  'cost of goods sold,  'gross margin,  'selling,  general,  and administrative,  'research and development,  'other operating expense,  net,  'operating income,  'interest income (expense),  net,  'other non-operating income (expense),  net,  'income tax (provision) benefit,  'net income,  'net income per share
# Time: 33.83 seconds
#
#
#
# 	85 - Key: d1a7289ae
# 2018 FULL-YEAR RESULTS COMPARED TO 2017. The table presents a comparison of the company\ revenue,  'wireless,  'cable,  'media,  'adjusted EBITDA,  'net income,  'margin,  'comparison,  '2018,  '2017
# Time: 23.34 seconds
#
#
#
# 	86 - Key: d1a73c530
# Financial Performance Over Two Years. The table presents the financial performance of an unnamed company over two years, from 2018 to 2019. The key trends include an increase in interest income, a decrease in interest expense, and a significant increase in total loss. Other notable items include realized and unrealized losses on non-designated derivative instruments, foreign exchange (loss) gain, loss on deconsolidation of Altera, and other loss. Interest expense,  'Interest income,  'Loss,  'Foreign exchange,  'Derivative instruments,  'Altera,  'Deconsolidation
# Time: 16.35 seconds
#
#
#
# 	87 - Key: d1a7161fa
# Financial Statements for the Years Ended October 31, 2015 to 2019. The table presents financial statements for the years ended October 31, 2015 to 2019. Key trends include a steady increase in net sales, operating income, and net income, with a peak in 2017. Basic and diluted earnings per share also show an upward trend, with a peak in 2017. Working capital, total assets, and stockholders’ equity have increased over the years. No long-term debt is reported for the years 2017, 2018, and 2019. net sales,  'operating income,  'net income,  'basic earnings per share,  'diluted earnings per share,  'working capital,  'total assets,  'long-term debt,  'stockholders’ equity
# Time: 21.61 seconds
#
#
#
# 	88 - Key: d1a72e818
# Financial Analysis: Costs and Income Over Three Years. The table presents financial data for three years ended March 31, with columns for each year and rows for various cost categories and income. Key trends include a decrease in gross profit, an increase in operating expenses, and a consistent net income of $142. Acronyms used in the table are: Amortization (Amort.), Depreciation (Depr.), and Interest (Int. Exp.). gross profit,  'net income,  'operating expenses,  'amortization,  'depreciation,  'interest expense
# Time: 29.48 seconds
#
#
#
# 	89 - Key: d1a736f40
# Net Periodic Benefit Cost Analysis. The table presents the net periodic benefit cost analysis for the years ended December 31, 2019 and 2018. The key trends include a significant decrease in total net periodic benefit cost by 84.9%, a substantial increase in interest income by 28.7%, and a notable decrease in other components of net periodic benefit cost by 79.6%. Early debt extinguishment costs saw a large increase from 2018 to 2019, but the definition of nm is not provided. net periodic benefit cost,  'interest income,  'other components,  'early debt extinguishment costs,  'total net periodic benefit cost,  'decrease,  'increase,  '2019,  '2018
# Time: 21.29 seconds
#
#
#
# 	90 - Key: d1a728e36
# Precious Metals and Oil Prices Comparison. The table compares the prices of copper, gold, oil, and silver in pounds, troy ounces, and barrels respectively for the fiscal years 2018 and 2019. Prices for copper, gold, and oil decreased while silver remained relatively stable. The average price of copper decreased from $2.86 per pound in 2018 to $2.93 in 2019. Gold prices dropped from 1,281 troy ounces in 2018 to 1,309 troy ounces in 2019. Oil prices decreased significantly from $64.43 per barrel in 2018 to $59.89 in 2019. Silver prices remained relatively stable, with a slight increase from 14.85 troy ounces in 2018 to 14.78 troy ounces in 2019. copper,  'gold,  'oil,  'silver,  'prices,  'fiscal years,  'comparison,  'decrease,  'increase,  'pounds,  'troy ounces,  'barrels
# Time: 28.79 seconds
#
#
#
# 	91 - Key: d1a740c66
# Cash Flow Statement for Fiscal Years Ended August 31, 2019, 2018, and 2017. The table presents the cash flow statement for the fiscal years ended August 31, 2019, 2018, and 2017. Net cash provided by operating activities increased from $(1,105,448) in 2018 to $1,193,066 in 2019, while it decreased from $(1,464,085) in 2017. Cash used in investing activities decreased from $2,141,263 in 2017 to $1,240,914 in 2018 but increased to (872,454) in 2019. Financing activities resulted in a net cash outflow in all three years, with the largest outflow in 2017 at $(404,546). The effect of exchange rate changes on cash and cash equivalents was positive in 2019 and 2018, but negative in 2017. The cash and cash equivalents remained constant at $1,947,310 throughout the three years. cash flow statement,  'net cash,  'operating activities,  'investing activities,  'financing activities,  'exchange rate changes,  'cash and cash equivalents
# Time: 37.06 seconds
#
#
#
# 	92 - Key: d1a735078
# Bond Portfolio Analysis. The table presents a comparison of key bond portfolio metrics for three consecutive years (2017, 2018, and 2019). The table shows the risk-free interest rate, expected life, expected volatility, and credit spread. The risk-free interest rate has increased from 0.94%-2.14% in 2017 to 2.68% in 2019. The expected life remains constant at 5 years for all three years. The expected volatility has decreased from 35.25%-40.22% in 2017 to 32.42% in 2018, but slightly increased to 32.42%-32.84% in 2019. The credit spread remains constant at 150 basis points for all three years. Keywords: Risk-free interest rate, Expected life, Expected volatility, Credit spread. Risk-free interest rate,  'Expected life,  'Expected volatility,  'Credit spread
# Time: 24.58 seconds
#
#
#
# 	93 - Key: d1a739632
# Financial Table: Accrued Interest, Expenses, and Deferred Compensation. The table presents financial figures for the years 2019 and 2018, focusing on accrued interest, accrued expenses, and deferred compensation. Notably, there is a significant decrease in accrued expenses from 2018 to 2019 (7,362 to 11,569). Accrued interest shows a substantial drop from 2018 to 2019 (1,598 to 163). Deferred compensation liabilities remained constant in 2019, while expenses increased from 1,000 to 1,000. Accrued Interest,  'Accrued Expenses,  'Deferred Compensation,  'Liabilities,  'Expenses,  '2019,  '2018
# Time: 21.65 seconds
#
#
#
# 	94 - Key: d1a727e1e
# Financial Performance by Year. The table presents the financial performance of the company for the years ended December 31, 2019 and 2018. The key trends include a significant increase in total revenue, operating income, and net income from 2018 to 2019. The Products and Licensing revenue, Technology Development revenue, and Cost of revenue remained constant at $44,491,041, $26,024,674, and $1,200,000 respectively. The gross profit, operating expenses, and other income also increased from 2018 to 2019. revenue,  'income,  'operating expenses,  'gross profit,  'cost of revenue,  'depreciation,  'amortization,  'net income
# Time: 39.51 seconds
#
#
#
# 	95 - Key: d1a717032
# Financial Performance Over the Years. This table presents the financial performance of a company from 2015 to 2019. The key financial metrics include Adjusted EBITDA, Net income, and various adjustments such as interest expense, income taxes, amortization and depreciation expense, stock-based compensation expense, acquisition-related expense, and litigation expense. The table shows a significant increase in Adjusted EBITDA from 2015 to 2019, with a corresponding increase in net income. However, the company experienced a significant increase in litigation expense in 2017 and a decrease in 2018. Financial Performance,  'Adjusted EBITDA,  'Net Income,  'Interest Expense,  'Income Taxes,  'Amortization and Depreciation Expense,  'Stock-Based Compensation Expense,  'Acquisition-Related Expense,  'Litigation Expense
# Time: 22.49 seconds
#
#
#
# 	96 - Key: d1a7253e4
# Financial Analysis of Charges from Continuing and Discontinued Operations. The table presents financial data for the years 2017, 2018, and 2019, focusing on charges from continuing and discontinued operations. The table shows a significant increase in other associated costs, restructuring charges, and total charges from continuing operations from 2017 to 2018. However, a decrease in these charges is observed from 2018 to 2019. The charges included in discontinued operations remain constant across the three years. charges,  'continuing operations,  'discontinued operations,  'other associated costs,  'restructuring charges,  'years,  '2017,  '2018,  '2019
# Time: 19.72 seconds
#
#
#
# 	97 - Key: d1a71f7d2
# Cash Flow Statement. The table presents a cash flow statement for a company, detailing cash inflows and outflows for the years 2018 and 2019. The primary source of cash inflow is cash flow from operations, which increased significantly from $65.9 million in 2018 to $124.9 million in 2019. Tax paid remained relatively stable, with a slight decrease from ($5.7) million in 2018 to ($5.6) million in 2019. Net capital expenditure decreased from ($10.6) million in 2018 to ($11.9) million in 2019. The table also includes a new line item for "Payment of lease liabilities, principal and interest," which was ($10.3) million in 2019 and was not present in 2018. Overall, the net cash provided by all activities increased from $55.5 million in 2018 to $108.0 million in 2019. cash flow,  'operations,  'tax,  'capital expenditure,  'lease liabilities,  'financing,  'investing,  'net cash provided
# Time: 34.93 seconds
#
#
#
# 	98 - Key: d1a7419cc
# Retail Subscriber Activations and Total Subscribers by Service (2018-2019). The table presents the number of retail subscribers and net subscriber activations (losses) for IPTV and satellite services in the years 2018 and 2019. The total retail subscribers, total retail subscribers excluding satellite, and net changes in subscribers are also provided. The table shows a significant decrease in retail net subscriber activations (losses) for all services, with the largest decrease observed for retail net subscriber activations (losses) in satellite (-15,506). IPTV and satellite services experienced a decrease in total retail subscribers, with IPTV showing a 5.5% increase in subscribers and satellite showing a 0.7% decrease. Total retail subscribers (excluding satellite) decreased by 0.3%. retail subscribers,  'net subscriber activations,  'IPTV,  'satellite,  '2018,  '2019,  'change,  'percent change
# Time: 38.05 seconds
#
#
#
# 	99 - Key: d1a73e9d4
# Financial Performance Over Five Years. This table presents the financial performance of a company over a five-year period (2015-2019). Key trends include a steady increase in net income, a decrease in income tax provision, a fluctuation in other expenses, and a consistent increase in depreciation, amortization, and accretion. The table also includes other financial metrics such as interest expense, interest income, other operating expenses, stock-based compensation expense, and Adjusted EBITDA. Net Income,  'Income tax provision,  'Other expense,  'Loss,  'Interest expense,  'Interest income,  'Other operating expenses,  'Depreciation,  amortization and accretion,  'Stock-based compensation expense,  'ADJUSTED EBITDA,  'Revenue
# Time: 20.12 seconds
#
#
#
# 	100 - Key: d1a7237ce
# Net Income and EBITDA Analysis for the Years 2015-2019. The table presents financial data for the years 2015-2019, focusing on net income and EBITDA. Net income shows a significant decrease from 2015 to 2016, followed by a steady increase until 2019 when it reached a loss of $20 million. EBITDA, on the other hand, shows an upward trend from 2015 to 2019, with a slight dip in 2018. Key adjustments to EBITDA include other net, investment distributions, gain/loss on extinguishment of debt, loss on impairment, and non-cash, stock-based compensation. Net income,  'EBITDA,  '2015,  '2016,  '2017,  '2018,  '2019,  'Interest expense,  'Income tax expense,  'Depreciation and amortization,  'EBITDA adjustments,  'Other net,  'Investment distributions,  'Gain/loss on extinguishment of debt,  'Loss on impairment,  'Non-cash,  stock-based compensation
# Time: 34.48 seconds
#
#
#
# 	101 - Key: d1a7367c0
# Summarised Income Statement and Balance Sheet. The table presents a summarised income statement and balance sheet for a given year. The income statement shows a decrease in revenue from £68.3m in 2018 to £64.0m in 2019, accompanied by a significant increase in loss for the year from £103.7m to £177.2m. The balance sheet indicates a decrease in investment and development property from £841.8m to £676.8m, an increase in borrowings – 4.125% bonds 2023 from £479.5m to £480.5m, an increase in borrowings – compound financial instrument from £473.8m to £488.5m, and a decrease in other net liabilities from £31.2m to £27.7m. Total assets decreased from £1,156.3m to £1,014.0m, while total liabilities increased from £855.6m to £1,146.2m. This resulted in a net assets decrease from £300.7m to £132.2m. revenue,  'loss,  'income statement,  'balance sheet,  'investment and development property,  'borrowings,  '4.125% bonds 2023,  'compound financial instrument,  'other net liabilities,  'total assets,  'total liabilities,  'net assets
# Time: 36.03 seconds
#
#
#
# 	102 - Key: d1a72e41c
# Stock Compensation for Selected Years. The table presents stock compensation data for three fiscal years ended on different dates. The key trends include a significant increase in Restricted Share Awards (RSAs) from 2017 to 2019, while stock options and the Employee Stock Purchase Plan (ESPP) remained constant for 2018 and increased for 2017. No data was provided for the ESPP in 2019. Stock Compensation,  'Fiscal Year,  'Restricted Share Awards,  'RSAs,  'Stock options,  'Employee Stock Purchase Plan,  'ESPP
# Time: 17.33 seconds
#
#
#
# 	103 - Key: d1a740464
# Prepayments Over Two Years. The table displays the total prepayments made by the company for two consecutive years, broken down into four categories: contract manufacturer and supplier prepayments, prepaid taxes, prepaid maintenance and other services, and other prepayments. The total prepayments for 2019 were $176,694, an increase of approximately $14,165 from 2018. The most significant increase was observed in other prepayments, which rose by $4,009. The prepaid taxes and prepaid maintenance and other services categories saw a slight decrease in 2019 compared to 2018. prepayments,  '2019,  '2018,  'contract manufacturer,  'supplier,  'prepaid taxes,  'prepaid maintenance,  'other prepayments,  'increase,  'decrease
# Time: 21.17 seconds
#
#
#
# 	104 - Key: d1a72250e
# Payments Due By Period for Contractual Obligations. The table presents a breakdown of payments due by period for various contractual obligations. The obligations include operating leases, long-term debt, purchase obligations, and claims payable. The purchase obligations are further categorized into feed grains, feed ingredients, and packaging supplies, construction contracts, and other. The table shows that the majority of the payments for operating leases are due within less than 1 year ($15,363), while the rest are due in 1-3 years ($22,919). Long-term debt payments are due in the 3-5 year period ($55,000). For purchase obligations, all payments for feed grains, feed ingredients, and packaging supplies are due immediately ($199,097). The payments for construction contracts and other are also due immediately ($8,996). Claims payable have payments due in less than 1 year ($9,687) and 1-3 years ($10,900). Payments,  'Due,  'Period,  'Contractual Obligations,  'Operating leases,  'Long-term debt,  'Purchase obligations,  'Feed grains,  'Feed ingredients,  'Packaging supplies,  'Construction contracts,  'Claims payable
# Time: 27.26 seconds
#
#
#
# 	105 - Key: d1a713f36
# Net Loss and Earnings Per Share (EPS) for 2018 and 2019. The table shows the net loss and earnings per share (EPS) for the years 2018 and 2019. The net loss decreased from $(24,122) in 2018 to $(15,571) in 2019. The basic EPS decreased from $(1.50) in 2018 to $(0.96) in 2019. The diluted EPS remained the same at $(0.96) for both years. No dilutive impact of stock options and restricted stock awards was recorded. Net Loss,  'Earnings Per Share (EPS),  '2018,  '2019,  'Basic,  'Diluted,  'Stock Options,  'Restricted Stock Awards
# Time: 22.28 seconds
#
#
#
# 	106 - Key: d1a7296ba
# Loans and Investments in Subsidiaries. This table shows the balance sheet items related to loans and investments in subsidiaries for the years 2018 and 2019. The non-current portions of loans and investments have increased, while the current portions have slightly decreased. The non-current portion of loans decreased by 1,321 (2.8%) and the investments increased by 1,000 (10%). The current portion of loans decreased by 59 (2.8%) and the investments increased by 100 (6.7%). loans,  'investments,  'subsidiaries,  'non-current,  'current,  'balance sheet,  'decrease,  'increase
# Time: 21.04 seconds
#
#
#
# 	107 - Key: d1a71f2f0
# Operating Income by Region (2018-2019). The table displays the operating income for the years 2018 and 2019, broken down by region (AMER, APAC, and EMEA) and corporate costs. The Americas (AMER) experienced an increase in operating income from $38.6 billion in 2018 to $57.8 billion in 2019. Asia-Pacific (APAC) saw a decrease from $213.9 billion to $208.2 billion. Europe, Middle East, and Africa (EMEA) had a slight decrease in operating income from $1.5 billion to $4.5 billion. Corporate and other costs decreased from $135.7 billion to $128.4 billion, resulting in a total operating income increase from $307.7 billion to $340.6 billion. operating income,  'loss,  'AMER,  'APAC,  'EMEA,  'corporate costs,  '2018,  '2019,  'increase,  'decrease
# Time: 25.07 seconds
#
#
#
# 	108 - Key: d1a73b46e
# Outstanding Warrants Over Time. The table shows the number of outstanding warrants for a company over the years 2018 and 2019. In 2018, the number of warrants granted was 772,303, forfeited was 224,354, and there were no exercises. At the beginning of 2018, the number of outstanding warrants was 547,949, and at the end of 2018, it was 547,949. In 2019, the number of warrants granted was 0, forfeited was 140,687, and there were no exercises. At the beginning of 2019, the number of outstanding warrants was 547,949, and at the end of 2019, it was 533,262. The table indicates a decrease in the number of outstanding warrants from 2018 to 2019 due to forfeitures. warrants,  'granted,  'forfeited,  'exercised,  'outstanding,  '2018,  '2019,  'decrease
# Time: 28.02 seconds
#
#
#
# 	109 - Key: d1a73ad20
# Current Assets by Category for 2018 and 2019. The table displays the current assets of the company categorized into parts and raw materials, work in process, and finished goods for the years 2018 and 2019. The total current assets increased significantly from $97,987 in 2018 to $230,025 in 2019. The most substantial growth was observed in the finished goods category, which rose from $14,696 in 2018 to $84,934 in 2019. current assets,  'parts and raw materials,  'work in process,  'finished goods,  'increase,  'growth,  '2018,  '2019
# Time: 18.82 seconds
#
#
#
# 	110 - Key: d1a738d04
# Tax Provision Analysis for 2018 and 2019. The table presents the tax provision analysis for the years ended December 31, 2018 and 2019. Key trends include a significant decrease in tax provision at the federal statutory rate, a decrease in the increase (decrease) in valuation allowance, and a decrease in other expenses. Notable changes include a gain on sale or deconsolidation of a subsidiary in 2018 and a bargain purchase gain in the same year. Additionally, there was no ASU 2017-11 adoption in 2018. tax provision,  'federal statutory rate,  'permanent differences,  'state tax,  'foreign rate differential,  'minority interest,  'executive and stock compensation,  'valuation allowance,  'transaction costs,  'tax credits,  'ASU 2017-11,  'goodwill impairment,  'gain/loss on sale or deconsolidation of a subsidiary,  'bargain purchase gain,  'other,  'warrant liability
# Time: 24.68 seconds
#
#
#
# 	111 - Key: d1a72c19e
# Net Cash Flow Statement for the Year Ended December 31, 2019 and 2018. The table presents the net cash flow statement for the years 2019 and 2018. The statement is divided into operating activities, investing activities, financing activities, and the effect of exchange rate changes on cash, cash equivalents, and restricted cash. In 2019, net cash provided by continuing operations was $1,535 million, while in 2018, it was used $14,610 million. The net cash used in discontinued operations was the same for both years at $1,000 million. Overall, the net cash provided by all activities in 2019 was $435 million, while in 2018 it was used $15,610 million. Net Cash Flow Statement,  '2019,  '2018,  'Operating Activities,  'Investing Activities,  'Financing Activities,  'Exchange Rate Changes,  'Net Cash Provided,  'Net Cash Used
# Time: 36.97 seconds
#
#
#
# 	112 - Key: d1a738034
# Financial Analysis for 2018 and 2019. The table presents a financial analysis for the years 2018 and 2019, categorizing expenses into various items. Personnel-related items, deferred revenue, and R&D projects saw an increase in 2019 compared to 2018. Notably, advanced payments from customers experienced a significant rise, while financing related items and supplier related items remained constant. Other expenses also increased slightly. The total expenses for 2019 were 101,281, a 37.4% increase from 2018. Personnel-related items,  'Deferred revenue,  'Financing related items,  'Current portion of lease liabilities,  'Advanced payments from customers,  'Supplier related items,  'Marketing related items,  'R&D projects,  'Other,  'Total,  '2018,  '2019,  'increase,  'expenses
# Time: 22.47 seconds
#
#
#
# 	113 - Key: d1a727b8a
# Revenue Analysis for 2017-2019. The table presents the revenue analysis for the years 2017, 2018, and 2019. The key trends include a steady increase in revenue from $481,985 in 2017 to $576,523 in 2019, representing a growth rate of 7.2%. The "Constant currency revenue" column adjusts for foreign exchange effects, showing a similar trend of growth from $487,850 in 2017 to $583,600 in 2019. The "Foreign exchange effect on current period revenue using prior year rates" column shows a fluctuation in the opposite direction of the revenue growth, with a decrease from $5,865 in 2017 to a loss of $7,077 in 2019. Revenue,  'Growth,  'Foreign exchange effect,  'Constant currency revenue
# Time: 21.51 seconds
#
#
#
# 	114 - Key: d1a72d756
# Revenue Analysis by Business Segment. This table presents the financial performance of a company for the year ended December 31, 2019, comparing it to the previous year (2018). The table shows the revenues generated by software-as-a-service, software and hardware, maintenance, sequencing and molecular analysis, and home health care services. The overall revenue increased by 3.6% from 2018 to 2019, with software-related revenues growing by 14.2%. However, non-software-related revenues decreased by 39.6% during the same period. revenue,  'software-as-a-service,  'software and hardware,  'maintenance,  'sequencing and molecular analysis,  'home health care services,  'growth,  'decrease,  'comparative analysis
# Time: 26.18 seconds
#
#
#
# 	115 - Key: d1a7179c4
# Revenue by Service Type for the Years 2017-2019. The table displays the revenue generated by three service types (Software services, Data and analytics services, and Consulting services) for the years 2017, 2018, and 2019. Total revenue increased slightly from $71.6 million in 2017 to $72.0 million in 2019. However, there was a decrease in revenue for Software services and Consulting services from 2017 to 2018, with a recovery in Software services in 2019. Data and analytics services saw a slight increase in revenue from 2017 to 2018, but a decrease in 2019. revenue,  'service types,  'Software services,  'Data and analytics services,  'Consulting services,  'years,  '2017,  '2018,  '2019,  'increase,  'decrease
# Time: 24.92 seconds
#
#
#
# 	116 - Key: d1a741bd4
# Financial Statement: Total Assets. The table presents the financial statement for total assets from 2018 to 2019. The total assets increased from $790.2 million in 2018 to $890.7 million in 2019. This growth is primarily driven by an increase in raw materials and supplies ($169.8 million in 2019 vs $157.5 million in 2018), work in process (425.7 million in 2019 vs 372.5 million in 2018), and finished and purchased products ($192.2 million in 2019 vs $159.2 million in 2018). total assets,  'raw materials and supplies,  'work in process,  'finished and purchased products,  'growth,  'increase
# Time: 20.15 seconds
#
#
#
# 	117 - Key: d1a7169c0
# Deferred Tax Assets and Liabilities. The table displays the deferred tax assets and liabilities for the company as of September 27, 2019 and September 28, 2018. Notable changes include a decrease in deferred tax assets from $241,044 in 2018 to $190,315 in 2019. Key components of the deferred tax assets include federal and foreign net operating losses and credits, intangible assets, property and equipment, other non-current deferred tax assets, deferred compensation, deferred gain, interest, and valuation allowance. deferred tax assets,  'liabilities,  'September 27,  2019,  'September 28,  2018,  'federal and foreign net operating losses and credits,  'intangible assets,  'property and equipment,  'other non-current deferred tax assets,  'deferred compensation,  'deferred gain,  'interest,  'valuation allowance
# Time: 24.11 seconds
#
#
#
# 	118 - Key: d1a718108
# Average Revenue Per Unit (ARPU) and Customer Connections for 2017 and 2018. The table presents the average revenue per unit (ARPU) and customer connections for the years ended December 31, 2017, and 2018. The ARPU for on-net and off-net connections decreased in 2018 compared to 2017, with the on-net ARPU dropping by 5.1% and the off-net ARPU decreasing by 6.8%. The average price per megabit also experienced a significant decrease of 25.9%. In terms of customer connections, there was a 12.1% increase in on-net connections, a 2.0% increase in off-net connections, and a 2.6% increase in total connections. ARPU,  'on-net,  'off-net,  'average price per megabit,  'customer connections,  'increase,  'decrease
# Time: 26.61 seconds
#
#
#
# 	119 - Key: d1a72f8c6
# Total Revenues and Operating Margin by Geography and Business for the Year Ended May 31, 2019. The table presents the total revenues and operating margin for the year ended May 31, 2019, broken down by geography (Americas, EMEA, and Asia Pacific) and business (Cloud and license, Hardware, and Services). Total revenues for the year remained flat at $39.5 billion, with a 0% change from 2018. The Americas contributed 55% of total revenues, followed by EMEA (29%) and Asia Pacific (16%). The Cloud and license business accounted for 83% of total revenues, followed by Hardware (9%) and Services (8%). The total operating margin was $13.5 billion, representing a 2% increase from 2018, with a margin percentage of 34% for both years. Total Revenues,  'Operating Margin,  'Geography,  'Business,  'Americas,  'EMEA,  'Asia Pacific,  'Cloud and license,  'Hardware,  'Services,  'Percent Change,  '2019,  '2018
# Time: 29.34 seconds
#
#
#
# 	120 - Key: d1a73d6ec
# Issue Price of Shares over Time. This table displays the total number of shares issued and their respective issue prices for specific dates between 1 July 2017 and 31 March 2019. The table shows that shares were issued on five separate occasions, with the largest issuance occurring on 23 February 2018, when 69,129 shares were issued at $8.52 per share. The smallest issuance was on 24 August 2018, when 28,407 shares were issued at no cost. No shares were issued at a cost on 21 December 2018 and 24 August 2018. shares,  'issue price,  'date,  '2017,  '2018,  '2019,  '130, 215, 813,  '130, 284, 942,  '69, 129,  '8.52,  '8.46,  '28, 407,  '129, 044,  '126, 098
# Time: 27.54 seconds
#
#
#
# 	121 - Key: d1a738764
# Fixed Assets Acquisition and Depreciation. The table presents the acquisition and depreciation of fixed assets for the years 2018 and 2019. Key trends include a decrease in total fixed assets acquisition from $86,190 in 2018 to $79,828 in 2019. Notable decreases were observed in leasehold improvements ($3,522 in 2019 vs $3,157 in 2018) and office equipment, computers and furniture ($14,206 in 2018 vs $11,553 in 2019). On the other hand, software acquisition increased slightly from $31,427 in 2018 to $31,349 in 2019. The total depreciation and amortization expenses decreased from $69,585 in 2018 to $58,641 in 2019. fixed assets,  'acquisition,  'depreciation,  '2018,  '2019,  'leasehold improvements,  'LoJack system components,  'law enforcement tracking units,  'plant equipment,  'tooling,  'office equipment,  'computers,  'furniture,  'software
# Time: 27.78 seconds
#
#
#
# 	122 - Key: d1a72d3f0
# Stock Options Data for the Company. The table presents stock options data for the company for the years 2018 and 2019. Key observations include a significant decrease in the number of options exercised, a substantial increase in the number of options granted, and a decrease in the number of options outstanding from 303,880 in 2019 to 149,397 in 2018. options,  'granted,  'exercised,  'outstanding,  'dividend,  'shares,  'forfeited
# Time: 13.88 seconds
#
#
#
# 	123 - Key: d1a73652c
# Year-End Balance Sheet for Fixed Income and Equities. This table presents the year-end balance sheet for municipal bonds, corporate bonds, and equities. The key trends include a decrease in the unrealized losses for municipal bonds, an increase in unrealized gains for corporate bonds, and significant unrealized losses for equities. The fair value of all assets is lower than their amortized cost, with the exception of equities. Amortized Cost,  'Unrealized Gains,  'Unrealized Losses,  'Fair Value,  'Municipal bonds,  'Corporate bonds,  'Equities
# Time: 17.31 seconds
#
#
#
# 	124 - Key: d1a72b474
# Cash Flow Statement for the Year 2019 and 2018. The table presents the cash flow statement for the years 2019 and 2018. At the beginning of the year, the company had $2.3 million in cash in 2019, compared to $2.6 million in 2018. During the year, the company received $0.3 million in cash, an increase from $0.1 million in 2018. The company released $0.6 million to the income statement in 2019, a decrease from $0.4 million in 2018. Net cash provided by operating activities was $1.4 million in 2019, a decrease from $2.1 million in 2018. Capital expenditures were $0.5 million in 2019, an increase from $0.4 million in 2018. The net cash used in investing activities was $0.9 million in 2019, an increase from $0.5 million in 2018. Net cash used in financing activities was $0.2 million in both years. Overall, the net cash provided by all activities was $0.6 million in 2019, a decrease from $1.0 million in 2018. cash flow statement,  '2019,  '2018,  'net cash provided,  'net cash used,  'operating activities,  'investing activities,  'financing activities,  '$ million
# Time: 36.89 seconds
#
#
#
# 	125 - Key: d1a714a58
# Balance Sheet: Property, Equipment, and Accumulated Depreciation. This table presents the balance sheet for a company, focusing on property, equipment, and accumulated depreciation as of December 31, 2019 and 2018. The total property and equipment increased from $309.6 million in 2018 to $345.5 million in 2019. The accumulated depreciation and amortization also increased from $132.5 million in 2018 to $168.6 million in 2019. Key assets include land, buildings and improvements, leasehold improvements, computer equipment, furniture, fixtures and other equipment. Balance Sheet,  'Property,  'Equipment,  'Land,  'Buildings and improvements,  'Leasehold improvements,  'Computer equipment,  'Furniture,  fixtures and other equipment,  'Accumulated depreciation and amortization,  'Increase,  'Total
# Time: 21.75 seconds
#
#
#
# 	126 - Key: d1a734614
# Pension Plan Financial Summary. The table presents the financial summary of a pension plan for the years 2018 and 2019. The projected benefit obligation (PBO) decreased from $3,848 in 2018 to $3,778 in 2019. The accumulated benefit obligation (ABO) also decreased slightly from $3,028 in 2018 to $2,999 in 2019. The funded status ratio improved from 97.9% in 2018 to 98.1% in 2019, indicating a higher level of funding. The total plan assets increased from $3,899 in 2018 to $3,999 in 2019. The unfunded obligation decreased from $830 in 2018 to $779 in 2019. Pension Plan,  'Financial Summary,  'Projected Benefit Obligation,  'Accumulated Benefit Obligation,  'Funded Status Ratio,  'Plan Assets,  'Unfunded Obligation
# Time: 27.48 seconds
#
#
#
# 	127 - Key: d1a73a08c
# Global Revenue by Region (2017-2019). The table displays the global revenue by region from 2017 to 2019. North America shows a significant decrease from $5,513 million in 2017 to $2,259 million in 2019. Europe and South America experienced growth, with Europe increasing from $124,857 million in 2017 to $179,009 million in 2019, and South America rising from $212,616 million in 2017 to $232,394 million in 2019. Asia, on the other hand, experienced a decline from $91,552 million in 2017 to $67,468 million in 2019. The "Other" region shows a slight increase from $28,511 million in 2017 to $1,319 million in 2019. revenue,  'global,  'region,  'North America,  'Europe,  'Asia,  'South America,  'Other,  'decrease,  'increase,  '2017,  '2018,  '2019
# Time: 26.89 seconds
#
#
#
# 	128 - Key: d1a71d5a4
# Unrealized Holding Gains (Losses) and Minimum Pension Liability. The table presents the financial data for Unrealized Holding Gains (Losses) and Minimum Pension Liability for the periods ending March 31, 2017, and December 31, 2016. The table includes the balance at the end of each period, other comprehensive loss before reclassifications, amounts reclassified from accumulated other comprehensive income (loss), net other comprehensive loss, and foreign currency. Key trends include a decrease in Unrealized Holding Gains (Losses) and Minimum Pension Liability from December 31, 2016, to March 31, 2017, and a net other comprehensive loss for both periods. Unrealized Holding Gains (Losses),  'Minimum Pension Liability,  'Other comprehensive loss,  'reclassifications,  'accumulated other comprehensive income (loss),  'foreign currency,  'balance,  'trends
# Time: 25.2 seconds
#
#
#
# 	129 - Key: d1a71dd10
# Total Revenue by Region for the Year Ended December 31. The table shows the total revenue for the company for the years 2018 and 2019, broken down by region. The total revenue decreased by 3.1% from 2018 to 2019. The Americas region saw a 1.9% decrease, Europe/Middle East/Africa had a 4.1% decrease, and Asia Pacific had a 4.3% decrease. However, when adjusted for currency, the Europe/Middle East/Africa region had a 0.4% increase, and the Asia Pacific region had a 1.2% increase. Excluding divested businesses, the Yr.-to-Yr. Percent Change for the total revenue was 0.2%, the Americas region had a 0.8% increase, and the Asia Pacific region had a 0.1% decrease. revenue,  'year,  '2019,  '2018,  'Americas,  'Europe/Middle East/Africa,  'Asia Pacific,  'percent change,  'currency,  'divested businesses
# Time: 27.49 seconds
#
#
#
# 	130 - Key: d1a71e47c
# Quarterly Revenue and Profit Margin. The table displays the quarterly revenue and profit margin for two fiscal years. The revenue ranges from $37.43 to $89.21 in Fiscal 2018 and $54.00 to $89.21 in Fiscal 2019. The profit margin, represented by the low values, varies from $37.43 to $63.81 in Fiscal 2018 and $54.50 to $71.12 in Fiscal 2019. Notably, there is an increase in both revenue and profit margin across all quarters in Fiscal 2019 compared to Fiscal 2018. revenue,  'profit margin,  'fiscal year,  'quarter,  'increase
# Time: 21.72 seconds
#
#
#
# 	131 - Key: d1a7384c6
# Consolidated Financial Data for Selected Years. The table presents the consolidated financial data for the years 2015 to 2019. Key trends include a significant increase in voyage revenues from 2015 to 2016, followed by a decrease in subsequent years. Voyage expenses also decreased from 2015 to 2018, but increased in 2019. Other expenses have consistently increased over the years. The net income fluctuated significantly, with a significant loss in 2018 and a substantial gain in 2019. Voyage Revenues,  'Voyage Expenses,  'Net Operating Income,  'Interest Income,  'Interest Expense,  'Other Financial Expense,  'Total Other Expenses,  'Income Tax Expense,  'Net Income,  'Earnings per Share,  'Cash Dividends Declared per Share,  'Weighted Average Shares Outstanding
# Time: 27.42 seconds
#
#
#
# 	132 - Key: d1a721654
# Financial Performance of a Company (2018-2019). The table presents the financial performance of a company for the years 2018 and 2019. The company experienced an increase in total revenue from US$140,176 in 2018 to US$171,819 in 2019. This growth is primarily driven by an increase in software license revenue (US$64,420 to US$82,575), subscription and maintenance revenue (US$56,996 to US$64,955), and search advertising revenue (US$11,968 to US$17,940). Service revenue and other revenue also saw slight increases. Interest income increased from US$192 to US$933, while interest expense remained constant at US$1,034. Income tax expense increased from US$1,348 to US$1,438, leading to a net income increase from US$12,212 to US$16,582. revenue,  'software license,  'subscription,  'maintenance,  'search advertising,  'service,  'other,  'interest income,  'interest expense,  'income tax,  'net income
# Time: 31.29 seconds
#
#
#
# 	133 - Key: d1a726af0
# ...
# Time: 32.77 seconds
#
#
#
# 	229 - Key: d1a715a70
# Stock-Based Compensation by Type of Award. The table shows the stock-based compensation by type of award for the years ended December 31, 2019 and 2018. The compensation is categorized into stock options, RSUs (Restricted Stock Units), and Other. The total compensation for stock options decreased from $2,926 in 2018 to $2,756 in 2019. RSUs compensation decreased from $1,129 in 2018 to $955 in 2019. The Other category remained relatively stable, with a slight increase from $1,000 in 2018 to $1,025 in 2019. Stock-Based Compensation,  'Type of Award,  'Stock options,  'RSUs,  'Other,  'Decrease,  'Increase,  '2018,  '2019
# Time: 21.43 seconds
#
#
#
# 	230 - Key: d1a7322b0
# Net Income Attributable to Common Shareholders. The table presents the net income (loss) attributable to common shareholders for the years 2017, 2018, and 2019. The net income decreased from $64,945 in 2017 to $(51,644) in 2018, and further decreased to $(20,845) in 2019. The weighted-average number of common shares outstanding increased from 60,373 in 2017 to 70,837 in 2019. The net income per common share followed the same trend, decreasing from 1.07 in 2017 to $(0.73) in 2018 and $(0.29) in 2019. Net income,  'Common shareholders,  '2017,  '2018,  '2019,  'Weighted-average number of common shares outstanding,  'Net income per common share
# Time: 25.6 seconds
#
#
#
# 	231 - Key: d1a71a9bc
# Net Earnings and Earnings Per Share (EPS) for 2018 and 2019. The table displays the net earnings and earnings per share (EPS) for the years 2018 and 2019. Net earnings from operations increased significantly from $157,133 in 2018 to $329,013 in 2019. The basic net earnings per share (EPS) from operations also increased from $3.00 in 2018 to $6.66 in 2019. The diluted net earnings per share (EPS) from operations also showed an increase from $2.93 in 2018 to $6.52 in 2019. Net earnings,  'Earnings per share (EPS),  'Net income per common share,  '2018,  '2019,  'Increase
# Time: 23.96 seconds
#
#
#
# 	232 - Key: d1a711510
# Current Assets and Liabilities Balances with and without Topic 606 Adjustments. The table presents the current assets and liabilities balances with and without the adoption of Topic 606 adjustments. Key trends include a decrease in Prepaid expenses and other current assets due to adjustments, and an overall increase in Total current liabilities. Receivables, less allowance for doubtful accounts, Inventories, Other accrued liabilities, Accounts payable, and Accrued expenses all show a slight decrease when adjusted for Topic 606. Current assets,  'Current liabilities,  'Receivables,  'Inventories,  'Prepaid expenses,  'Other accrued liabilities,  'Accounts payable,  'Accrued expenses,  'Topic 606,  'Adjustments
# Time: 24.41 seconds
#
#
#
# 	233 - Key: d1a734e2a
# Deferred Income Tax Assets and Liabilities. The table presents the deferred income tax assets and liabilities for the company as of March 31, 2019 and March 31, 2018. The assets include deferred revenue, tax value of carry forward losses of UK and overseas subsidiaries, advanced capital allowances, share-based payments, and other temporary differences. The liabilities consist of intangible assets, deferred selling cost, and other temporary differences. The total deferred income tax assets increased from $120.7 million in 2018 to $115.0 million in 2019, while the total deferred income tax liabilities decreased from $14.5 million in 2018 to $15.1 million in 2019. deferred income tax assets,  'deferred income tax liabilities,  '2019,  '2018,  'deferred revenue,  'carry forward losses,  'UK subsidiaries,  'overseas subsidiaries,  'advanced capital allowances,  'share-based payments,  'temporary differences,  'intangible assets,  'deferred selling cost
# Time: 25.78 seconds
#
#
#
# 	234 - Key: d1a741756
# Stock Ownership of Directors and Named Executive Officers. The table displays the number of shares beneficially owned and the percentage owned by directors and named executive officers of an unspecified company. The table also includes a group total for all officers and directors as a group (8 persons). Additionally, it lists the top 5% or greater stockholders, including Benchmark Capital Partners VI, L.P and entities affiliated with DAG Ventures. The table does not include information about the total number of shares outstanding or the company name. Stock Ownership,  'Directors,  'Named Executive Officers,  'Number of Shares,  'Percent Owned,  'Benchmark Capital Partners VI,  L.P,  'DAG Ventures,  'Officers,  'Group Total
# Time: 38.13 seconds
#
#
#
# 	235 - Key: d1a726870
# Financial Performance Over the Years. This table presents the financial performance of a company from 2015 to 2019. Key trends include a steady increase in total bookings, total customers, total revenue, and total expenses, with net income fluctuating but generally increasing. The company total bookings,  'total customers,  'total revenue,  'total expenses,  'net income,  '2015,  '2016,  '2017,  '2018,  '2019
# Time: 36.79 seconds
#
#
#
# 	236 - Key: d1a7334da
# Deferred Tax Assets and Liabilities. The table presents the deferred tax assets and liabilities for the years 2018 and 2019. Deferred tax assets have increased from $15,608 in 2018 to $16,404 in 2019, with significant contributions from Employee benefits ($5,092 in 2019 vs $5,078 in 2018), Capital Loss carry-forward ($2,455 in 2019 vs $1,385 in 2018), and Net operating loss carry-forwards ($5,556 in 2019 vs $6,451 in 2018). Deferred tax liabilities have decreased from $12,688 in 2018 to $11,67 in 2019, primarily due to a decrease in Deferred state income tax ($727 in 2018 vs $767 in 2019). Deferred tax assets,  'Deferred tax liabilities,  'Employee benefits,  'Inventory,  'Accounts receivable,  'Tax credits,  'Capital Loss carry-forward,  'Net operating loss carry-forwards,  'Property,  plant and equipment,  'Other liabilities,  'Deferred state income tax,  'Valuation allowance
# Time: 30.85 seconds
#
#
#
# 	237 - Key: d1a731a4a
# Product Sales and Revenue Growth by Product Line for 2018 and 2019. The table presents the consolidated sales and revenue growth for various products from 2018 to 2019. Key observations include a significant increase in Altium Designer licenses (23%), Octopart search advertising (50%), and TASKING licenses (30%). Notably, service sales experienced a decrease of 28%. Product Sales,  'Revenue Growth,  'Altium Designer licenses,  'Altium Designer subscriptions,  'Octopart search advertising,  'TASKING licenses,  'TASKING maintenance,  'Altium Nexus,  'Service sales,  'Other
# Time: 16.91 seconds
#
#
#
# 	238 - Key: d1a72a812
# Trade Receivables Balance Sheet. The table presents the balance sheet for trade receivables as of December 31, 2019 and 2018. Key observations include an increase in trade receivables (billed and unbilled), with the total trade receivables amounting to $176.4 in 2019 compared to $173.6 in 2018. The allowance for doubtful accounts remained constant at -$1.3 for both years. As a result, net trade receivables increased from $172.3 in 2018 to $175.1 in 2019. Trade Receivables,  'Balance Sheet,  '2019,  '2018,  'Increase,  'Total,  'Billed,  'Unbilled,  'Allowance for doubtful accounts,  'Net trade receivables
# Time: 20.96 seconds
#
#
#
# 	239 - Key: d1a73d426
# Regional Revenue Share by Year. The table shows the regional revenue share for the years 2017, 2018, and 2019. Taiwan and Singapore have maintained relatively stable shares, while China, Japan, USA, Europe, and Others have experienced fluctuations. Taiwan and Singapore have the highest shares in 2019, with Taiwan at 36.4% and Singapore at 16.2%. revenue,  'share,  'region,  'Taiwan,  'Singapore,  'China,  'Japan,  'USA,  'Europe,  'Others,  '2017,  '2018,  '2019
# Time: 15.62 seconds
#
#
#
# 	240 - Key: d1a72e1ec
# Global Sales Revenue by Region (2017-2019). The table displays the sales revenue for various regions of the world from 2017 to 2019. The United States had the highest revenue, followed by Europe, Middle East, and Africa. South America and Asia and Pacific Rim showed a slight increase in revenue, while Canada and All other regions experienced a decrease. sales revenue,  'global,  'regions,  'United States,  'Europe,  'Middle East,  'Africa,  'South America,  'Canada,  'Asia,  'Pacific Rim,  'increase,  'decrease
# Time: 15.43 seconds
#
#
#
# 	241 - Key: d1a711fd8
# Capital Expenditures and Capital Intensity of a Company from 2018 to 2019. The table presents the capital expenditures and capital intensity of a company for the years 2018 and 2019. Capital expenditures are divided into four categories: Wireless, Cable, Media, and Corporate. Wireless expenditures increased by 22% from 2018 to 2019, while Cable expenditures decreased by 19%. Media expenditures grew by 13%, and Corporate expenditures rose by 25%. The total capital expenditures for the company increased by 1% from 2018 to 2019. Capital intensity, which is a measure of the amount of capital invested per unit of output, remained constant at 10.3 for both years.  Capital expenditures,  'Wireless,  'Cable,  'Media,  'Corporate,  'Capital intensity,  'Growth,  'Decrease,  'Percentage change
# Time: 25.45 seconds
#
#
#
# 	242 - Key: d1a72fbe6
# Financial Income and Costs for the Years 2017, 2018, and 2019. The table presents financial income and costs for the years 2017, 2018, and 2019. The financial income includes interest income and total financial income, which remained relatively stable from 2017 to 2018 but increased in 2019. The financial costs consist of amortization and write-off of deferred loan/bond issuance costs/premium, interest expense on loans and realized loss on cash flow hedges, interest expense on bonds and realized loss on CCSs, lease charge, loss arising on bond repurchases at a premium (Note 13), and other financial costs, including unrealized foreign exchange losses on cash and bonds. The total financial costs increased significantly from 2017 to 2018 and continued to rise in 2019. financial income,  'interest income,  'total financial income,  'financial costs,  'amortization,  'write-off,  'deferred loan/bond issuance costs/premium,  'interest expense,  'loans,  'cash flow hedges,  'bonds,  'CCSs,  'lease charge,  'bond repurchases,  'unrealized foreign exchange losses,  'years,  '2017,  '2018,  '2019
# Time: 33.05 seconds
#
#
#
# 	243 - Key: d1a712ec4
# FY19 EAIP NEO Payout Amounts. The table displays the payout amounts for NEOs (Named Executive Officers) based on their base salary, annual incentive target, company performance funding, individual performance factor, and individual payout amount. Key trends include varying base salaries, incentive targets, and payout amounts, with some individuals receiving performance-based bonuses. FY19,  'EAIP,  'NEO,  'payout amounts,  'base salary,  'annual incentive target,  'company performance funding,  'individual performance factor,  'individual payout amount,  'Gregory S. Clark,  'Nicholas R. Noviello,  'Amy L. Cappellanti-Wolf,  'Samir Kapuria
# Time: 17.81 seconds
#
#
#
# 	244 - Key: d1a734402
# Company Financial Analysis for Years Ended December 31, 2019 and 2018. The table presents a financial analysis of the company for the years ended December 31, 2019 and 2018. The analysis includes various expense categories such as salaries, professional fees, acquisition-related costs, board compensation, investor relations, consultants, advertising and promotion, depreciation and amortization, research, development, and maintenance, integration incentives, office, facility, and other expenses, travel, stock-based compensation, and a subtotal. The total compensation expense for 2019 was $19,133,139, which is an increase of $7,106,554 from 2018. Keywords: Salaries, Wages, Benefits, Professional Fees, Acquisition Costs, Board Compensation, Investor Relations, Consultants, Advertising, Depreciation, Research, Development, Maintenance, Integration Incentives, Office Expenses, Travel, Stock-based Compensation. Salaries,  'Wages,  'Benefits,  'Professional Fees,  'Acquisition Costs,  'Board Compensation,  'Investor Relations,  'Consultants,  'Advertising,  'Depreciation,  'Research,  'Development,  'Maintenance,  'Integration Incentives,  'Office Expenses,  'Travel,  'Stock-based Compensation
# Time: 34.2 seconds
#
#
#
# 	245 - Key: d1a7337aa
# Financial Obligations Breakdown. The table provides a breakdown of various financial obligations for the company, categorized by payment period and type of obligation. The key trends include a significant increase in operating lease obligations from 2020 to 2023, followed by a decrease in 2025 and beyond. Purchase obligations show a decrease from 2020 to 2022, with a slight increase in 2023. Liability for uncertain tax positions remains constant from 2021 to 2024, with an increase in 2025 and thereafter. Investment commitments show a decrease from 2020 to 2021, followed by a slight increase in 2022. Financial obligations,  'Operating lease obligations,  'Purchase obligations,  'Liability for uncertain tax positions,  'Investment commitments,  'Payment period,  'Increase,  'Decrease,  '2020,  '2021,  '2022,  '2023,  '2024,  '2025
# Time: 31.92 seconds
#
#
#
# 	246 - Key: d1a716452
# Target Allocations of Plan Assets from 2018 to 2020. The table displays the target allocations of plan assets for three consecutive years, from 2018 to 2020. The asset categories considered are Equity securities, Debt securities, and Other. The percentage of plan assets for each category is provided for the years 2018, 2019, and 2020. Notably, the allocation for Equity securities remained constant at 13% from 2018 to 2020, while Debt securities maintained a steady 83% allocation. The Other category also remained consistent with a 4% allocation throughout the observed period. Target Allocations,  'Plan Assets,  'Equity securities,  'Debt securities,  'Other,  '2018,  '2019,  '2020,  'Percentage
# Time: 19.54 seconds
#
#
#
# 	247 - Key: d1a71cca8
# Post-employment Benefit Obligations for DB Pension Plans and OPEB Plans. The table presents the post-employment benefit obligations for DB pension plans and OPEB plans for the years 2018 and 2019. Key trends include a decrease in the discount rate from 3.8% to 3.1%, a constant rate of compensation increase at 2.25%, and a constant cost of living indexation rate at 1.6%. The actuarial present value of benefits decreased from $900,000,000 in 2018 to $1,000,000,000 in 2019. DB Pension Plans,  'OPEB Plans,  'Post-employment benefit obligations,  'Discount rate,  'Rate of compensation increase,  'Cost of living indexation rate,  'Actuarial present value of benefits,  '2019,  '2018
# Time: 25.63 seconds
#
#
#
# 	248 - Key: d1a71be0c
# Pension Plan Financial Performance. The table presents the financial performance of a pension plan from 2017 to 2019. Key trends include a decrease in the rate of compensation increase and an increase in the actual return on plan assets. The expected long-term return on plan assets has fluctuated, while the discount rate has remained relatively stable. Keywords: pension, financial performance, expected long-term return, rate of compensation increase, discount rate, projected benefit obligation, actual return on plan assets. pension,  'financial performance,  'expected long-term return,  'rate of compensation increase,  'discount rate,  'projected benefit obligation,  'actual return on plan assets
# Time: 20.29 seconds

# %%
dataset = "TATQA"
table_dict = np.load(f'table_summaries_{dataset}_long.npy', allow_pickle='TRUE').item()
len(table_dict)
# Out:
# 248

# %% [markdown]
# ----------------------------------------------------------------------------
